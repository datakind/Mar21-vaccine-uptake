# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd
import os
PROJ_ROOT = os.path.join(os.pardir)

df_path = os.path.join(PROJ_ROOT, 
                         'data',
                          'topics_data_5_topics.csv')
data_path=os.path.join(PROJ_ROOT, 
                         'data')

from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
import seaborn as sns

from textblob import TextBlob

# %%
full_data = pd.read_csv(df_path)
full_data['created_at'] = pd.to_datetime(full_data['created_at'])

# %%
full_data=full_data.drop_duplicates(['user_id','full_text'])

# %%
def vader_sent_df(df=full_data):
    '''Returns a new df with VADER sentiment scores'''
    
    s_vader=SentimentIntensityAnalyzer() #instantiate Analyzer
    
    #create a list of scores for each tweet
    sent_scores = [s_vader.polarity_scores(sent) for sent in tqdm(df.full_text)]
    
    #Add each emotion (positive, negative & compound) scores to the dataframe
    for emotion in sent_scores[0].keys():
        df[emotion+'_sentiment'] = [x[emotion] for x in tqdm(sent_scores)]
    
#     df.index.rename('created_at',inplace=True)
#     df=df.reset_index() #reset the index
    
    return df

def plot_vader_sent(df, title='all'):
    '''Plot the sentiment scores '''
    date_ranges=pd.date_range(start=df.index.min(), end=df.index.max(), freq='D')
    date_ranges=date_ranges.strftime('%m-%d-%Y') # reformat
    # create a list of each emotion
    vals = df.pos_sentiment.tolist()
    n_vals = [x*-1 for x in df.neg_sentiment.tolist()]
    c_vals = df.compound_sentiment.tolist()
    

    #plot the moving averages
    xmin = max(date_ranges)
    xmax = min(date_ranges)
    plt.figure(figsize=(15, 10)) 
    plt.plot(date_ranges,vals, color='blue', alpha=.3, label='positive')
    plt.plot(n_vals,color='red', alpha=.3, label='negative')
    plt.plot(c_vals,color='green', label='compound')
#     plt.hlines(.05, xmin, xmax, linestyles = 'dotted', label='positive')
#     plt.hlines(-.05,xmin,xmax,linestyles = 'dotted', label='negative')
    plt.axhspan(-.05,.05,xmin,xmax, color='grey', alpha=.2,label='neutral')

    
    # label the plot and show
    plt.xlabel('Tweets')
    plt.ylabel('Sentiment Score')
    plt.title('Sentiment Score Across Time for {} data'.format(title))
    plt.grid(which='major',axis='x')
    plt.legend()
    plt.show()
    plt.savefig('sent_over_time.png', bbox_inches='tight')

# %%
full_data.head()
# Out:
#                  created_at  level_0  index      tweet_id  \
# 0 2021-02-23 14:38:16+00:00        0      0  1.364223e+18
# 1 2021-02-24 01:07:52+00:00        1      1  1.364381e+18
# 2 2021-02-24 16:14:15+00:00        2      2  1.364610e+18
# 3 2021-02-24 23:59:58+00:00        3      3  1.364727e+18
# 4 2021-02-24 23:59:58+00:00        4      4  1.364727e+18
#
#                                            full_text  geo coordinates place  \
# 0  Here’s what's in the COVID relief package:\n \...  NaN         NaN   NaN
# 1  Will the National Endowment for the Arts be he...  NaN         NaN   NaN
# 2  This is both anecdotal and early, but many lon...  NaN         NaN   NaN
# 3  A Link to Professor Chossudovsky’s Analysis of...  NaN         NaN   NaN
# 4  Children warned over hugging grandparents even...  NaN         NaN   NaN
#
#    retweet_count  favorite_count  ... rating topic_title     other  \
# 0           9160           38093  ...    244     Opinion  0.000384
# 1           6131           18560  ...  26021     Opinion  0.000716
# 2           5941           63174  ...  23685     Opinion  0.000831
# 3              1               0  ...  20318     Opinion  0.192905
# 4              0               2  ...   3872     Opinion  0.000500
#
#   coronavirus_updates  wellness  vaccine_updates   opinion dominant_topic  \
# 0            0.000384  0.000384         0.000384  0.998462            4.0
# 1            0.000716  0.000716         0.489670  0.508182            4.0
# 2            0.000831  0.000831         0.366900  0.630608            4.0
# 3            0.000668  0.000668         0.000668  0.805090            4.0
# 4            0.000500  0.000500         0.000500  0.997999            4.0
#
#    topic_perc_contrib                                           keywords
# 0              0.9985  coronavirus, vaccine, vaccinate, people, pande...
# 1              0.5087  coronavirus, vaccine, vaccinate, people, pande...
# 2              0.6307  coronavirus, vaccine, vaccinate, people, pande...
# 3              0.8051  coronavirus, vaccine, vaccinate, people, pande...
# 4              0.9980  coronavirus, vaccine, vaccinate, people, pande...
#
# [5 rows x 30 columns]

# %%
#add sentiment analysis to the dataframe
tweet_sent=vader_sent_df()
# Out:
# <ipython-input-4-313ccd9f0773>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   sent_scores = [s_vader.polarity_scores(sent) for sent in tqdm(df.full_text)]
#   0%|          | 0/46324 [00:00<?, ?it/s]
# <ipython-input-4-313ccd9f0773>:11: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   df[emotion+'_sentiment'] = [x[emotion] for x in tqdm(sent_scores)]
#   0%|          | 0/46324 [00:00<?, ?it/s]
#   0%|          | 0/46324 [00:00<?, ?it/s]
#   0%|          | 0/46324 [00:00<?, ?it/s]
#   0%|          | 0/46324 [00:00<?, ?it/s]

# %%
tweet_sent['created_at'] = pd.to_datetime(tweet_sent['created_at'])

# %%
from collections import defaultdict



def aggregate_by_day(df):
        date_ranges=pd.date_range(start=df.created_at.min(), end=df.created_at.max(), freq='D')
        date_ranges=date_ranges.strftime('%m-%d-%Y') # reformat
        tweets_by_day=defaultdict(list)
        df=df.set_index('created_at')
        for day in date_ranges:
            tweets_by_day[day].append(df.loc[day].full_text.tolist())
        
        return tweets_by_day

# %%
#aggreagate all the tweet text by day
tweets_by_day=aggregate_by_day(full_data)
for day,tweets in tweets_by_day.items():
    tweets_by_day[day]=[text for tweet in tweets for text in tweet]
    tweets_by_day[day]= ''.join(tweets_by_day[day][0])
    
tweets_by_day = pd.DataFrame.from_dict(tweets_by_day, orient='index', columns=['full_text'])

# %%
tweets_by_day.head()
# Out:
#                                                     full_text
# 02-22-2021  If there’s one message I want to cut through t...
# 02-23-2021  Here’s what's in the COVID relief package:\n \...
# 02-24-2021  Will the National Endowment for the Arts be he...
# 02-25-2021  Six weeks ago, 14% of people over 75 in the US...
# 02-26-2021  Tell me why I’ve received multiple emails and ...

# %%
#add sentiment analysis to the dataframe
tweet_sent_day=vader_sent_df(df=tweets_by_day)
tweet_sent_day.index=tweets_by_day.index
# Out:
# <ipython-input-4-313ccd9f0773>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   sent_scores = [s_vader.polarity_scores(sent) for sent in tqdm(df.full_text)]
#   0%|          | 0/9 [00:00<?, ?it/s]
# <ipython-input-4-313ccd9f0773>:11: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   df[emotion+'_sentiment'] = [x[emotion] for x in tqdm(sent_scores)]
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]

# %%
tweet_sent_day.to_csv('sentiment_by_day_8t.csv')

# %%
plot_vader_sent(tweet_sent_day)

# %%
def df_plot_by_topic(df):

    for title in df.topic_title.unique():
        print(title)
        tmp=df[df.topic_title==title]

        #aggreagate all the tweet text by day
        tweets_by_day=aggregate_by_day(tmp)
        
        for day,tweets in tweets_by_day.items():
            tweets_by_day[day]=[text for tweet in tweets for text in tweet]
            tweets_by_day[day]= ''.join(tweets_by_day[day][0])


        tweets_by_day = pd.DataFrame.from_dict(tweets_by_day, orient='index', columns=['full_text'])
        

        #add sentiment analysis to the dataframe
        tweet_sent_day=vader_sent_df(df=tweets_by_day)
        tweet_sent_day.to_csv('sentiment_by_topic_by_day_8t.csv')

        plot_vader_sent(tweet_sent_day,title)

# %%
df_plot_by_topic(full_data)
# Out:
# Opinion
# <ipython-input-4-313ccd9f0773>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   sent_scores = [s_vader.polarity_scores(sent) for sent in tqdm(df.full_text)]
#   0%|          | 0/9 [00:00<?, ?it/s]
# <ipython-input-4-313ccd9f0773>:11: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   df[emotion+'_sentiment'] = [x[emotion] for x in tqdm(sent_scores)]
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
# Vaccine Updates
# <ipython-input-4-313ccd9f0773>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   sent_scores = [s_vader.polarity_scores(sent) for sent in tqdm(df.full_text)]
#   0%|          | 0/9 [00:00<?, ?it/s]
# <ipython-input-4-313ccd9f0773>:11: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   df[emotion+'_sentiment'] = [x[emotion] for x in tqdm(sent_scores)]
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
# Coronavirus Updates
# <ipython-input-4-313ccd9f0773>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   sent_scores = [s_vader.polarity_scores(sent) for sent in tqdm(df.full_text)]
#   0%|          | 0/8 [00:00<?, ?it/s]
# <ipython-input-4-313ccd9f0773>:11: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   df[emotion+'_sentiment'] = [x[emotion] for x in tqdm(sent_scores)]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
# Other
# <ipython-input-4-313ccd9f0773>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   sent_scores = [s_vader.polarity_scores(sent) for sent in tqdm(df.full_text)]
#   0%|          | 0/9 [00:00<?, ?it/s]
# <ipython-input-4-313ccd9f0773>:11: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   df[emotion+'_sentiment'] = [x[emotion] for x in tqdm(sent_scores)]
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
# Wellness
# <ipython-input-4-313ccd9f0773>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   sent_scores = [s_vader.polarity_scores(sent) for sent in tqdm(df.full_text)]
#   0%|          | 0/9 [00:00<?, ?it/s]
# <ipython-input-4-313ccd9f0773>:11: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   df[emotion+'_sentiment'] = [x[emotion] for x in tqdm(sent_scores)]
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]

# %%
full_data[['compound_sentiment','user_followers_count']].plot.scatter('user_followers_count','compound_sentiment')
# Out:
# <AxesSubplot:xlabel='user_followers_count', ylabel='compound_sentiment'>

# %% [markdown]
# **user count & sentiment by topic**

# %%
for topic in full_data.topic_title.unique():
    full_data[full_data.topic_title==topic][['compound_sentiment','user_followers_count']].plot.scatter('user_followers_count','compound_sentiment')
    plt.title('topic title {}'.format(str(topic)))
    plt.show()

# %% [markdown]
# ### Who were the most positive and negative twitter users with the most followers?

# %%
top_pos = full_data[['compound_sentiment','user_followers_count','user_id','full_text']]
top_pos = top_pos[(top_pos.user_followers_count>5000000) & (top_pos.compound_sentiment>.05)]
print('Top 5 positive tweets by those with the most followers')
[print(str(i+1)+'\n'+tweet+'\n-----\n') for i,tweet in enumerate(top_pos.sort_values(by='compound_sentiment',ascending=False)[:5].full_text.tolist()) ]
print('scores \n',top_pos.sort_values(by='compound_sentiment',ascending=False)[:5].compound_sentiment.tolist())
print('no of followers \n',top_pos.sort_values(by='compound_sentiment',ascending=False)[:5].user_followers_count.tolist())

print('Twitter Ids')
top_pos.sort_values(by='compound_sentiment',ascending=False)[:5].user_id.tolist()
# Out:
# Top 5 positive tweets by those with the most followers
# 1
# India handled Covid better than many other countries.
# India will now  handle vaccination better than many other countries.
#
# All the best to all Indians as we enter the next phase of vaccination!
#
# Stay healthy. Stay compassionate. When it's your turn, get your vaccine!
# -----
#
# 2
# बस हो गया!
#
# The first dosage of COVID-19 vaccine was administered to me at RR Hospital today.
#
# India’s resolve for making the country COVID free has been strengthened by this inoculation drive. The Vaccine is completely safe and hassle free.
# #LargestVaccineDrive https://t.co/sKsrtLeGqi
# -----
#
# 3
# Hope everyone is alright! Had my wisdom teeth out recently, ruthless stuff! I'll be on in a few days. Sending you all love
# -----
#
# 4
# About 2.5 million women have been forced out of the workforce during the pandemic. The American Rescue Plan provides relief to women and families with $1,400 payments, a $3,000 child tax credit, and funding to safely reopen schools and child care. It’s time for the Senate to act.
# -----
#
# 5
# WHO's Tedros Adhanom Ghebreyesus thanks PM Modi for supporting vaccine equity
#
# "Your commitment to COVAX &amp; sharing COVID19 vaccine doses is helping 60 plus countries start vaccinating their healthworkers&amp;other priority groups.Hope other countries will follow your example,"he says
# -----
#
# scores
#  [0.9476, 0.938, 0.9199, 0.9081, 0.9081]
# no of followers
#  [12743209.0, 19590415.0, 35547449.0, 9264771.0, 5249829.0]
# Twitter Ids
# [44588485.0, 1346439824.0, 84279963.0, 8.036941790794588e+17, 355989081.0]

# %% [markdown]
# Those 5 Twitter users:<br>
# ID Conversions from https://tweeterid.com/:<br><br>
# 44588485 => @chetan_bhagat<br>
# Chetan Bhagat is an Indian author and columnist. He was included in Time magazine's list of World's 100 Most Influential People in 2010. <br><br>
# 1346439824 => @rajnathsingh<br>
# Rajnath Singh is an Indian politician serving as the Defence Minister of India. He is the former President of Bharatiya Janata Party.<br><br>
# 84279963 => @Louis_Tomlinson<br>
# Louis William Tomlinson is an English singer and songwriter. He rose to fame as a member of the boy band One Direction. <br><br>
# 803694179079458816 => @VP
# The vice president of the United States <br><br>
# 355989081 => @ANI<br>
# Asian News International is an Indian news agency that offers syndicated multimedia news feed to multiple news-bureaus in India and beyond.

# %%
top_neg = full_data[['compound_sentiment','user_followers_count','user_id','full_text']]
top_neg = top_neg[(top_neg.user_followers_count>4000000) & (top_neg.compound_sentiment<-.05)]
print('Top 5 positive tweets by those with the most followers')
[print(str(i+1)+'\n'+tweet+'\n-----\n') for i,tweet in enumerate(top_neg.sort_values(by='compound_sentiment',ascending=True)[:6].full_text.tolist()) ]
print('scores \n',top_neg.sort_values(by='compound_sentiment',ascending=True)[:6].compound_sentiment.tolist())
print('no of followers \n',top_neg.sort_values(by='compound_sentiment',ascending=True)[:6].user_followers_count.tolist())

print('Twitter Ids')
top_neg.sort_values(by='compound_sentiment',ascending=True)[:6].user_id.tolist()
# Out:
# Top 5 positive tweets by those with the most followers
# 1
# Attacks against Asian-Americans in New York City have soared since the pandemic began, terrifying many and stoking fears of targeted violence. The xenophobia is also compounded by the economic fallout of the pandemic and fears of the coronavirus.
# https://t.co/9sbMfgQWzv
# -----
#
# 2
# How annoying that the Brazil variant snuck into Britain during the many weeks we knew about it but didn’t shut our border.
# Damn that virus for not respecting our Govt’s right to dither and delay.
# -----
#
# 3
# One year ago today, Kayleigh McEnany made a really bad COVID prediction, but what's really special is how she also made a bad terrorism prediction in the same sentence https://t.co/yIjgHFMm3K
# -----
#
# 4
# @AP The FDA said J&amp;J’s vaccine offers strong protection against what matters most: serious illness, hospitalizations and death. One dose was 85% protective against the most severe COVID-19 illness, in a massive study that spanned three continents. https://t.co/GcNZXjVCpQ
# -----
#
# 5
# Fraudsters are trying to cash in on mistakes made by the EU's #coronavirus vaccination campaign by offering millions of scam jabs to member states https://t.co/PIDxvMOymU
# -----
#
# 6
# Virus update:
# • U.S. COV-19 death toll tops 500,000.
# • Biden mourns American dead, balancing nation's grief and hope.
# • Doctors trying to treat patients who lose sense of smell.
# • Mexico gets doses of Russian vaccine.
#
# Follow all @AP coverage: https://t.co/JBfeZY1bn1
# -----
#
# scores
#  [-0.946, -0.8955, -0.8897, -0.8733, -0.8625, -0.8625]
# no of followers
#  [49523682.0, 7764801.0, 9452014.0, 15089739.0, 7001025.0, 15089739.0]
# Twitter Ids
# [807095.0, 216299334.0, 158414847.0, 51241574.0, 7587032.0, 51241574.0]

# %% [markdown]
# Those 5 Twitter users:<br><br>
# 807095 => @nytimes<br>
# 51241574 => @AP<br>
# 216299334 => @piersmorgan<br>
# Piers Stefan Pughe-Morgan is an English broadcaster, journalist, writer, and television personality. <br>
# 158414847 => @TheDailyShow<br>
# 51241574 => @AP<br><br>
#
# This does not track well for negative sentiments.<br>
# - Most are news outlets<br>
# - Results may be different if subjectiviiy is taken into account, some of these are covid updates on deaths, illness etc. Which are counted as a negative sentiment.<br>
# - Sentiment can be re-run with these keywords removed to get a better sense of the sentiment<br><br>
#
# Sentiment via a NN may be better option for this dat

# %%
# functions to determine sentiment based on intensity/subjectivity scores for TextBlob

def sent_scores(row):
  subj = row['tb_score']
  if row['compound_sent'] < .05 and row['compound_sent'] > -.05:
    return 'neu'
  elif row['neg_sent'] < .2 and row['pos_sent'] - row['neg_sent'] > 0:
        return 'pos'
  elif row['pos_sent'] < .2 and row['neg_sent'] - row['pos_sent'] > 0:
        return 'neg'
  else:
    return 'neu'

def sent_subj(row):
  subj = row['tb_score']
  if row['compound_sent'] < .05 and row['compound_sent'] > -.05:
    return 'neu'
  elif row['pos_sent'] - row['neg_sent'] > .05 and row['tb_subj']>.30 and row['neg_sent']>0 and row['compound_sent']>.5:
        return 'pos'
  elif row['neg_sent'] - row['pos_sent'] > .05 and row['tb_subj']>.30 and row['pos_sent']>0 and row['compound_sent']<-.5:
        return 'neg'
  else:
    return 'neu'

# %%
s_vader = SentimentIntensityAnalyzer() # instantiate the Analyzer

#process the VADER score for all tweets in the df
vader_score = [s_vader.polarity_scores(sent) for sent in tqdm(full_data.full_text)] 

#add each sentiment option as a column in the dataframe, and place the score for each for each sentence
for scores in vader_score[0].keys():
    full_data[scores+'_sent'] = [x[scores] for x in vader_score ]
# Out:
# <ipython-input-21-03a8f8c4dcf2>:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   vader_score = [s_vader.polarity_scores(sent) for sent in tqdm(full_data.full_text)]
#   0%|          | 0/46324 [00:00<?, ?it/s]

# %% [markdown]
# ### textblob sentiment

# %%
#obtain the sentiment polarity & subjectivity scores for each tweet
tb_score = [TextBlob(sent).polarity for sent in tqdm(full_data.full_text)]
tb_sub_score = [TextBlob(sent).subjectivity for sent in tqdm(full_data.full_text)]

#place the polarity and subjectivity scores into the dataframe
full_data['tb_score']=tb_score
full_data['tb_subj']=tb_sub_score
# Out:
# <ipython-input-22-1b48cb5fcb02>:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   tb_score = [TextBlob(sent).polarity for sent in tqdm(full_data.full_text)]
#   0%|          | 0/46324 [00:00<?, ?it/s]
# <ipython-input-22-1b48cb5fcb02>:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   tb_sub_score = [TextBlob(sent).subjectivity for sent in tqdm(full_data.full_text)]
#   0%|          | 0/46324 [00:00<?, ?it/s]

# %%
# add the TextBlob sentiment with the rules in the defined functions
full_data['tb_sent'] = full_data.apply(sent_scores, axis=1)
full_data['tb_sent_subj'] = full_data.apply(sent_subj, axis=1)
# add the VADER sentiment to the dataframef
full_data['v_sent'] = full_data.apply(lambda x: 'pos' if x['compound_sent']>=.05 else ('neg' if x['compound_sent']<=-.05 else 'neu'), axis=1)

# %% [markdown]
# ## EDA with sentiment

# %% [markdown]
# ### Sentiment scores by topic
# Which topics had the most/least positive and negative sentiment?

# %%
sent_bytopic_dict = defaultdict(list)

sent_vals = {'neu','pos','neg'}

for x, topic in enumerate(full_data.topic_title.unique()):
    cnts = full_data[full_data.topic_title==topic].tb_sent_subj.value_counts(normalize=True)
    
    for idx in cnts.index:
        sent_bytopic_dict[idx+'_p'].append(cnts.loc[idx])
    
    if len(cnts.index)<3:
        for s in sent_vals.difference(set(cnts.index)):
            sent_bytopic_dict[s+'_p'].append(0)
    
    
    cnts = full_data[full_data.topic_title==topic].tb_sent_subj.value_counts()
    
    for idx in cnts.index:
        sent_bytopic_dict[idx].append(cnts.loc[idx])
    
    if len(cnts.index)<3:
        for s in sent_vals.difference(set(cnts.index)):
            sent_bytopic_dict[s].append(0)
    
    sent_bytopic_dict['topic'].append(topic)

# %%
sent_cnts_topic = pd.DataFrame.from_dict(sent_bytopic_dict)
display(sent_cnts_topic)
sent_cnts_topic.to_csv('sent_by_topic_total_8t.csv',index=False)
# Out:
#       neu_p     neg_p     pos_p    neu   neg   pos                topic
# 0  0.854623  0.076652  0.068725  22533  2021  1812              Opinion
# 1  0.959005  0.014025  0.026970  16890   247   475      Vaccine Updates
# 2  0.981453  0.013910  0.004637    635     9     3  Coronavirus Updates
# 3  0.955272  0.015974  0.028754    897    15    27                Other
# 4  0.975000  0.005263  0.019737    741     4    15             Wellness

# %%
# sent_cnts_topic['topic']=sent_cnts_topic.topic.astype(str)

# %%
sent_cnts_topic['topic'] = sent_cnts_topic.topic.astype(str)

# %%
plot=sns.catplot(y='topic',
                 x='neg_p', 
                 kind='bar',
                 data = sent_cnts_topic.sort_values(by=['neg_p'],ascending=False), 
                 color='red', 
                 height=7,
                 aspect=1.3)
plot.set_yticklabels(fontsize=14)
plot.fig.suptitle('Negative Sentiment Disbribution by Topic', y=1.05)
plot.ax.set_xlabel('Negative Sentiment')
plot.ax.set_ylabel('Topic')
# fig.show()
# Out:
# Text(-81.45, 0.5, 'Topic')

# %%
plot=sns.catplot(y='topic',
                 x='neg', 
                 kind='bar',
                 data = sent_cnts_topic.sort_values(by=['neg'],ascending=False), 
                 color='red', 
                 height=7,
                 aspect=1.3)
plot.set_yticklabels(fontsize=14)
plot.fig.suptitle('Negative Sentiment Counts by Topic', y=1.05)
plot.ax.set_xlabel('Negative Sentiment')
plot.ax.set_ylabel('Topic')
# Out:
# Text(-81.45, 0.5, 'Topic')

# %%
plot=sns.catplot(y='topic',
                 x='pos_p', 
                 kind='bar',
                 data = sent_cnts_topic.sort_values(by=['pos_p'],ascending=False), 
                 color='blue', 
                 height=7,
                 aspect=1.3)
plot.set_yticklabels(fontsize=14)
plot.fig.suptitle('Positive Sentiment Disbribution by Topic', y=1.05)
plot.ax.set_xlabel('Positive Sentiment')
plot.ax.set_ylabel('Topic')
# fig.show()
# Out:
# Text(-81.45, 0.5, 'Topic')

# %%
plot=sns.catplot(y='topic',
                 x='pos', 
                 kind='bar',
                 data = sent_cnts_topic.sort_values(by=['pos'],ascending=False), 
                 color='blue', 
                 height=7,
                 aspect=1.3)
plot.set_yticklabels(fontsize=14)
plot.fig.suptitle('Positive Sentiment Counts by Topic', y=1.05)
plot.ax.set_xlabel('Positive Sentiment')
plot.ax.set_ylabel('Topic')
# fig.show()
# Out:
# Text(-81.45, 0.5, 'Topic')

# %%
plot=sns.catplot(y='topic',
                 x='neu', 
                 kind='bar',
                 data = sent_cnts_topic.sort_values(by=['neu'],ascending=False), 
                 color='grey', 
                 height=7,
                 aspect=1.3)
plot.set_yticklabels(fontsize=14)
plot.fig.suptitle('Neutral Sentiment Counts by Topic', y=1.05)
plot.ax.set_xlabel('Neutral Sentiment')
plot.ax.set_ylabel('Topic')
# fig.show()
# Out:
# Text(-81.45, 0.5, 'Topic')

# %%
plot=sns.catplot(y='topic',
                 x='neu_p', 
                 kind='bar',
                 data = sent_cnts_topic.sort_values(by=['neu_p'],ascending=False), 
                 color='grey', 
                 height=7,
                 aspect=1.3)
plot.set_yticklabels(fontsize=14)
plot.fig.suptitle('Neutral Sentiment Counts by Topic', y=1.05)
plot.ax.set_xlabel('Neutral Sentiment')
plot.ax.set_ylabel('Topic')
# fig.show()
# Out:
# Text(-81.45, 0.5, 'Topic')

# %% [markdown]
# Without looking at many of the tweets in each topic, my assumptions based on the above graphs is: <br><br>
# - That the 'Opinion' topic has tweets that are more subjective and thus more positive and negative.
# - Where the topic 'Vaccine Info' encompassing roll out, distribution, details have more positive sentiment within their topic than say the Pandemic info. Tweets about vaccines 'finally' getting to a certain area or celebrating that they've taken the vaccine. I assume the negative tweets here would be the updates where the vaccine is delayed and/or warning about taking the vaccine are  sorted.
# - The topic of Pandemic Info has a lot of negative sentiment tweets within it's topic, but, because the vast majority of tweets in this topic are not as much as 'Opinion' I'm assuming this is because the Pandemic Info are tweets with updates that are less subjective but carry a lot of tweets that carry negative sentiment. Such as 'death' and 'serious illness'.
# - It would be interesting to see how objective/subjective each of these topics are
# - The non-Opinion topics have a higher % of neutral comments within the topic than the 'Opinion'.

# %% [markdown]
# ### Investigate levels of subjectivity within each topic

# %%
full_data['subjectivity']=full_data.apply(lambda x: 'low' if x['tb_subj']<.2 else ('high' if x['tb_subj']>.45 else 'med'),axis=1)

# %%
sentb_bytopic_dict = defaultdict(list)

sent_vals = {'high','med','low'}

for x, topic in enumerate(full_data.topic_title.unique()):
    cnts = full_data[(full_data.topic_title==topic)].subjectivity.value_counts(normalize=True)
    
    for idx in cnts.index:
        sentb_bytopic_dict[idx+'_p'].append(cnts.loc[idx])
    
    if len(cnts.index)<3:
        for s in sent_vals.difference(set(cnts.index)):
            sentb_bytopic_dict[s+'_p'].append(0)
    
    
    cnts = full_data[full_data.topic_title==topic].subjectivity.value_counts()
    
    for idx in cnts.index:
        sentb_bytopic_dict[idx].append(cnts.loc[idx])
    
    if len(cnts.index)<3:
        for s in sent_vals.difference(set(cnts.index)):
            sentb_bytopic_dict[s].append(0)
    
    sentb_bytopic_dict['topic'].append(topic)

# %%
sentb_cnts_topic = pd.DataFrame.from_dict(sentb_bytopic_dict)
display(sentb_cnts_topic)
sentb_cnts_topic.to_csv('subjectivity_by_topic_8t.csv',index=False)
sentb_cnts_topic['topic']=sentb_cnts_topic.topic.astype(str)
# Out:
#      high_p     med_p     low_p   high   med   low                topic
# 0  0.479709  0.288553  0.231738  12648  7608  6110              Opinion
# 1  0.352544  0.298944  0.348512   6209  5265  6138      Vaccine Updates
# 2  0.588872  0.143740  0.267388    381    93   173  Coronavirus Updates
# 3  0.358892  0.296060  0.345048    337   278   324                Other
# 4  0.359211  0.200000  0.440789    273   152   335             Wellness

# %%
plot=sns.catplot(y='topic',
                 x='high_p', 
                 kind='bar',
                 data = sentb_cnts_topic.sort_values(by=['high_p'],ascending=False), 
                 color='steelblue', 
                 height=7,
                 aspect=1.3)
plot.set_yticklabels(fontsize=14)
plot.fig.suptitle('High Subjectivity Distribution by Topic', y=1.05)
plot.ax.set_xlabel('Subjective Sentiment')
plot.ax.set_ylabel('Topic')
# fig.show()
# Out:
# Text(-81.45, 0.5, 'Topic')

# %%
plot=sns.catplot(y='topic',
                 x='med_p', 
                 kind='bar',
                 data = sentb_cnts_topic.sort_values(by=['med_p'],ascending=False), 
                 color='grey', 
                 height=7,
                 aspect=1.3)
plot.set_yticklabels(fontsize=14)
plot.fig.suptitle('Med Subjectivity Distribution by Topic', y=1.05)
plot.ax.set_xlabel('Subjective Sentiment')
plot.ax.set_ylabel('Topic')
# fig.show()
# Out:
# Text(-81.45, 0.5, 'Topic')

# %%
plot=sns.catplot(y='topic',
                 x='low_p', 
                 kind='bar',
                 data = sentb_cnts_topic.sort_values(by=['low_p'],ascending=False), 
                 color='grey', 
                 height=7,
                 aspect=1.3)
plot.set_yticklabels(fontsize=14)
plot.fig.suptitle('Low Subjectivity Distribution by Topic', y=1.05)
plot.ax.set_xlabel('Subjective Sentiment')
plot.ax.set_ylabel('Topic')
# fig.show()
# Out:
# Text(-81.45, 0.5, 'Topic')

# %% [markdown]
# They all have a similar distribution of High/Med/Low subjectivity within each topic.

# %%
subj_cnts=sentb_cnts_topic.melt('topic', var_name='subjectivity',value_name='val')

plt.figure(figsize=(15,10))
catplot=sns.catplot(y='val',
              x='topic', 
              kind='bar',
              data = subj_cnts,
              hue='subjectivity',
              palette = ['slategrey','lightsteelblue','cornflowerblue']*3,
              col='subjectivity',
              sharey=False,
              sharex=False,
              col_wrap=3,
                   dodge=False)
plt.subplots_adjust(hspace=.7)
catplot.fig.suptitle('Subjectivity Disbribution by Topic', y=1.05)
catplot.set_xticklabels(rotation=65, horizontalalignment='right')

# %%
display(sentb_cnts_topic)
# Out:
#      high_p     med_p     low_p   high   med   low                topic
# 0  0.479709  0.288553  0.231738  12648  7608  6110              Opinion
# 1  0.352544  0.298944  0.348512   6209  5265  6138      Vaccine Updates
# 2  0.588872  0.143740  0.267388    381    93   173  Coronavirus Updates
# 3  0.358892  0.296060  0.345048    337   278   324                Other
# 4  0.359211  0.200000  0.440789    273   152   335             Wellness

# %%
subj_cnts=sentb_cnts_topic.melt('topic', var_name='subjectivity',value_name='val')
vals1 = list(set([x for x in subj_cnts.subjectivity.values if '_' in x ]))
vals2 = list(set([x for x in subj_cnts.subjectivity.values if '_' not in x ]))
for topic in subj_cnts.topic.unique():
    for vals in [vals1, vals2]:
        
    
        plt.figure(figsize=(15,10))
        catplot=sns.catplot(y='val',
                      x='subjectivity', 
                      kind='bar',
                      data = subj_cnts[(subj_cnts.topic==topic) & (subj_cnts.subjectivity.isin(vals))],
                      hue='subjectivity',
                      palette = ['slategrey','lightsteelblue','cornflowerblue']*2,
                      col='topic',
                      sharey=False,
                      sharex=False,
                      col_wrap=3,
                           dodge=False)
        plt.subplots_adjust(hspace=.7)
        catplot.fig.suptitle('Subjectivity Disbribution by Topic', y=1.05)
        catplot.set_xticklabels(rotation=65, horizontalalignment='right')

# %%
tw = 3 #tweets to print per sentiment
for s in full_data.subjectivity.unique():
    print('Subjectivity| {}-----------'.format(s))
    for t in full_data.topic_title.unique():
        print('Topic | {}-----'.format(t))
        for sent in full_data.tb_sent.unique():
            print('Sentiment| {}-------\n'.format(sent))
            print('Tweet with --> Topic | Subjectivity | Sentiment')
            print('Tweets with --> {} | {} | {} \n'.format(t,s,sent))
            for i,x in enumerate(full_data[(full_data.topic_title==t)&(full_data.subjectivity==s)&(full_data.tb_sent==sent)].sample(tw).full_text):
                print('Tweet {} of {}--> '.format(i+1,tw),x,)
            print('++++++'*5,'\n\n')
    print('----'*5,'\n\n')
# Out:
# Subjectivity| high-----------
# Topic | Opinion-----
# Sentiment| pos-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Opinion | high | pos
#
# Tweet 1 of 3-->  A magnificent article by ⁦@zeynep⁩ on ⁦@TheAtlantic⁩. Full of lessons from mistakes made over the last year &amp; full of hope for the future ahead.
# Essential reading for this weekend to finally start conceiving a post #Covid life😁 #COVID19 @IFRC https://t.co/pJb6Z4uJOn
# Tweet 2 of 3-->  @bakerstherald @DrEricDing Moderna’s Phase 1 testing cannot happen fast enough. It’s new news to me that the virus in CA is their own creation. Yikes.
# Tweet 3 of 3-->  Vaccination in Israel: Challenging mortality figures? https://t.co/8ydlo2YGB0
#
# "They claim that Pfizer's shot causes "mortality hundreds of times greater in young people compared to mortality from coronavirus without the vaccine"
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neu-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Opinion | high | neu
#
# Tweet 1 of 3-->  #antivax i see the #antivaxxers have climbed out of the rabbit hole and released a new recruitment cult video https://t.co/WMsuigVWG1
# Tweet 2 of 3-->  Pfizer dose #1. And no implant! Ok, the implant told me to say that. #vaccine #COVID19Vaccine #vaccinated https://t.co/6GiwutBnOu
# Tweet 3 of 3-->  @DangerGirl6 @GovCanHealth Wait for the J and J live virus traditional vaccine don't be a lab rat for experimental mrna gene tharapies
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neg-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Opinion | high | neg
#
# Tweet 1 of 3-->  Covid-19 Shopping Makes Card Fees a Bigger Burden for Merchants - WSJ https://t.co/O4EmoJE0ft
# Tweet 2 of 3-->  The national debt was already a problem
#
# Unfortunately the pandemic has forced an increase in federal spending
#
# But if we have to borrow another $1.9 trillion,at least spend it on things related to #Covid19 not a list of longtime pre-COVID liberal demands
# Tweet 3 of 3-->  @SJonNantucket The J&amp;J vaccine is produced much like flu vaccine and it takes a long time to grow enough virus for a huge supply. This is why flu vaccine production must be started months before the start of a flu season.
# ++++++++++++++++++++++++++++++
#
#
# Topic | Vaccine Updates-----
# Sentiment| pos-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Vaccine Updates | high | pos
#
# Tweet 1 of 3-->  Florida has vaccinated millions of seniors representing over 50% of our senior population. Counties with noteworthy coverage of seniors include:
#
# St. Johns - 78% (of seniors vaccinated)
# Leon - 73%
# Nassau - 71 %
# Alachua - 67%
# Indian River - 67%
#
# Great job!
# Tweet 2 of 3-->  @FireFly53647402 @sureshseshadri1 @nair_hena @arvindnayak1 @sbk1963 @INSANATAN @umeshctyagi @NationmyFamily @ResurgentIndia @sharma_jyo @swetamishraa @surewrap @keshda @macharajarao @Am_dilip1 @Drsunandambal @GenPanwar @shytigress @keeranl @Gurdeep15087618 @Chouhan_ks @Anju1951Purohit @Bharatwashi1 @jitin_bhalla @KEYESEN2000 @roshovani @RohitSi09082662 @Satishrathod100 @kailashkaushik8 @BachaoIndiako @prasad_perla @paperrose2k @WishMaster2019 @jtiku @KishorTrivedi7 @nutan_jyot @Savitritvs India is not only #AtmaNirbharBharat, it helps other countries help fight #Covid_19. 👍👏👏👏👏👏
#
# #Brazil's health ministry signed a deal with India's #BharatBiotech to purchase 20 million doses of #Covaxin, a #coronavirus vaccine
#
# https://t.co/1QktiCxaOD
# Tweet 3 of 3-->  Covid-19 Live Updates: Single Pfizer Dose Strongly Protects Those Who’ve Had the Virus, Studies Find https://t.co/64mE9AVgrb
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neu-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Vaccine Updates | high | neu
#
# Tweet 1 of 3-->  #CoronavirusPandemic The vaccine supply is steadily *increasing* in #DouglasCounty, Here's the latest update from #healthofficials.
#
# #COVIDVaccines #VaccineRollout #Moderna #Pfizer #johnsonandjohnson #Vaccines #coronavirus #COVID19 https://t.co/OurDiTf75f
# Tweet 2 of 3-->  INOVIO ALSO ADVANCING WORK TO TEST POTENTIAL USAGE OF COVID-19 VACCINE CANDIDATE AS A SEASONAL BOOSTER: CONF CALL #News #Forex #COVID19 #VACCINE
# Tweet 3 of 3-->  USA TODAY: Moderna to begin trial of new COVID vaccine to address virus variant
#
# https://t.co/nrcwSQVFRN
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neg-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Vaccine Updates | high | neg
#
# Tweet 1 of 3-->  @TheBernician Isn’t the number of vax deaths going to exceed / have exceeded the genuine COVID fatalities? Only 344 under 65 with no illnesses died of COVID last year!
# Tweet 2 of 3-->  Virus update: A mass test of Pfizer’s COVID-19 vaccine in more than half a million people confirms that it’s very effective at preventing serious illness or death, even after one dose. Here's the latest. https://t.co/oySFUQPRoo
# Tweet 3 of 3-->  As Ohio starts into Phase 1C of the vaccine distribution, I came across this little item:
#
# "We are no longer receiving vaccine shipments for persons in phase 1A. We will no longer be able to offer vaccination for persons in phase 1A."
# ++++++++++++++++++++++++++++++
#
#
# Topic | Coronavirus Updates-----
# Sentiment| pos-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Coronavirus Updates | high | pos
#
# Tweet 1 of 3-->  #Corona Info for #USA:
# New Cases: 48095
# Today Recovery: 59107
# Today Deaths: 1562
# Total Active Cases: 9145625
# Total Cases: 28947419
# Total Recovery: 19285199
# Total Deaths: 516595
# #Coronavirus  #Covid19 #Covid_19 #SARSCoV2 #StaySafe
#
# Source: 'CoronaTrackerNepal_bot' #Telegram.
# Tweet 2 of 3-->  Virus update: Days after marking a solemn milestone in the pandemic, President Joe Biden is celebrating the pace of his efforts to end it. Plus, more Americans will soon be eligible for unemployment benefits. https://t.co/8MoaHqVDHx
# Tweet 3 of 3-->  Virus update: Days after marking a solemn milestone in the pandemic, President Joe Biden is celebrating the pace of his efforts to end it. Plus, more Americans will soon be eligible for unemployment benefits. https://t.co/fE4DwDNl22
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neu-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Coronavirus Updates | high | neu
#
# Tweet 1 of 3-->  399 new cases of COVID-19 confirmed in Alberta on Thursday
# #Health #News #AlbertaCoronavirus #AlbertaCoronavirusNumbers #AlbertaCoronavirusUpdate #AlbertaCovid-19 #AlbertaCovid-19Numbers #AlbertaCovid-19Update #AlbertaHealth #Coronavirus #Covid-19
# https://t.co/1ItMMbOOOZ
# Tweet 2 of 3-->  #Trump2024 DM for full list of $100 domains #domain #domainnames #domainname #covid #corona #coronavirus #covid19 #vaccination #vaccine #variant #politics #btc #bitcoin #crypto #forsale #doge #eth #xrp #fda #hhs #sedo #website #seo #business #website #pfizer #astrazeneca #moderna
# Tweet 3 of 3-->  Day 338 of 92 or 184 or 363 or 455 #June21st #coronavirus #shambles  #abandoned #damaging #Unbelievable #lackofdirection #totalchaos #madnessawaits #uturns #wearedoomed #COVID19 #120kdeathsDay https://t.co/iE1MUulvQf
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neg-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Coronavirus Updates | high | neg
#
# Tweet 1 of 3-->  @celliottability NEW STATS from VAERS - 2-18-21
# 1,095 reported deaths
# 19,907 reported adverse events
# 755 life threatening AEs
#
# https://t.co/54RJXgT04L
# Tweet 2 of 3-->  Cases: 113,365,595 (+84,259)
# Deaths: 2,515,627 (+1,681)
# Recovered: 63,912,233 (+10,838)
# Active Cases: 49,453,362 (43.62%)
# Completed Cases: 66,427,860 (58.60%)
# Mortality Rate: 2.22% (No Change)
# Case Fatality Rate: 3.79% (No Change)
#
# #COVID19 #Coronavirus #StayHome
# Tweet 3 of 3-->  America's wealthy are getting vaccinated faster than the poor, and a poorly designed system is partly to blame  https://t.co/6XfFiFUHx9
# ++++++++++++++++++++++++++++++
#
#
# Topic | Other-----
# Sentiment| pos-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Other | high | pos
#
# Tweet 1 of 3-->  ANTIFA #Covid_19 #coronavirus Nancy BLM Proud Boys Capitol QAnon Mitch McConnell Hawley Haley @mtgreenee @RepBoebert Texas Greg Abbott Ted Cruz Texas AOC @GovAbbott Don Jr. USPS Barr Johnson &amp; Johnson  Moderna Marjorie LGBTQ Nazi Göring, Goebbels Hitler Nazi SS CNN CPAC Acosta # https://t.co/qXuBahx8O8
# Tweet 2 of 3-->  y’all better give me 7k like
#
# /j /j /j https://t.co/mMA2ke6ATF
# Tweet 3 of 3-->  well that was definitely a song! /j /lh
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neu-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Other | high | neu
#
# Tweet 1 of 3-->  BIG DAY at Del Monte. 🙂
# #Vaxxed #Vaccinated #fullyvaxed #seniorlife #bigsmiles #happy #care #love #GoldenYears #compassionatecare #assistedliving #seniorcare #seniorliving #memorycare  #elderlycare #healthcare #alzheimers #retirementgoals #Monterey #montereycounty #pacificgrove https://t.co/mr3bPgkG2E
# Tweet 2 of 3-->  @LeaderMcConnell All I am concerned about right now is why I have not been vaccinated against the Coronavirus in Alabama. PASS Biden's stimulus, quit bickering, compromise and get 'er done!
# Tweet 3 of 3-->  @ChrisCuomo All I am concerned about right now is why I have not been vaccinated against the Coronavirus in Alabama. PASS Biden's stimulus, quit bickering, compromise and get 'er done!
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neg-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Other | high | neg
#
# Tweet 1 of 3-->  @Weinbergrrrrr @DKThomp A freakishly unexpected graph:
#
# ^ @dfreelon
# "Black vax hesitancy makes headlines, but the most reluctant group by far is white Republicans--a much larger group." https://t.co/1bDCtakC26 https://t.co/TS6GkPdKS3
# Tweet 2 of 3-->  @emmakennytv Government website on adverse reactions. Download 3rd and 4th report for Pfizer jab and AZ jab. Makes for Grim reading. Hundreds have died and 50+ pages of injuries for each type of jab Inc. strokes, heart attacks, blindness etc. Pregnancy grim reading.
#
# https://t.co/ViSarYn23f
# Tweet 3 of 3-->  #Municipalities with high risk due to the #Covid19 #Pandemic in #Sonora 🇲🇽
#
# #Municipios con alto riesgo por la #pandemia #Covid19 en Sonora 🇲🇽
#
# #Cajeme
# #Empalme
# #Guaymas
# #Huatabampo
# #Navojoa
# #PuertoPenasco
#
# @ClaudiaPAVLOVIC @HLGatell @GobiernoSonora https://t.co/rmk2kKD74S
# ++++++++++++++++++++++++++++++
#
#
# Topic | Wellness-----
# Sentiment| pos-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Wellness | high | pos
#
# Tweet 1 of 3-->  Snacking on pistachios can help to keep your blood sugar steady which is key in weight management
# #80aDay #FitnessMotivation #healthylifestyle #Corona #COVID19 #COVIDVaccine #Motivation
#
# https://t.co/U10cw3MgTR https://t.co/OGE5zmZggw
# Tweet 2 of 3-->  CurQfen®: A 100% natural and clean label curcumin for brain health...
#
# https://t.co/3a0BxTew4D
#
# #turmeric #curcumin #curqfen #brainhealth #bioavailablecurcumin #greenformulation #fenugreek #fenumat #functionalfood #immunity #nutraceuticalingredient #cognitivehealth https://t.co/i98gocNVrA
# Tweet 3 of 3-->  @YakultIndia Total 17 yakult bottle spotted on the image 👇
#  #FindForFun #contest
# #YakultIndia #Probiotics #Immunity #ContestIndia
# Join guys ♥️
# @SaiShruti8
# @0SATYAJIT0 @hazari_neelam @Im_karan22 @SubhamK82455097 @SubhamS98776800 @Subha77918966 @KabitaN56812582 @kaisha911 @cuty_mamalin https://t.co/1DUpTwXWhQ
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neu-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Wellness | high | neu
#
# Tweet 1 of 3-->  @YakultIndia Found all the differences and have marked them #FindForFun #YakultIndia #Probiotics #Immunity #Contest #ContestIndia @YakultIndia https://t.co/cuBtpwAiEv
# Tweet 2 of 3-->  New premium face masks for adults and kids.
# #covidvirus #covid #virus #germs #cutegerms #facemask #health #facemasks
# #zazzle #giftideas #gifts #childsfacemasks #adultfacemasks
#
# https://t.co/Kpj3oxdzpK
# Tweet 3 of 3-->  You can read more about Brussels sprouts:
# https://t.co/rAX686IuFC
#
# #healing #nutrition #foodie #cleaneating #weightloss #immunity #digestion #health #antiinflammatory #anticancer #metabolism #health_benefit #herbalist #herbs_encyclopedia #ESTEPS #herbs #app https://t.co/NgafnaYdpV
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neg-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Wellness | high | neg
#
# Tweet 1 of 3-->  Confusion and frustration have marked New York's vaccination rollout. Here's the latest on who's eligible and how to make an appointment. https://t.co/3eMQ6pUAtg
# Tweet 2 of 3-->  Confusion and frustration have marked New York's vaccination rollout. Here's the latest on who's eligible and how to make an appointment. https://t.co/wtovsuR9lu
# Tweet 3 of 3-->  The number of Somalis dying of COVID 19 has risen sharply in the country, especially among the elderly. Notable people who have died this month include:
# Sheikh Nur Barood Gurhan.
# Ugas Mohamed Wali.
# fafuma NAKRUMA and tonight UGAAS KHALIF UGAAS ROOBLE dies.
# @COVID19 2021
# @MOH
# ++++++++++++++++++++++++++++++
#
#
# --------------------
#
#
# Subjectivity| med-----------
# Topic | Opinion-----
# Sentiment| pos-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Opinion | med | pos
#
# Tweet 1 of 3-->  Looks like @SonaNanotech is ready to drop a training video for their saliva test. Incoming game changer! Anyone got the password?😉
#
# https://t.co/VoMBt7RNBE
#
# $SONA $SNANF #COVID19 #stocks #StocksToBuy #StockMarket #money #investing #business #Finance #reddit #wallstreetbets #news
# Tweet 2 of 3-->  As an #epidemiologist &amp; #PublicHealth professional keep your social circles only among those who live in your home with you &amp; #Virtually with others - also practice #Covid19 safety measures until everyone is #vaccinated - if not we increase the opportunit…https://t.co/iroZeeWHSX
# Tweet 3 of 3-->  I got my first dose of Pfizer’s COVID-19 vaccine today. Thank you @POTUS . I believe this would not have happened without you. 🙏🏻
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neu-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Opinion | med | neu
# Tweet 1 of 3-->  @Mitumba10 Really?
#
# I'd rather believe this retired Chief Scientist from Pfizer.
#
# https://t.co/oltDDwBxZY
# Tweet 2 of 3-->  @GeorgeTakei It seems that one way or another the GOP is going down.  "A full 49 percent of Republicans now say they won’t get vaccinated"  #SplitGOP
# https://t.co/qdseRjomrR
# Tweet 3 of 3-->  @pecan39 @elliehughesci @ToryFibs I don’t think Ellie said that at all Paul, her comments are very specifically around the rollout of the vaccine. We are not talking about the handling of the pandemic as a whole.
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neg-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Opinion | med | neg
#
# Tweet 1 of 3-->  @POTUS @JustinTrudeau My mom is 90 and I am 66 we have just been ignored about getting the corona vaccine we live in 1661 Old Country Road lot 94 Riverhead NY 11901 I have been trying to get one and it always says no appointments available we have just been forgotten here.   Pamela and Hannah
# Tweet 2 of 3-->  Pharma executives are using the pandemic to line their pockets. To the tune of half a billion dollars. While millions of Americans are struggling to stay healthy and pay their bills.
#
# Just letting that sink in. https://t.co/cpXvdBiX6L
# Tweet 3 of 3-->  How is my daughter supposed to continue her nursing program? Where do I find the money to rent a separate place for her? She will loose a year or I have to live in the basement isolated! @JustinTrudeau @fordnation #fail #vaccine #COVID19 https://t.co/eSYyIZPJu0
# ++++++++++++++++++++++++++++++
#
#
# Topic | Vaccine Updates-----
# Sentiment| pos-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Vaccine Updates | med | pos
#
# Tweet 1 of 3-->  TODAY MY SISTER AND I GOT OUR FIRST DOSE OF THE 🤯PFIZER VACCINE🤯
#
# I AM OVERWHELMED WITH JOY AS WELL AS BEYOND GRATEFUL TO BE ALIVE TODAY TO GET THE VACCINE. CAN’T WAIT FOR MY SECOND DOSE!!!  #vaccine #covid #pandemic #getvacinated #pfizer https://t.co/am1BKs0CYL
# Tweet 2 of 3-->  Paul Koh says got a list of 10K Wake County school employees who said they'd be interested in being vaccinated for COVID-19. Multiple vaccination events for school employees have been held. #wcpss #nced #coronavirus
# Tweet 3 of 3-->  #Bangladesh has administered at least 2.08 million doses. As per the number of people who received at least one dose of #Covid19 #vaccine, as of February 20, holds 11th position in the global vaccination race
# #Vaccinated #VaccineCovid19
# #ThankYouPM
# https://t.co/T9pua3VxYV https://t.co/VwDJd8d6U8
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neu-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Vaccine Updates | med | neu
#
# Tweet 1 of 3-->  RT @Gray_Mackenzie: Some updated vaccine targets from Maj-Gen Fortin #cdnpoli
#
# For Pfizer, we’ll get 769 k per week in the first two week…
# Tweet 2 of 3-->  Its official vaccine 1 and 2 are complete #COVID19Vaccine #vaccinated
# Tweet 3 of 3-->  #Ethiopia: Overall #Covid19 trends
#
# "As of early 2021, trends in the #Covid19 pandemic’s spread in Ethiopia show new reported cases at roughly 600 per day or roughly one-third of their August 2020 peak of 1,800 new cases per day."
# #FlattenTheCurve
# https://t.co/OB9fWFiixh https://t.co/Y07trwouSI
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neg-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Vaccine Updates | med | neg
#
# Tweet 1 of 3-->  The FDA has authorized a third COVID-19 vaccine for emergency use, this one made by Johnson &amp; Johnson (J&amp;J). Swipe through for five reasons to be excited about this development!
#
# Read more: https://t.co/a7gsvQOvzq https://t.co/SstR1tAJor
# Tweet 2 of 3-->  Updated adverse reaction data for COVID-19 MRNA VACCINE PFIZER-BIONTECH (TOZINAMERAN)
# "The number of individual cases identified in EudraVigilance for TOZINAMERAN is 71,060 (up to 23/02/2021)"
# Tweet 3 of 3-->  Union Health Ministry has released a list of 20 illnesses that will be considered as co-morbidities. They have also released the certificate people between this age group needs to get signed by a registered medical practitioner. Read more here. #COVID19
# https://t.co/W0Q0lVsrDP
# ++++++++++++++++++++++++++++++
#
#
# Topic | Coronavirus Updates-----
# Sentiment| pos-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Coronavirus Updates | med | pos
#
# Tweet 1 of 3-->  CHEVROLET CAMARO 2015 UPGRADED TO 2019
# WITH ORIGINAL CUSTOM DUTY
# CONDITION: FOREIGN USED
# Location: Abuja
# CALL 📞: 08033213995 @AbadCars
# #abadcars #forsale #abuja #kano #kaduna #lagos
# #stayathome #staysafe #Corona #Coronavirus #covid #covid19 https://t.co/tSqeRAhjfE
# Tweet 2 of 3-->  TOYOTA CAMRY 2013
# WITH ORIGINAL CUSTOM DUTY
# CONDITION: FOREIGN USED
# Location: Abuja
# Price: 3.5m
# CALL 📞: 08033213995
# #abadcars #forsale #abuja #kano #kaduna #lagos
# #stayathome #staysafe #Corona #Coronavirus #covid #covid19 https://t.co/EY06HYP3Ht
# Tweet 3 of 3-->  #Lebanon 25 Feb 2021
# during the past 24 hours,
# day 43 of lockdown/curfew.
# • 19,681 PCR tests
# • 3,469 new cases of #corona
# • 52 deaths
# • 913 intensive care
# Number of new cases increasing!
# #stay_home
# #COVID19
# #COVID19_2021 https://t.co/SUw26FBL8F
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neu-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Coronavirus Updates | med | neu
#
# Tweet 1 of 3-->  Andaman Coronavirus Outbreak
#
# #AndamanUpdate
#
# •Spike of 0 cases reported today
# •0 discharged recently
# •Total count: 5020
# •Active cases: 06
# •Total recovered till date: 4952
# •Deaths: 62
#
# #COVID19
# #AndamanFightsCovid_19
# #IndiaFightsCorona
#
# andamanherald report
# Tweet 2 of 3-->  First group of 41 Korean travelers arrive in #Thailand under a "golf quarantine" program devised by the Thai government.
#
# #COVID #COVID19 #Golf #GolfCourse #GolfTrip #Quarantine #LuxuryTravel #LuxuryVacation #GolfVacation
# https://t.co/TKNsZbrOyb
# Tweet 3 of 3-->  COVID-19 vaccinations in the U.S.:
#
# Partially vaccinated:
# ▓▓░░░░░░░░░░░░░
# 15.28% (+0.40)
#
# Fully vaccinated:
# ▓░░░░░░░░░░░░░░
# 7.51% (+0.33)
# #COVID19 #Coronavirus
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neg-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Coronavirus Updates | med | neg
#
# Tweet 1 of 3-->  The new system, operated by Blue Shield, aims to streamline a confusing county-by-county patchwork of vaccination efforts. https://t.co/Rttl0VSiMQ
# Tweet 2 of 3-->  Watch a WWII bomb explode in England and leave behind a crater the size of a double-decker bus, the CDC discusses the rollout of a 3rd coronavirus vaccine, and more of today's top videos. https://t.co/Ev4PHoBxW3
# Tweet 3 of 3-->  The new system, operated by Blue Shield, aims to streamline a confusing county-by-county patchwork of vaccination efforts. https://t.co/FHMBTJzYoP
# ++++++++++++++++++++++++++++++
#
#
# Topic | Other-----
# Sentiment| pos-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Other | med | pos
#
# Tweet 1 of 3-->  https://t.co/woko0wlap7
#  Clear difference between mRNA vaccines&amp;DNA
# AstraZeneca&amp;J&amp;J Delivery.CudVaccineSelection
# BeImpt4ThoseWithGeneticAutoimmuneDiseases2
# PreventCauseHyperImmuneResponses?
# WhichSafest4GrowingChildren/Teens&amp;🤰🏻?
# #longhaulers
# #MeCFS #COVID19Vaccination #COVID19
# Tweet 2 of 3-->  The FDA authorized use of a Covid-19 vaccine from Johnson &amp; Johnson, the first requiring just a single dose. It is expected to give a big boost to vaccination efforts. https://t.co/Ysw5gMtji1
# Tweet 3 of 3-->  @CDCgov 🚨 #COVID19 #CORONAVIRUS
#
# ➡️ Help Save Lives:
#
# 😷  Wear a Mask
# ✔️  Social Distance
# ✔️  Wash Your Hands
# ✔️  Avoid Large Gatherings
# ➡️  Get Your Vaccination
#
# ⚕️ @WHCOVIDResponse
# ⚕️ @CDCDirector
# ⚕️ @CDCgov
# ⚕️ @HHSGov
#
# 🇺🇸 @POTUS Biden
# 🇺🇸 @VP Harris
# 🇺🇸 @SenateDems
# 🇺🇸 @HouseDemocrats https://t.co/e9EC5FnOco
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neu-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Other | med | neu
#
# Tweet 1 of 3-->  New York City doled out 62,000 doses in a day while the state as a whole did 179,000 shots — both were records. https://t.co/Qer1cWe6TJ
# Tweet 2 of 3-->  @AlexBerenson @powellnyt Hey @jack @TwitterSupport @TwitterSafety you claim that you are taking down #vaccine #disinformation accounts.
#
# Why are https://t.co/T2mbqKIQwY and https://t.co/fXzUC9x9Lw still allowed to spread #antivax disinformation?
#
# #TobyRogers #AlexBerenson
# Tweet 3 of 3-->  @BharatBiotech developed indigenous #COVID19 #vaccine #COVAXIN is a highly purified, whole virion, inactivated #SARSCoV2
#
# It contains chemisorbed TLR7/8 agonist onto Al(OH)3 gel
#
#  CISR lab-@csiriict developed the synthetic route for the agonist molecule
#
# https://t.co/X7rwwrj92S https://t.co/kR2otHtChp
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neg-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Other | med | neg
#
# Tweet 1 of 3-->  US health officials warn against reopening too quickly as virus variants spread. “We stand to completely lose the hard-earned ground that we have gained,” said Dr. Rochelle Walensky, head of the CDC. https://t.co/Kiz46L337d
# Tweet 2 of 3-->  @fordnation Over 1,000 dead after vax now...? CDC's website and follow the steps below:https://t.co/TkBzFNwAqL
# 1) Accept disclaimers
# 2) Click on "VAERS Data Search"
# 3) Group results by "Event Category"
# 4) Select "COVID 19 VACCINE" and press "Open"
# 5) Choose "All Locations"
# 6) Press "Send" ✅
# Tweet 3 of 3-->  US health officials warn against reopening too quickly as virus variants spread. “We stand to completely lose the hard-earned ground that we have gained,” said Dr. Rochelle Walensky, head of the CDC. https://t.co/eG1Ry8W1Q1
# ++++++++++++++++++++++++++++++
#
#
# Topic | Wellness-----
# Sentiment| pos-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Wellness | med | pos
#
# Tweet 1 of 3-->  Boost up yourself. @Greenbrrew #greencoffee
# .
# .
# Order Now @amazonIN https://t.co/f5onoMXmmW
#
# #weightloss #instagood #coffee #Coffeelovers #coffeeaddict #natural #health #healthylife #Life #Lifestyle #coffeetalk #Coffeebreak #healthyliving #instacoffee #energy #booster #Immunity https://t.co/44wKY4FfgC
# Tweet 2 of 3-->  Healthy Belly Complete Superfood contains 30 superfoods AND 17 additional ingredients to reduce inflammation, support digestive health and immunity, and improve mood.
#
# #Energy #Mood #Immunity https://t.co/VNiIjuFuie https://t.co/eBjnROVJaK
# Tweet 3 of 3-->  Starting your day with a glass of Luke warm water does wonders to your health, try it today!
#
# .
# .
# .
#
# #supplement #immunity #immunitybooster #Pharmearth #pharmearthonline #pharmearthapp  #Healthy #medicinesonlineindia  #Healthtip #healthyeating #fitnessmotivation #fitnessjourney https://t.co/u41c95LLdS
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neu-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Wellness | med | neu
#
# Tweet 1 of 3-->  Moderna to begin trial of new COVID vaccine to address virus variant first found in South Africa  https://t.co/ecZc2Y5xxk
# Tweet 2 of 3-->  RT @AirFairy04: PM2.5 #AirPollution  Tues 2 Mar 8.52am  #Lockdown
# #LocalAQMonitoring real time #PurpleAir
# #Health #COVID19 https://t.co/…
# Tweet 3 of 3-->  We at @Goldentigerlife are on a mission to make #Immunity #Vitality #DailyRecovery accessible to everyone by integrating the 5,000 year-old practices of #Ayurveda into #Modernlife @PGA @GolfChannel @TGRFound @TMZ_Sports @WalmartCEO @WholeFoods @jacknicklaus @fredcouplesgolf @LPGA https://t.co/PxxNelbT99
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neg-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Wellness | med | neg
#
# Tweet 1 of 3-->  Having trouble falling asleep at night? Stop scrolling your phone in bed.
# .
# .
# .
# #NutraV #naturallybetter #vitaminV #LiveNutraV #natural #glutenfree #plantbased #antiaging #allnatural #guthealth #nutrients #immunity #wellness https://t.co/DlERtTtYvV
# Tweet 2 of 3-->  This one aged horribly due to #longcorona
#
# #covid #corona #begov https://t.co/oxO8dg8E5A
# Tweet 3 of 3-->  Eat defensively!
# #diet #nutrition #health #healthy #healthcare #foodie #food #FoodForThought #Democide #Medical #BigPharma #poison #GMO #Cancer https://t.co/ADgeO2aMUx
# ++++++++++++++++++++++++++++++
#
#
# --------------------
#
#
# Subjectivity| low-----------
# Topic | Opinion-----
# Sentiment| pos-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Opinion | low | pos
#
# Tweet 1 of 3-->  RT @MichaelDuku3: ...its no longer an imported disease but a community infection. Media has a role to play to deliver the correct informati…
# Tweet 2 of 3-->  Lowering Drug Prices Protects Patients and Profits https://t.co/LGCJFSDFac #drugprices #BigPharma
# Tweet 3 of 3-->  I stapled up this Studs Terkel quote a year ago, when I was feeling so grateful that Covid was happening at the same time as spring was popping. Proof that life persists. https://t.co/uxIp2heOM7
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neu-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Opinion | low | neu
#
# Tweet 1 of 3-->  CDC study: Teacher interaction, indoor sports fueled COVID-19 spread in Marietta schools https://t.co/BAEGuZYvMC
# Tweet 2 of 3-->  If it weren't for double standards, the left wouldn't have any standards at all.
#
# #FireFauci
# Tweet 3 of 3-->  The pandemic is over here but, of course, that doesn't matter. https://t.co/JsvrHrgpuy
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neg-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Opinion | low | neg
#
# Tweet 1 of 3-->  @BuranGeoff @JamesJamesw440 @POTUS I have, I'm an R.N. I have seen up close what this virus can do. You guys need to shut up and take the damn vaccine.
# Tweet 2 of 3-->  No Evidence of Coronavirus Transmission From Food or Food Packaging @FDAMedia https://t.co/TVsEfcj4rd #coronavirus #COVID19
# Tweet 3 of 3-->  RT @gerdosi: @obradam @GirardotMarc @AnnaBis37268098 @FatEmperor The burden of proof is on those who suggest that one NEEDS any vaccine at…
# ++++++++++++++++++++++++++++++
#
#
# Topic | Vaccine Updates-----
# Sentiment| pos-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Vaccine Updates | low | pos
#
# Tweet 1 of 3-->  BREAKING: CDC panel recommends use of J&amp;J’s single-shot Covid vaccine, clearing way for distribution
# https://t.co/Pg5yNzRP4o
# Tweet 2 of 3-->  Best news of the week:
#
# Bubbe Mindy in Massachusetts got her second dose of the coronavirus #vaccine.
#
# Can’t wait to see her and for my turn in line to get the shot(s).
#
# Keep wearing a 😷 and together let’s put an end to this pandemic. https://t.co/09prqpFN5Z
# Tweet 3 of 3-->  Do you know someone who may need help registering? Lend your skills and help someone register today!  Make appointments at https://t.co/L2pfIuJRrd  Pfizer vaccines are administered by Walmart pharmacy  @indplsul 777 Indiana Avenue https://t.co/SnWzjF5ttF
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neu-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Vaccine Updates | low | neu
# Tweet 1 of 3-->  Watch #HealthShow: Corona &amp; Vaccination  @dd_odia on 27.02.2021 (Saturday) at 5.30 PM. https://t.co/AX3qwFfawH
# Tweet 2 of 3-->  MPs Will Be Vaccinated Against Corona Before The Parliamentary Session https://t.co/HsPJoc3PZe
# Tweet 3 of 3-->  Register name at Co-WIN portal to get corona vaccine #CollectorCNarayanaReddy #CoronaVaccine https://t.co/aSlec8FZ8Y
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neg-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Vaccine Updates | low | neg
#
# Tweet 1 of 3-->  Tonight! Join us for a virtual panel discussion, "Systemic Racism and COVID-19," with presenters from @ncdhhs @Together4Youth @DukeMedSchool and GeriaRx, Inc.
#
# Feb 23, 5:30 PM EST!
#
# Zoom link: https://t.co/KJFvYbt79Z https://t.co/IUHYowRFCT
# Tweet 2 of 3-->  #Iran: #Coronavirus Death Toll in 486 Cities Exceeds 219,700 Health Ministry: Given the circulation of the mutated #COVID19 in Khuzestan and several other provinces, this trend’s continuation will be catastrophic in the country.
# https://t.co/30smkOypGu
# Tweet 3 of 3-->  Into Jerusalem public transport stops for shushan purim. #Jerusalem #Israel #covid19 #corona #coronavirus #purim https://t.co/NiRDSow7gA
# ++++++++++++++++++++++++++++++
#
#
# Topic | Coronavirus Updates-----
# Sentiment| pos-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Coronavirus Updates | low | pos
#
# Tweet 1 of 3-->  @OmarAlghabra
#  Please keep your word!!
#
# #saveCanadianAviation #aviationnews #cabincrew #Airlines #travel #rapidtesting #travelban #COVID19 #COVID19AB #CovidVaccine #Pfizer #Moderna  #AstraZeneca #TrudeauActNow #TrudeauMustGo https://t.co/c43k0BxYxP
# Tweet 2 of 3-->  The growing evidence that the Covid-19 vaccines can reduce transmission, explained https://t.co/Q0tWFBoDEt via @voxdotcom
# Tweet 3 of 3-->  Pfizer-BioNTech Shot Could Help End Pandemic, Israel Study Shows - Bloomberg
# https://t.co/VVkTLIJqsX
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neu-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Coronavirus Updates | low | neu
#
# Tweet 1 of 3-->  @256107504 @JC1053 Jeff does have Surtain above Farley
# Tweet 2 of 3-->  So this happened today.  #vaccinated #part1  #doingmypart  #allinthistogether https://t.co/sQIWc78N9w
# Tweet 3 of 3-->  I am Vaccinated. This one is for those who already took Corona Virus Vaccine. Link below.
#
# https://t.co/vY03IaAomR…
#
# #dpcm
# #usbuysdaechwita
# #masumlarapartmanı
# #tshirtdesigns
# #redbubble
# #teespring https://t.co/kjfkPQQQ2U
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neg-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Coronavirus Updates | low | neg
#
# Tweet 1 of 3-->  #COVID19 can’t stop the #gospel or #missionaries being sent out! #missions #disciplemakingmovements #YouAreSent https://t.co/fr0ql76Z4r
# Tweet 2 of 3-->  Lower than vermin, @BBCNews @BBCNewsnight @BBCPolitics @BBCr4today @BBCWorldatOne @BBCPM @Channel4News #QED #ToryScum #bbcaq #ToryCovidCatastrophe #COVID19 #murderers #LabourLeaks #LabourLeadershipElection2021 #FordeReport #LabourScum #Fascist #ApartheidIsrael  #StarmerOut https://t.co/mrIKMoifTA
# Tweet 3 of 3-->  #Iran:#Coronavirus Death Toll&gt;222,500
# #Covid19,https://t.co/UPk0u9PsrW .@rki_de.@Daily_Express.@NRO.@I24News.@nytimes.@euronews.@Telegraph.@BBCWorld.@ntvde.@FoxNews.@LMdiplo.#Iranian.@USABehFarsi.@AlArabiya_Fa.@VOAIran.@dw_persian.@SR_Farsi_Dari.@RFI_Fa.@SundayExpres.@ArabNews
# ++++++++++++++++++++++++++++++
#
#
# Topic | Other-----
# Sentiment| pos-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Other | low | pos
#
# Tweet 1 of 3-->  ‘Held to ransom’: Pfizer plays hardball in Covid-19 vaccine negotiations with Latin American... https://t.co/xQ19C4vX1d via @statnews
# Tweet 2 of 3-->  Go like and follow the gaming page. https://t.co/KzGzGk7QTc #gamer #COVID19 #SupportSmallStreamers #SnowfallFX #WandaVision #Crypto #WeAreProudOfYouSana #SmallStreamersConnect #thursdayvibes #INDvENG #العيد_الوطني_الكويتي #gamer #smallstreamer #CallofDuty #CallofDuty
# Tweet 3 of 3-->  @Covid19_VAX Thank you piku
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neu-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Other | low | neu
#
# Tweet 1 of 3-->  @JuliaHB1 BRAKING NEWS “On 30thJan2021 German Corona Extra-Parliamentary Inquiry Committee interviewed Dr. Vanessa Schmidt-Kruger, a Cell Biologist with 20 years’ experience molecular medicine working at Max Delbrück Center ” explosive vax info
# https://t.co/x2pvheuAd6…
# Tweet 2 of 3-->  #dogearmy #DogecoinRise #DogLover #TheView #FallGuysSeason4 #stocks #FireFauci #tuesdayvibe #StockMarket  #Booking #ROSÉ #LarryStylinson onlyfans belle delphine 18+ #rosmello #gregorelli #prelemi #gfvip #tzvip #bts #sovip #BTC #Dogecoins https://t.co/6vl0wY5uhQ
# Tweet 3 of 3-->  @tomarhatchway The gc I'm not a part of 🤭
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neg-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Other | low | neg
#
# Tweet 1 of 3-->  #Coronavirus CREATORS are milking Governments through vaccines for strains, 2nd wave variants and now a 3rd wave variant vaccine is LOADING.
#
# Khona kushaya manzi la....
# 🤐🤐🤐🤐🤐🤐🤐🤐🤐🤐🤐🤐 https://t.co/ilt9Nnprha
# Tweet 2 of 3-->  Imagine the virus is an antelope &amp; we're lions. And in a bush is a meerkat. The meerkat's curiosity is Pfizer &amp; his wife the arm of a sceptic, but not her thigh. Now imagine we take that thigh &amp; give it to the antelope, but not the lion.....
#
# #DowningStreetBriefing #DailyBriefing
# Tweet 3 of 3-->  They will not take it, but mandate it for you. Know thy enemy. #vaccine #antivax #medicalfascism #DontTakeTheJab #CalculatedRisk #Liberty #DNAchanging #MarkOfTheBeast #Depopulation https://t.co/Wvu1J71cBD
# ++++++++++++++++++++++++++++++
#
#
# Topic | Wellness-----
# Sentiment| pos-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Wellness | low | pos
#
# Tweet 1 of 3-->  Want to expand your franchise by 50%? Here's some #MondayMotivation from @teriyakimad. #ProudPartner #BusinessGrowth https://t.co/YZOawYGlrA https://t.co/GsFOrK1Q9L
# Tweet 2 of 3-->  @YakultIndia found 7 bottles
#  #FindForFun #contest
# #YakultIndia #Probiotics #Immunity #ContestIndia
# @YakultIndia
#
# Join
# @RaikarRamya
# @AparnaA22141836
# @the_pride_grv https://t.co/1rwlr5ajRG
# Tweet 3 of 3-->  [ASAP] Aptamer Conjugated Gold Nanostar-Based Distance-Dependent Nanoparticle Surface Energy Transfer Spectroscopy for Ultrasensitive Detection and Inactivation of Corona Virus https://t.co/NdL4gabAGv #chemicalphysics https://t.co/xNc3QDfAcT
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neu-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Wellness | low | neu
#
# Tweet 1 of 3-->  @YakultIndia Here are the differences #FindForFun #YakultIndia #probiotics #Immunity @YakultIndia https://t.co/BOauwJvfbN
# Tweet 2 of 3-->  @YakultIndia Spotted
#
# #FindForFun #YakultIndia #Probiotics #Immunity #Contest #ContestIndia
# @YakultIndia
#
# @godsowntalk
# @Dayal_5
# @gurgaon_rangers
# @ShainaArora1
# @coolkishore59
# @Mr_YashG
# @KpParmar98
# @aakash_beast786
# @p_sinha123
# @sanjudhy
# @SrinathAkula369
# @Man1shRox
# @khushboo_khetan https://t.co/kOwZbtGMvd
# Tweet 3 of 3-->  Spotlight series @BoojaBooja @daylesfordfarm @MichelinGuideUK @AandH_Official @TeamGB @wholeearthfoods @TheVeganSociety #Neutrient @nibblesimply #GreenStar #immunity #organic #Protein #Snacks #socialmedia #Sports #supplements #truffles #vitaminD #vitaminK https://t.co/51ipIcXb3r
# ++++++++++++++++++++++++++++++
#
#
# Sentiment| neg-------
#
# Tweet with --> Topic | Subjectivity | Sentiment
# Tweets with --> Wellness | low | neg
#
# Tweet 1 of 3-->  COVID-denying, anti-vax doctor loses medical license via /r/worldnews https://t.co/2DXuBHSlhs
# Tweet 2 of 3-->  J Cole doesn’t miss https://t.co/877FzTG5u8
# Tweet 3 of 3-->  Use the power of food to reboot your metabolism and lose weight
# #Coke #FitnessMotivation #HealthyFaith #Corona #COVID19 #WednesdayMotivation
#
# https://t.co/U10cw3MgTR https://t.co/k9YusPLsaP
# ++++++++++++++++++++++++++++++
#
#
# --------------------

# %% [markdown]
# The subjectivity did a pretty good job of segmenting out low subjectivity comments, such as updates. The sentiment could be tweaked to improve the sentiment of the tweet due to sarcasm and negation. <br><br>
# Looking at this data, I believe the next step is to take all highly subject tweets, to filter out updates about coronavirus and vaccines and perform another topic modeling to find out what topics people are being subjective about. It may even produce better results to perform this modeling on all Highly Subjective AND Positive or Negative sentiments to see what topics people are most positive and/or negative about.

# %% [markdown]
# ### Take a look at defining positive/negative a different way
# By changing the cut offs for positive and negative sentiment

# %%
sent_df=full_data[full_data.columns[-13:]]

# %%
sent_df.head(2)
# Out:
#    neu_sentiment  pos_sentiment  compound_sentiment  neg_sent  neu_sent  \
# 0          0.676          0.210              0.6124     0.114     0.676
# 1          0.837          0.163              0.7041     0.000     0.837
#
#    pos_sent  compound_sent  tb_score   tb_subj tb_sent tb_sent_subj v_sent  \
# 0     0.210         0.6124  0.233333  0.766667     pos          pos    pos
# 1     0.163         0.7041  0.000000  0.500000     pos          neu    pos
#
#   subjectivity
# 0         high
# 1         high

# %% [markdown]
# Notes: There will require a lot more time digging into classifying what is 'positive' and what is 'negative'. I believe the subjectivity feature will be highly valuable in learning what regular folks feel.<br><br>
# Take a look below. I have printed 'positive' tweets, that are highly subjective. Though the majority are negative and sarcastic.

# %% [markdown]
# ### Positive

# %%
# using textblob subjectivity and positive sentiment sorted by vader compound sentiment
idxs=sent_df[(sent_df.tb_subj>.5)&(sent_df.tb_sent_subj=='pos')].sort_values(by='compound_sent',ascending=False).index.tolist()[:5]
[print(x,'\n----\n') for x in full_data.iloc[idxs].full_text.tolist()]
# Out:
# @ashlieatkinson Yes your that worried about your health you don’t mind wearing a mask but you don’t care about stuffing your face. Good luck getting an experimental vaccine. Good luck sweetheart. #NoVaccine
# ----
#
# Medicine has this bias where you can't do anything unless you're super super super super sure it's not bad. A pandemic requires bolder decision making. It's pretty clear to me, a layperson, that we should get first doses into as many people as possible first. https://t.co/yco6v7urwz
# ----
#
# @PFr1end @Nicole86201389 @endtimeslife As a Christian taking the vax is like having experimental plastic surgery done but in reverse. God's protect me from the virus by giving me an amazing immune system that can deal perfectly w/it. I will not be vaccinated! May my Lord Yeshua judge. In Him alone I trust. Luke 12:7🛐 https://t.co/KmoWW6idyW
# ----
#
# @joqween @ColorsOfTheWi13 DEAR TEXANS: Because you —
# are tough
# are fighters
# love freedom
# love life
# PLEASE CONTINUE TO —
# wear your mask
# wash your hands
# respect the distance
# get vaccinated ASAP
# Above all,
# BE LIBERATED FROM FEAR
# BE FREE FROM COVID-19
# HELP LIBERATE THE USA
# WEAR THE MASK
# ETC.
# ----
#
# the pandemic has got my chronic pain *really* bad lately but i am feeling really grateful bc i have a boyf who has googled ways to help ease it n takes care of me even when i insist he doesn’t bc i don’t want to be a bother/useless n idk i am j very thankful :) alhamdullilah
# ----
# [None, None, None, None, None]

# %% [markdown]
# The following are tweets with a slightly different filter. It's highly subject and highly positive according to textblob.<br><br>
#
# It's interesting that these speak to education of vaccines or the progress of tackling the pandemic

# %%
# using textblob subjectivity and positive sentiment sorted by textblob score
idxs=sent_df[(sent_df.tb_subj>.5)&(sent_df.tb_score>.5)].sort_values(by='tb_score',ascending=False).index.tolist()[:5]
[print(x,'\n----\n') for x in full_data.iloc[idxs].full_text.tolist()]
# Out:
# F YOU COVID! You've murdered relatives, friends, 500K in the USA. Hypocrisy to blame someone for no national policy, if I don't do my part. Excellent job by @alabamastateu for the vaccines. Dr. Joyce in control. #COVID19Vaccine #MyASU #pandemic #pfizer #RollUpSleeve https://t.co/aIZ1Vhieju
# ----
#
# Thank you @NSSD112 for taking care of your staff and getting us vaccinated against #COVID19 (TY to @Walgreens for your service this AM &amp; @DPS109 for providing the space)!! Grateful and proud to be a 112 staff member! #112leads #vaccine #vaccinated https://t.co/U2IFMRykCu
# ----
#
# @BorisJohnson @Young_Tories https://t.co/nWVQBhWY75
# whilst giving us #herdimmunity and 121,747 deaths + with #coronavirus #COVID19
# #priceless
# ----
#
# Happy Client!
# .
# .
# .
# #Eatfit247 #happyclient #healthylife #healthgoals #health #weightloss #diet #dietplans #skinandhair #immunity #cleaneating #goodhealth https://t.co/BoE1uA120w
# ----
#
# Happy Immunization Day!
#
# ✅
#
# #Immunity #immunization #COVID19Vaccine #COVID19Ontario #covid19  #vaccine #vaccination https://t.co/y93zv3xYxB
# ----
# [None, None, None, None, None]

# %% [markdown]
# The following are tweets were tweaked a bit further. It's highly subject and highly positive according to vader sentiment. It's the same as above, only ranked by vader sentiment compound score, cutoffs were the same.<br><br>
#
# There is a possibility that some of these are not referring to the pandemic, but were picked up originally for words like 'virus', not in the context of the covid-19 pandemic.<br><br>
# With that said - it's interesting that these focus on fun activities & family time/experiences despite or due to the pandemic.

# %%
# using textblob subjectivity and a different textblob positive sentiment cutoff sorted by vader compound sentiment
idxs=sent_df[(sent_df.tb_subj>.5)&(sent_df.tb_score>.5)].sort_values(by='compound_sent',ascending=False).index.tolist()[:5]
[print(x,'\n----\n') for x in full_data.iloc[idxs].full_text.tolist()]
# Out:
# Congrats to @ericbouck and @Robsaysthings for the launch of @HedgehogTrivia! I've been on many games -- great hosts, great questions, super fun and entertaining. Great way to facilitate team bonding!! https://t.co/pnGqseJo4X #WFH #COVID19 #teamfun
# ----
#
# @SunlitS_J  you’ve had some lovely videos from some lovely people today, I bet Jack is really happy that Captain Seb was there for him this morning. I’m proud of you both for bringing everyone together in this pandemic, &amp; for being a great friend. Thank you. 🤗🤗 for Jack.
# ----
#
# Happiest Birthday to our dork yet cool brave man! Thank you for being our happy virus. Thank you for sharing your talent to all of us. May you continue to shine like a star! Yejiapsa, mochi!💙
# Your Omega, J.
# @OFFICIALBTOB @LeeCS_BTOB
# #BORN_TO_BE_CHANGSUB
# https://t.co/CSeCqsg8ra
# ----
#
# 🍊Defense Boost Vitamin C Gummies are crafted with a delicious flavor and vital nutrients and antioxidants to help encourage optimal wellness and support your immune system.
#
# #Defenseboost #vitaminc #vitamingummies #immunity https://t.co/zRhg29oynM
# ----
#
# Feeling grateful for good things today. 🙏
#
# Got called off from #COVID unit early because the number of patients has significantly declined. YAY! 🙌
#
# Went for an impromptu run with the hubby @BlazingSandals on a beautiful 60F afternoon full of sunshine. 🌞
#
# Today was good. ❤️
# ----
# [None, None, None, None, None]

# %% [markdown]
# ### Negative

# %% [markdown]
# Same as above, but fliped for negative sentiments

# %% [markdown]
# Side note - I've seen 'asian american' terms come up. It would be interesting to see how that term trends over time due to the pandemic

# %% [markdown]
# A pretty good mix of the most negative tweets. It seems to be negative sentiment around politics, the disruption of the pandemic, racism, anti-vaxers. It seems to be more of the same topics in the news today.
#
# An interesting find though ... some of the 'positive' sentiments above could gain more insight into what folks 'feel' or think about a vaccine. For example, if a person who is not into taking vaccine, would not talk negativley about not taking the vaccine. They would say how their decision is good, and explain why. It may be worth it to do more EDA into neg vs positive to find these nuances.

# %%
idxs=sent_df[(sent_df.tb_subj>.5)&(sent_df.tb_sent_subj=='neg')].sort_values(by='compound_sent',ascending=True).index.tolist()[:5]
[print(x,'\n----\n') for x in full_data.iloc[idxs].full_text.tolist()]
# Out:
# Marxism.... Max stress
# Fake news
# Fake pandemic
# Fake elections.
# Fake president
# Fake white supremacy
# Fake extremism
# Fake Trump insurrection
# Fake Kamala not afr amer
# Fake climate change
# Fake Biden Healing
# Fake Vax https://t.co/48Y2W7FDr7
# ----
#
# @GOP Trump’s d worst POTUS &amp; most incompetent ever! Shameless &amp; biggest loser incumbent ever! A pathological liar, racist &amp; unstable! Narcissist, traitor, Insurrectionist, dishonorable, d most corrupt &amp; amoral! He’s vaccinated secretly while lying to his stupid supporters about covid
# ----
#
# The vax seeks to reduce costs of Covid, but how much weight to give to hospitalizations and death, how much to economic disruptions, how much to devastating harm faced by our children? I never imagined that the that % chance of death by age would be the only thing that matters.
# ----
#
# I hate these anti-vaxers like bitch you really just wanna die even though you’ve been vaxed your whole life? Idk stop changing shit also why now? You sound stupid. Also if a new corona come, just get another vax? You act like the variations of flu don’t be killing people too.
# ----
#
# tw // racism, hate crimes
#
# this is fucking disgusting. there has been so much anti-asian hate speech + hate crimes since covid started. this isn’t just about him not liking bts’s performance...it’s racially motivated hate speech, and it’s representative of a larger problem. https://t.co/Sm7bdhONkP
# ----
# [None, None, None, None, None]

# %%
idxs=sent_df[(sent_df.tb_subj>.5)&(sent_df.tb_score<.5)].sort_values(by='tb_score',ascending=True).index.tolist()[:5]
[print(x,'\n----\n') for x in full_data.iloc[idxs].full_text.tolist()]
# Out:
# @AP People I know have been suffering horribly from these vaccines.  They say they would rather catch it than take the vaccination ever
# ----
#
# This is freaking insane.  #firefauci https://t.co/llHdGMcv6d
# ----
#
# I am insanely relieved... dose 1 of @pfizer #covid #vaccination done! https://t.co/LcPQVfHOzD
# ----
#
# @RepKClark @WhipClyburn Unlock the cities from ur insane Wuhan virus program of destruction, &amp; pass policies which promote jobs!
# ----
#
# US Covid-19: After a devastating milestone, vaccine makers pledge hundreds of millions of doses through July - CNN https://t.co/IGvmUiK9Z7
# ----
# [None, None, None, None, None]

# %% [markdown]
# This below filter is similar to the first one

# %%
idxs=sent_df[(sent_df.tb_subj>.5)&(sent_df.tb_score<.5)].sort_values(by='compound_sent',ascending=True).index.tolist()[:5]
[print(x,'\n----\n') for x in full_data.iloc[idxs].full_text.tolist()]
# Out:
# Marxism.... Max stress
# Fake news
# Fake pandemic
# Fake elections.
# Fake president
# Fake white supremacy
# Fake extremism
# Fake Trump insurrection
# Fake Kamala not afr amer
# Fake climate change
# Fake Biden Healing
# Fake Vax https://t.co/48Y2W7FDr7
# ----
#
# @CSandbox @DrDooleyMD I hate 2 say it but hypothesis of various doctors / evidence oFMANDATORY FLU VAX stats from MILITARY show u got flu shot &amp; u hv higher % get sick w covid19 disease not SARS COV2! Italians had highest population OLD FOLKS ESP of lethal FLU VAX &amp; worst covid19 disaster! All connecT
# ----
#
# @GOP Trump’s d worst POTUS &amp; most incompetent ever! Shameless &amp; biggest loser incumbent ever! A pathological liar, racist &amp; unstable! Narcissist, traitor, Insurrectionist, dishonorable, d most corrupt &amp; amoral! He’s vaccinated secretly while lying to his stupid supporters about covid
# ----
#
# @BekahTheBold @Lui_101499 @WSJ No. I'm saying y would a 58 yr old just drop dead "coincidentally" after a Covid vax. She's not the only one. You implied that only allergic reaction 2 a pharma product could kill someone. Vioxx 🖤 attack victims were not allergic. MEDICATIONS CAN CAUSE DEATH for myriad reasons
# ----
#
# The vax seeks to reduce costs of Covid, but how much weight to give to hospitalizations and death, how much to economic disruptions, how much to devastating harm faced by our children? I never imagined that the that % chance of death by age would be the only thing that matters.
# ----
# [None, None, None, None, None]

# %% [markdown]
# ## Which twitter users were most positive / negative?

# %%
sent_byuser_dict = defaultdict(list)

sent_vals = {'neu','pos','neg'}

for x, user in tqdm(enumerate(full_data.user_id.unique())):
    cnts = full_data[full_data.user_id==user].tb_sent_subj.value_counts(normalize=True)
    
    for idx in cnts.index:
        sent_byuser_dict[idx+'_p'].append(cnts.loc[idx])
    
    if len(cnts.index)<3:
        for s in sent_vals.difference(set(cnts.index)):
            sent_byuser_dict[s+'_p'].append(0)
    
    
    cnts = full_data[full_data.user_id==user].tb_sent_subj.value_counts()
    
    for idx in cnts.index:
        sent_byuser_dict[idx].append(cnts.loc[idx])
    
    if len(cnts.index)<3:
        for s in sent_vals.difference(set(cnts.index)):
            sent_byuser_dict[s].append(0)
    
    sent_byuser_dict['user'].append(user)
# Out:
# <ipython-input-52-15e240dd1237>:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for x, user in tqdm(enumerate(full_data.user_id.unique())):
# 0it [00:00, ?it/s]

# %%
sent_cnts_users = pd.DataFrame.from_dict(sent_byuser_dict)
sent_cnts_users['user']=sent_cnts_users.user.apply(lambda x: str(int(x)))
display(sent_cnts_users.head(2))
sent_cnts_users.to_csv('sentiment_user_counts_8t.csv',index=False)
# Out:
#    pos_p  neg_p  neu_p  pos  neg  neu                 user
# 0    1.0    0.0    0.0    1    0    0             29501253
# 1    0.0    0.0    1.0    0    0    3  1201670995435646976

# %%
plot=sns.catplot(y='user',
                 x='neg', 
                 kind='bar',
                 data = sent_cnts_users.sort_values(by=['neg'],ascending=False)[:10], 
                 color='red', 
                 height=7,
                 aspect=1.3)
plot.set_yticklabels(fontsize=14)
plot.fig.suptitle('Negative Sentiment Disbribution by Users', y=1.05)
plot.ax.set_xlabel('Negative Sentiment')
plot.ax.set_ylabel('Users')
# fig.show()
# Out:
# Text(-98.325, 0.5, 'Users')

# %% [markdown]
# Twitter Ids have been removed
#
# 18734815 => removed <br>
# 1199283206547095552 => removed <br>
# 466069719 => removed <br>
# 1087134051914395648 => removed<br>
# 1359853845682278400 => Error: Not Found*<br>
# 1324329792867602432 => Error: Not Found*<br>
# 18831926 => removed<br>
# 1363532276798226432 => Error: Not Found*<br>
# 17353325 => removed<br>
# 18868445 => removed<br>
# <br><br><br>
# These user ids did not return a value. It could be that this user deleted their account, or, during wrangling python has rounded the user id variable while it was a number, making the number different

# %% [markdown]
# #### 5 of the negative tweets from @24AheadDotCom

# %%
[print(x) for i,x in enumerate(full_data[full_data.user_id==18734815][:5].full_text) if full_data[(full_data.user_id==18734815)].iloc[i].tb_sent_subj=='neg']
# Out:
# @AaliaAnthony @HildaSolis @Cleavon_MD @LACDevAuthority @Curative @lapublichealth 95% of C19 deaths were 50+ &amp; risk factors play a major role. Vax them &amp; there's basically no more pandemic.
#
# Instead, @HildaSolis wants to vax young/healthy people of the "right race" before seniors/high risk of the "wrong race" because she's David Duke with a tan.
# @m2angels2 @luna_c_is_here @GavinNewsom The solution is simple: vax by ICU risk. Cover seniors/high risk - those most likely to die - and the spread doesn't matter.
#
# @GavinNewsom is going about it backwards: vaxing young/healthy before seniors/high risk. That increases deaths &amp; prolongs the pandemic.
# @TexasDoctorCool @SenToniAtkins @GavinNewsom The problem is with con leaders. Newsom is extremely vulnerable on his vax tiers that are prolonging the pandemic &amp; increasing deaths.
#
# Instead of harping on that, con leaders act like their kids &amp; whine about school sports as Newsom is literally killing people.
# [None, None, None]

# %% [markdown]
# #### 5 of the negative tweets from @stefan90671458

# %%
[print(x) for i,x in enumerate(full_data[full_data.user_id==1199283206547095552][:5].full_text) if full_data[(full_data.user_id==18734815)].iloc[i].tb_sent_subj=='neg']
# Out:
# The world round us wil be made to coerce us into taking Phizers DNA🧬Rna vax. Public transport,favorite events,restaurants,workplaces,travel etc &amp; for what a virus that has 99.997% recovery rate 900 dead/26,000,000, u have more of chance of dying in car accident 1500 dead 2019🇦🇺
# @theheraldsun The world round us will be made to coerce us into taking Phizers DNA🧬Rna vax. Public transport,favorite events,restaurants, workplaces,travel etc &amp; for what a virus that has 99.997% recovery rate 900 dead/26,000,000, u have more of chance of dying in car accident 1500 dead 2019!
# [None, None]

# %%
plot=sns.catplot(y='user',
                 x='pos', 
                 kind='bar',
                 data = sent_cnts_users.sort_values(by=['pos'],ascending=False)[:10], 
                 color='blue', 
                 height=7,
                 aspect=1.3)
plot.set_yticklabels(fontsize=14)
plot.fig.suptitle('Number of positive counts by user', y=1.05)
plot.ax.set_xlabel('Positive Sentiment')
plot.ax.set_ylabel('Users')
# fig.show()
# Out:
# Text(-98.325, 0.5, 'Users')

# %%
[print(str(int(i))) for i in sent_cnts_users.sort_values(by=['pos'],ascending=False)[:10].user]
# Out:
# 1346109936896516096
# 1349800103234551808
# 718851553692528640
# 1185531782952816640
# 820452522494226432
# 1364681954168352768
# 2572777037
# 748652249551757312
# 261086565
# 18734815
# [None, None, None, None, None, None, None, None, None, None]

# %%
[print(x) for i,x in enumerate(full_data[full_data.user_id==1178417352511127552][:5].full_text) if full_data[(full_data.user_id==1178417352511127552)].iloc[i].tb_sent_subj=='pos']
# Out:
# @CPAC Our entire country has been screwed thanks to #Trump
# #TrumpKnewAndDidNothing
# He denied the virus &amp; the science, he put our country far behind &amp; held super spreader events. The USA makes up 4% of the world's population but 25% of #COVID19 cases/deaths 😪 in the richest country!
# @BillyDStarchild Our entire country has been screwed thanks to #Trump
# #TrumpKnewAndDidNothing
# He denied the virus &amp; the science, he put our country far behind &amp; held super spreader events. The USA makes up 4% of the world's population but 25% of #COVID19 cases/deaths 😪 in the richest country!
# [None, None]

# %% [markdown]
# The above person with the most positive tweets shows a couple things.
# The suppports that more work is needed to define 'positive' and 'negative'. The above tweets I would characterize as negative / sarcastic. <br>
# Also - It looks like either this person retweeted or tweeted the same post multiple times to show his passion on the subject, or, there are multiple tweets in the dataset

# %%
[print(x) for i,x in enumerate(full_data[full_data.user_id==3291683682][:5].full_text) if full_data[(full_data.user_id==3291683682)].iloc[i].tb_sent_subj=='pos']
# Out:
# @deNutrients Significant clinical  benefits
# https://t.co/o3GI3to7CG
# https://t.co/7Bj66Lz2H4
# https://t.co/hDAFUf2d47
# Over-the-Counter prevention &amp; therapy
# https://t.co/qchnVb7SqH
# Vitamin D &amp; Quercetin inhibit viral entry &amp; Vitamin D+ QCT + Estradiol interfere with 26/27 (96%) virus proteins
# [None]

# %% [markdown]
# verify that the above are different tweets, different tweet ids

# %%
print('count of this post, posted at different times: ',full_data[(full_data.user_id==3291683682)&(full_data.tb_sent_subj=='pos')].created_at.nunique())
print('number of different tweet ids: ',full_data[(full_data.user_id==3291683682)&(full_data.tb_sent_subj=='pos')].tweet_id.nunique())
# Out:
# count of this post, posted at different times:  1
# number of different tweet ids:  1

# %%
sent_cnts_users.sort_values(by=['pos'],ascending=False)[:10]
# Out:
#           pos_p     neg_p     neu_p  pos  neg  neu                 user
# 3916   0.365854  0.000000  0.634146   15    0   26  1346109936896516096
# 1091   0.384615  0.000000  0.615385    5    0    8  1349800103234551808
# 30479  1.000000  0.000000  0.000000    5    0    0   718851553692528640
# 1272   0.067797  0.016949  0.915254    4    1   54  1185531782952816640
# 1048   0.230769  0.230769  0.538462    3    3    7   820452522494226432
# 10216  1.000000  0.000000  0.000000    3    0    0  1364681954168352768
# 2250   0.230769  0.076923  0.692308    3    1    9           2572777037
# 3591   0.750000  0.000000  0.250000    3    0    1   748652249551757312
# 1735   1.000000  0.000000  0.000000    3    0    0            261086565
# 3942   0.103448  0.413793  0.482759    3   12   14             18734815

# %%
full_data.to_csv(data_path+'\\'+'complete_data_5t.csv',index=False)

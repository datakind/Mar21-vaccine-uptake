# %% [markdown]
# ## EDA-01
#
# ### Questions:
# 1. What rules did you put in place to refine/clean the data?
# 2. What number of duplicates occurred?
# 3. What amount of data was nonsensical?
# 4. What number of unique posts/posters occurred?
# 5. Is there surprising missingness or sparsity (e.g. by time, date, location, etc.)

# %% [markdown]
# ### Field	Description
#
# 1. **tweet_id**: Unique identifier of the tweet
#
# 2. **created_at**:	Time stamp of when the tweet was sent.
#
# 3. **full_text**:	The text of the tweet
#
# 4. **geo**	Geo tag of the tweet. Will only be included if user has location services enabled.
#
# 5. **coordinates** 	Latitude and Longitude of the tweet. Will only be included if the user has location services
# enabled.
#
# 6. **place**	Twitter identified place. Will only be included if the user has location services enabled.
#
# 7. **retweet_count**	The number of retweets the tweet received
#
# 8. **favorite_count**	The number of favorites the tweet received
#
# 9. **possible_sensitive**	Twitter flag if the tweet contains sensitive material. This is done by Twitter. If the tweet did not have this tagged by Twitter, we imputed NOT FOUND
#
# 10. **lang**	The language of the tweet. We filtered towards English 'en'
#
# 11. **user_id**	The unique identiifer of the person or entity sending the tweet
#
# ### Data Collection Methodology
# The twitter public API allows for a query based keyword search to return 100 random samples of tweets containing keywords from the previous 7 days.
#
# Data was scraped from February 23 - March 3 searching for either a combination of a Covid-19 related keyword and a vaccine related key word, or just containing a hashtag keyword.
#
# The queries were randomly generated with the above logic in order to obtain unique tweets per API request.

# %%
import os 
# set your cwd
my_cwd = "/home/mriveralanas/projects/Mar21-vaccine-uptake"
os.chdir(my_cwd)

# %%
# import data libraries
import pandas as pd
pd.options.mode.chained_assignment = None  
import datetime
from collections import Counter

# nlp
import re
import nltk
import numpy as np
from sklearn.cluster import AffinityPropagation
import distance
import unicodedata as ud
from langdetect import detect 

import time

# %%
# https://stackoverflow.com/questions/3094498/how-can-i-check-if-a-python-unicode-string-contains-non-western-letters

latin_letters= {}

def is_latin(uchr):
    try: 
        return latin_letters[uchr]
    except KeyError:
         return latin_letters.setdefault(uchr, 'LATIN' in ud.name(uchr))

def only_roman_chars(unistr):
    return all(is_latin(uchr) for uchr in unistr if uchr.isalpha())

def test_hashtag(unistr):    
    unistr_strip = list(filter(lambda x: only_roman_chars(x), unistr))
    return len(unistr_strip)>.5*len(unistr)

def clean_hashtag(unistr):    
    unistr = list(map(lambda x: x if only_roman_chars(x) else "", unistr))
    return unistr

#? ----- Affinity Propagation grouping
def hashtag_group(grouping, hashtag):
    hashtag_lower = hashtag.lower()
    hashtag_clean = re.sub(r'[^a-zA-Z0-9]', '', hashtag_lower)
    for key, value in grouping.items():
        if hashtag_clean in value:
            return key
        elif hashtag_clean == key:
            return key
    # error
    print(hashtag_clean)
    raise ValueError

# %%
import matplotlib.pyplot as plt

large = "22"
med = "18"
small = "16"
params = {"axes.titlesize": large, 
        "legend.fontsize":large,
        "figure.figsize":(20,8), 
        "axes.labelsize":med,
        "axes.titlesize":med,
        "xtick.labelsize":med,
        "ytick.labelsize":med,
        "figure.titlesize":large
        }
plt.rcParams.update(params)
plt.style.use('seaborn-darkgrid')

def plot_count_by(data, metric, groupby):

    data_groupby = data[[groupby,metric]].groupby([groupby])[metric].count().reset_index()

    x = data_groupby[groupby]
    y = data_groupby[metric]

    x_pos = [i for i, _ in enumerate(x)]
    plt.bar(x_pos, y, color='green')
    plt.xlabel("{} y {}".format(metric, groupby))
    plt.ylabel(metric)
    plt.title(groupby)

    plt.xticks(x_pos, x)

    plt.show()
    return None

# %%
# pull local twitter_text
raw_text = pd.read_csv("data/twitter_gdrive/twitter_text.csv")

# %%
raw_text.head()
# Out:
#               tweet_id                      created_at  \
# 0  1364223054851813377  Tue Feb 23 14:38:16 +0000 2021
# 1  1364381497302671362  Wed Feb 24 01:07:52 +0000 2021
# 2  1364609594056704002  Wed Feb 24 16:14:15 +0000 2021
# 3  1364726798412443649  Wed Feb 24 23:59:58 +0000 2021
# 4  1364726797947052038  Wed Feb 24 23:59:58 +0000 2021
#
#                                            full_text  geo coordinates place  \
# 0  Here’s what's in the COVID relief package:\n \...  NaN         NaN   NaN
# 1  Will the National Endowment for the Arts be he...  NaN         NaN   NaN
# 2  This is both anecdotal and early, but many lon...  NaN         NaN   NaN
# 3  A Link to Professor Chossudovsky’s Analysis of...  NaN         NaN   NaN
# 4  Children warned over hugging grandparents even...  NaN         NaN   NaN
#
#   retweet_count favorite_count possibly_sensitive lang       user_id
# 0          9160          38093          NOT FOUND   en  2.950125e+07
# 1          6131          18560          NOT FOUND   en  1.201671e+18
# 2          5941          63174          NOT FOUND   en  3.842872e+07
# 3             1              0              False   en  2.192010e+09
# 4             0              2              False   en  2.868190e+09

# %%
# clean text data

def convert_date(d):
    if pd.isnull(d):
        return "NOT FOUND"
    else:
        new_d = datetime.datetime.strptime(d, "%a %b %d %H:%M:%S +0000 %Y").strftime("%Y-%m-%d")
        return new_d

raw_text['date'] = list(map(lambda d: convert_date(d), raw_text['created_at']))

# %%
# pull local twitter_user
raw_user = pd.read_csv("data/twitter_gdrive/twitter_user.csv")

# %%
raw_user.head()
# Out:
#                user_id                   user_location  user_verified  \
# 0             29501253                     Burbank, CA           True
# 1  1201670995435646976                   Colorado, USA           True
# 2             38428725                             NaN           True
# 3           2192010002                  here & now  🇺🇸          False
# 4           2868189989  Brighton UK and Bayonne France          False
#
#    user_followers_count
# 0               2931387
# 1                557873
# 2                124131
# 3                  2947
# 4                  2556

# %%
# pull local twitter_hashtag
raw_hashtag = pd.read_csv("data/twitter_gdrive/twitter_hashtag.csv")

# convert tweet id to string
raw_hashtag['tweet_id'] = list(map(lambda x: str(x), raw_hashtag['tweet_id']))

# %%
raw_hashtag.head()
# Out:
#        hashtags             tweet_id
# 0         Covid  1364726798412443649
# 1       COVID19  1364726771606691845
# 2       COVID19  1364726746797367297
# 3      eviction  1364726728183144449
# 4  ChuckSchumer  1364726702027530241

# %%
# # non english hashtags:
# {"中共病毒":"CCP Virus", # on twitter seems to linked to anti-CCP sentiment
#  "上本町わたなべクリニック":"",

# %% [markdown]
# ### What is the Tweet location distribution over the 7 day window?

# %%
tweet_time = raw_text[['tweet_id', 'date']]

# %%
plot_count_by(tweet_time, metric='tweet_id', groupby='date')

# %% [markdown]
# ### Tweet ID by lang

# %%
raw_text_lang = raw_text[['tweet_id', 'lang']]
raw_text_eng = raw_text_lang[list(map(lambda x: x == "en", raw_text_lang['lang']))]
raw_text_otherlang = raw_text_lang[list(map(lambda x: x != "en", raw_text_lang['lang']))]

# %%
# non english tweets
plot_count_by(raw_text_otherlang, metric='tweet_id', groupby='lang')

# %% [markdown]
# ### Analysis of Hashtags
#
# - [Difficulty with time dependent, not purely lexical relationship among hashtags](https://www.mitpressjournals.org/doi/pdf/10.1162/COLI_a_00277)
#     - Unlike other tagging systems (e.g., Flickr1), hashtags in Twitter are used more as a symbol of community membership than for organizing a message content, as remarked in Huang, Thornton, and Efthimiadis (2010).
#     - Together, these problems reduce the effectiveness of Twitter hashtags as a means both for tracing users’ interests (owning to obscurity and sense shifts), and for capturing the worldwide impact of trending topics (because of synonymy and multilinguality).
#     - Despite this, however, better methods for analyzing the semantics of hashtags are most definitely needed, since hashtags are readily available, whereas textual analysis techniques, when applied on large and lengthy micro-blog streams, are limited both by complexity constraints and by the very reduced dimension of micro-blog texts (140 characters). What is more, real-time detection of sense-related hashtags could be used to improve the task of hashtag recommendation, thereby facilitating the monitoring of online discussions
#     - The solution proposed in this article is to use an algorithm for hashtag sense clustering based on temporal co-occurrence and similarity of the related time series, named SAX*
#     - Ferragina, Piccinno, and Santoro (2015).
#     - **The underlying idea of SAX* is that hashtags with similar temporal behavior are semantically related**
#
#
#
# - [Clustering using Edit distance, lexical similarity](https://stats.stackexchange.com/questions/123060/clustering-a-long-list-of-strings-words-into-similarity-groups)
# - [Affinity Propagation](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AffinityPropagation.html#sklearn.cluster.AffinityPropagation)

# %%
# --------- cleaning

# limit to english lang tweets
hashtag_eng = raw_hashtag[list(map(lambda x: test_hashtag(x), raw_hashtag['hashtags']))]
hashtag_noneng = raw_hashtag[list(map(lambda x: not test_hashtag(x), raw_hashtag['hashtags']))]

# lower-case
hashtag_eng_list = list(map(lambda x: x.lower(), hashtag_eng['hashtags']))

#? strip non alpha numeric
hashtag_eng_list = list(map(lambda x: re.sub(r'[^a-zA-Z0-9]', '', x), hashtag_eng_list))

# %%
sorted(list(set(hashtag_eng_list)))
len(hashtag_eng_list)
# Out:
# 23990

# %%
start_time = time.time()

words = list(set(hashtag_eng_list))
words = np.asarray(words)
lev_similarity = -1*np.array([[distance.levenshtein(w1,w2) for w1 in words] for w2 in words])

affprop = AffinityPropagation(affinity="precomputed", 
                              damping=0.7)
affprop.fit(lev_similarity)

print("--- %s seconds ---" % (time.time() - start_time))

# %%
affprop_dict = {}
for cluster_id in np.unique(affprop.labels_):
    exemplar = words[affprop.cluster_centers_indices_[cluster_id]]
    cluster = np.unique(words[np.nonzero(affprop.labels_==cluster_id)])
    affprop_dict[exemplar] = list(cluster)

# %% [markdown]
# ### Prune Clusters:
#
# Remove members from cluster (basically create a new cluster) for members with average Lev distance less than the average of all members average pairwise lev distance to other cluster members
#
# **consider an alternative distance measure to lev distance**

# %%
c = 0
for key, value in affprop_dict.items():
    if len(value) <2:
        continue
    print(key)
    print(value)
    print("==========================")
    c +=1
    
print(c)
# Out:
# faucifraud
# ['afriforum', 'faucifraud', 'fauciisaliar', 'fauciisaquack', 'faucithefraud', 'saudiarabia']
# ==========================
# corruption
# ['anticorruption', 'confusion', 'congratulations', 'construction', 'corrections', 'corrupt', 'corruptcuomo', 'corruption', 'corruptmedia', 'corrupttrump', 'groupthink', 'torycorruption', 'ucpcorruption']
# ==========================
# healthyeating
# ['healthequity', 'healthscreening', 'healthweatheralert', 'healthyaging', 'healthyeating', 'healthylifestyle']
# ==========================
# modi
# ['cambodia', 'cox1', 'crdt', 'hamont', 'media', 'mgus', 'miami', 'modhi', 'modi', 'modigovt', 'modijobdo', 'moditax', 'movies', 'mtedu', 'mumbai', 'muniq', 'niravmodi', 'odu', 'pmmodi', 'ssdi', 'toci', 'urdu']
# ==========================
# mondaythoughts
# ['food4thought', 'justathought', 'mondaythoughts', 'saturdaythoughts', 'thursdaythoughts', 'viralthoughts']
# ==========================
# vaccineselfie
# ['thevaccineissafe', 'vaccines4life', 'vaccinesaresafe', 'vaccineselfie', 'vaccinesforall', 'vaccinesideeffects']
# ==========================
# dallascounty
# ['collincounty', 'dallascounty', 'deblasiovariant', 'oaklandcounty', 'palmbeachcounty', 'sanjoaquincounty', 'santaclaracounty', 'stcharlescounty']
# ==========================
# mask
# ['2wtk', 'imask', 'mafs', 'mark', 'mask', 'maskfit', 'masking', 'maskmob', 'masks', 'maskswork', 'mason', 'massage', 'mh17', 'mmsm', 'moats', 'msm', 'mykhsc', 'poshmark', 'risk', 'sask', 'unmask']
# ==========================
# washyourhands
# ['bloodonyourhands', 'taiyyarrehnahai', 'washyourhands']
# ==========================
# svpol
# ['aupol103', 'auspol', 'basfprovm', 'capitol', 'dkpol', 'dstv403', 'flapol', 'gapol', 'nzpol', 'qldpol', 'school', 'snpfail', 'suffolk', 'sunol', 'svpol', 'symptom', 'utpol', 'wvpol']
# ==========================
# healthcare
# ['healthcanada', 'healthcare', 'healthcareheroes', 'healthcenter', 'healthcomm', 'healthdata', 'healthfreedom', 'healthtips', 'healthtrends', 'healthwatch', 'healthygut', 'mbnaturecare', 'ovhealthcare', 'right2cure', 'thewalrusarchive', 'tohellwithcorona', 'wealthtax']
# ==========================
# covidrelief
# ['arvindkejriwal', 'bookreview', 'covidheroes', 'covidrelief', 'covidreliefbill', 'covidreliefpackage', 'nocovidmonopolies']
# ==========================
# declined
# ['airlines', 'bidencheated', 'bidenlied', 'deadlinewh', 'declined', 'decoupling', 'deluded', 'demvoice1', 'dogecoinrise', 'excited', 'kindleunlimited', 'reunited', 'tellinme', 'theallineed']
# ==========================
# vernoncoleman
# ['drvernoncoleman', 'vernoncoleman']
# ==========================
# antigens
# ['angiotensin', 'antibodies', 'antibody', 'antidepressants', 'antigen', 'antigens', 'antimaskers', 'antioxidants', 'anxiety', 'emergency', 'hitchens', 'indigenous', 'mzanzimemes']
# ==========================
# leadershipmatters
# ['leadershipmatters', 'workerscompmatters']
# ==========================
# palestinians
# ['doublestandards', 'fellowghanaians', 'moorestownmall', 'palestinian', 'palestinians', 'urasekaipicnic']
# ==========================
# thankyouscience
# ['behavioralscience', 'partyofscience', 'thanksscience', 'thankyouanitaanand', 'thankyouscience']
# ==========================
# selfiestation
# ['firstnations', 'fullrestitution', 'selfesteem', 'selfie4tacha', 'selfiestation', 'selfishbritain', 'selfisolation', 'utilityregulation']
# ==========================
# ue
# ['aex', 'aye', 'be', 'blue', 'ce', 'cte', 'due', 'fwn', 'iud', 'lung', 'm', 'me', 'men', 'pei', 'qubec', 'rwe', 's', 'self', 'sf', 'tech', 'true', 'uae', 'udes', 'ue', 'ue4', 'uf', 'ugh', 'ui', 'uk', 'umc', 'un', 'uq', 'us', 'uv', 'uvi', 'ux', 'we', 'yeg']
# ==========================
# nspoli
# ['2shotz', 'abpoli', 'bardoli', 'bcpoli', 'bospoli', 'cdnpoli', 'endpolio', 'mapoli', 'mbpoli', 'mongolia', 'ncpol', 'netflix', 'njspotlight', 'nlpoli', 'ns10v10', 'nspoli', 'nstworld', 'nwtpoli', 'onpoli', 'princephilip', 'vtpoli']
# ==========================
# wantactionwednesday
# ['wantactionwednesday', 'wellnesswednesday']
# ==========================
# unite2fightcorona
# ['fightagainstcorona', 'indiafightscorona', 'unite2fightcorona', 'unitedagainstcovid']
# ==========================
# eatouttohelpout
# ['eatouttohelp', 'eatouttohelpout']
# ==========================
# westend
# ['content', 'glucond', 'hesperidin', 'neisvoid', 'neutrient', 'newamsterdam', 'osuwexmed', 'peoplekind', 'twentytwenty', 'wallstreet', 'warpspeed', 'weareid', 'weekendfun', 'westend', 'westernma', 'westernu', 'westmids', 'westonfl', 'westvirginia']
# ==========================
# ireland
# ['auckland', 'circleback', 'disneyland', 'england', 'filedunder', 'finland', 'firebud', 'iceland', 'ireland', 'isleofman', 'kirkland', 'maryland', 'newzealand', 'oakland', 'overwhelmed', 'portland', 'propaganda', 'rutland', 'scotland', 'srilanka', 'srilankan', 'surveillance', 'switzerland']
# ==========================
# who
# ['aco', 'bhm', 'bwhi', 'drwho', 'hoy', 'know', 'kwch12', 'mywhy', 'nhs', 'ohio', 'pho', 'ptbo', 'twiv', 'war', 'wato', 'wbz', 'wef', 'wfh', 'wha', 'who', 'why', 'wlwt', 'wsj', 'wtf', 'wto']
# ==========================
# middierising
# ['indoordining', 'macdanielsblog', 'middierising', 'minersnursing', 'redditrading']
# ==========================
# green
# ['agreed', 'ceraweek', 'ellen', 'evergreen', 'free', 'ghee', 'golden', 'greatman', 'greece', 'green', 'greenzoneact', 'gremeany', 'gretsch', 'grey', 'grief', 'groupofseven', 'ibgroup', 'queen', 'queens', 'reopen', 'screen', 'sheep', 'sleep', 'sweden', 'udreview', 'walgreens']
# ==========================
# covid19pandemic
# ['covid19nigeria', 'covid19pandemic', 'covidscamdemic', 'powerandpandemic']
# ==========================
# democrats
# ['advocates', 'democracy', 'democrates', 'democratic', 'democrats', 'dixievodka400', 'doyourpart', 'drmarcomtz', 'econwatch', 'fakedemocracy', 'immigrants']
# ==========================
# recession
# ['decepticons', 'depression', 'duecesbitch', 'eccunion', 'inclusion', 'pelosiresign', 'recession', 'refocussunday', 'swbordermission', 'transmission']
# ==========================
# news
# ['7news', '9news', 'beknews', 'c4news', 'chws', 'cltnews', 'dems', 'energy', 'geonews', 'hcws', 'inners', 'itvnews', 'keys', 'kiwis', 'mecfs', 'mtnews', 'nejm', 'nevhc', 'nevis', 'new', 'news', 'newsgroup', 'newsmax', 'newsom', 'nps', 'nutr', 'nwo', 'onev1', 'ottnews', 'selx', 'unrwa', 'vaxnews']
# ==========================
# savelives
# ['beverlyhills', 'cancelibexams', 'hatecrimes', 'labvolumeindex', 'maldives', 'maskssavelives', 'ndtvexclusive', 'positivevibes', 'savelives', 'saveournhs', 'saveourvenues', 'schnelltest', 'sharelove', 'stevenuniverse', 'wedeliver']
# ==========================
# physicianassistants
# ['opticalassistant', 'physicianassistants', 'physicianassociate']
# ==========================
# coronavirus
# ['contagious', 'coronadiaries', 'coronaimpfung', 'coronasverige', 'coronavirus', 'coronavirusat', 'coronaviruschina', 'coronavirusuk', 'coronavirusus', 'coronavrus', 'covidvirus', 'rotavirus']
# ==========================
# santabarbara
# ['atmanirbharbharat', 'hartaberfair', 'mamatabanerjee', 'santabarbara']
# ==========================
# coronavirusupdate
# ['coronaabsurditten', 'coronavirusfacts', 'coronaviruspandemic', 'coronavirusupdate', 'coronavirusupdates', 'coronavirusvaccine', 'coronavirusvariant']
# ==========================
# nobelprize
# ['cybercrime', 'keyworkerpayrise', 'newshelpline', 'nobelprize', 'recallpritzker', 'uncategorized']
# ==========================
# freetommy
# ['dontfreetommy', 'freedom', 'freedomfighters', 'freeebook', 'freetommy', 'freetoread', 'freezeme', 'rareautoimmune', 'triplewhammy']
# ==========================
# agranews
# ['agranews', 'arkansasnews', 'centralnews', 'ignfanfest', 'kumparannews', 'localnews', 'losangeles', 'nigerianews', 'orangeclowns', 'panaynews', 'usafricabrknews']
# ==========================
# teaching
# ['artemisinin', 'ccpchina', 'geocaching', 'impeachcollins', 'onlineteaching', 'protectchicago', 'teachers', 'teaching', 'teamcherry', 'teamhalo', 'teamhisd', 'training', 'whatwearewatching']
# ==========================
# pharmacies
# ['asthmaremedies', 'charliemackesy', 'parkgatesociety', 'pharmacare', 'pharmacarenow', 'pharmacies', 'pharmacists', 'pharmacy', 'pharmacystudent', 'pharmallies', 'pharmatopnews', 'richarddawkins', 'shaddowbanned', 'shareariel']
# ==========================
# medicalsupplies
# ['americanrescueplan', 'cleaningsupplies', 'medicalaffairs', 'medicalsupplies']
# ==========================
# sundayvibes
# ['30days30videos', 'fridayvibes', 'saturdayvibes', 'sundayfunday', 'sundayvibes', 'thursdayvibes', 'tuesdayvibe', 'wednesdayvibes']
# ==========================
# tribaldistrict
# ['fridaylivestream', 'orldistrict6', 'tribaldistrict', 'yaiptalyaistifa']
# ==========================
# takethevaccine
# ['getthevaccine', 'iwilltakethevaccine', 'janssenvaccin', 'passeportvaccinal', 'takethevaccine']
# ==========================
# read
# ['bad', 'dead', 'deaf', 'dream', 'fear', 'genx', 'herd', 'naad', 'peace', 'qed', 'raf', 'reachdeep', 'read', 'readup', 'real', 'reddeer', 'reddit', 'redfm', 'remaon', 'replay', 'retail', 'roadmap', 'texas', 'thread']
# ==========================
# operationwarpspeed
# ['operationslowpoke', 'operationwarpspeed']
# ==========================
# oxfordshire
# ['hertfordshire', 'lincolnshire', 'oxfordshire', 'shropshire']
# ==========================
# mutation
# ['akhmetkaliyev', 'asymptomatic', 'attention', 'automation', 'aviation', 'cutebuttongirl', 'education', 'mediation', 'melatonin', 'migration', 'motivation', 'mtisnation', 'mushroom', 'mutation', 'mutations', 'mymumhasseen', 'playstation5', 'population', 'putalidonit', 'vacation']
# ==========================
# defenseboost
# ['dagenshelikopter', 'defenseboost', 'defneseboost', 'thejerusalempost']
# ==========================
# lakecounty
# ['berkscounty', 'chestercounty', 'clarkcounty', 'essexcounty', 'kerncounty', 'kingcounty', 'lakecounty', 'openupthecountry', 'raleighcounty', 'renfrewcounty', 'sanbenitocounty', 'takeout', 'tularecounty']
# ==========================
# potus
# ['airbus', 'cpsplus', 'exguy', 'focus', 'kumud', 'lupus', 'moves', 'pcrtest', 'pets', 'poetry', 'popular', 'portugal', 'potus', 'potus46', 'scotus', 'shots', 'shoutouts', 'virus', 'wegotus']
# ==========================
# believe
# ['belgium', 'believe', 'believeindia', 'belikedolly', 'berkeley', 'bestdayever', 'beyonce', 'bluebeetle', 'bolivia', 'bullseye', 'onepiece', 'relief', 'relieved', 'unbelievable', 'yellowfever']
# ==========================
# spring
# ['barming', 'boeing', 'boxing', 'censoring', 'cummings', 'killing', 'mining', 'morningdew', 'saving', 'serving', 'spagna', 'spain', 'splitgop', 'spring', 'springfield', 'sputnikv', 'surfing', 'symposium', 'ukraine', 'usezinc']
# ==========================
# wolframlanguage
# ['signlanguage', 'wolframlanguage']
# ==========================
# martialarts
# ['cnarayanareddy', 'firetwoblasts', 'hawaiiairports', 'kawarthalakes', 'ladygagadogs', 'marshillblog', 'martialarts', 'medalerts', 'nastiparty', 'puertovallarta']
# ==========================
# firefauci
# ['facistfauci', 'fakefauci', 'fibromyalgia', 'firefauci', 'firefaucinow', 'fireholcomb', 'fraudfauci', 'ignorefauci', 'impeachfauci', 'ouchiefauci', 'popefrancis', 'shutupfauci', 'sirenstudy']
# ==========================
# sinkcovid
# ['1yearcovidch', 'fuckcovid', 'goodnewscovid', 'kidshandlecovid', 'longcovid', 'mostopscovid', 'sickofcovid', 'sinkcovid', 'sinovac', 'supportcovid', 'swisscovidfail', 'yestonocovid', 'zerocovid']
# ==========================
# pfizer
# ['fuckpfizer', 'peaker', 'pfizer', 'pfizerproud', 'phizer', 'prayer', 'spoilers', 'teampfizer']
# ==========================
# scientific
# ['dementiajoe', 'sanantonio', 'scientific', 'scientificbasis', 'scientists', 'screwmitch', 'studentsrise']
# ==========================
# pandemic
# ['andaluca', 'casedemic', 'endthepandemic', 'epidemic', 'evangelical', 'fakepandemic', 'humanizedmice', 'pandemia', 'pandemic', 'pandemicend', 'pandemichair', 'pandemicide', 'pandemics', 'panikmache', 'paramedictk', 'parkwestgc', 'pinardelro', 'plandemic', 'planerin', 'scamdemic', 'scamdemic2020']
# ==========================
# covid19vaccine
# ['covid19learning', 'covid19vacccine', 'covid19vaccince', 'covid19vaccine', 'covid19vaccineact', 'covid19vaccineph', 'covid19vaccineprep', 'covid19vaccinereport', 'covid19vaccines', 'covid19vaccinewebinar', 'cv19factscene', 'sayyestocovid19vaccine']
# ==========================
# stockmarkets
# ['inboundmarketing', 'sharemarket', 'sticktofacts', 'stockmarket', 'stockmarkets', 'wetmarkets']
# ==========================
# singapore
# ['biggaybrunch', 'bridgeport', 'kingstonny', 'mikegeorge', 'pinnacle', 'signalforhelp', 'singapore', 'singaporeans', 'singledose', 'skypapers', 'spikeprotein', 'thingstodo']
# ==========================
# toryliars
# ['coralgables', 'gopcowards', 'stormchasers', 'termlimits', 'tokyo2020', 'torycronyism', 'torykillers', 'torylawbreakers', 'toryliars', 'toryscumbags', 'youngwizards']
# ==========================
# behindthescenes
# ['behindhereyes', 'behindthescenes']
# ==========================
# childcare
# ['catholicchurch', 'chicago', 'childcare', 'childcarehero', 'childsafety', 'coldchain', 'criticalrole', 'decisivedecade', 'hopecare', 'savenychildcare']
# ==========================
# connecticut
# ['coindescurieux', 'connecticticut', 'connecticut', 'donotzestimate', 'inuktitut']
# ==========================
# scottyfrommarketing
# ['scottyfromcoverups', 'scottyfrommarketing']
# ==========================
# saturdaymorning
# ['saturdaymorning', 'saturdaynightlive', 'thursdaymorning']
# ==========================
# equity
# ['deputy', 'envivo', 'equality', 'equalityact', 'equitable', 'equity', 'fertility', 'gevity', 'inequality', 'inequity', 'ottcity', 'ubiquitin']
# ==========================
# coronatine
# ['chronicillness', 'colonialism', 'colonycove', 'commonsense', 'compensationfund', 'coronagipfel', 'coronakrise', 'coronameter', 'coronasomnia', 'coronatine', 'coronavaccine', 'firingline', 'fordnation', 'jasonkenney']
# ==========================
# whatshappeninginmyanmar
# ['whatishappeninginthailand', 'whatshappeninginmyanmar']
# ==========================
# dietician
# ['azphysician', 'deficiency', 'diedtoosoon', 'dietician', 'digitbiencomn', 'esnoticia', 'mathematician', 'origennoticias', 'snd42digital', 'tweetiatrician', 'westmichigan']
# ==========================
# creepyunclejoe
# ['championsleague', 'creepyunclejoe']
# ==========================
# andhrapradesh
# ['anacarepromise', 'andhrapradesh', 'uttarpradesh']
# ==========================
# familytime
# ['facilities', 'familycareivers', 'familyconnect', 'familykavach', 'familymeeting', 'familytime']
# ==========================
# elizabeth
# ['elizabeth', 'klinikbetten', 'oldhabits', 'queenelizabeth']
# ==========================
# nashville
# ['askdrvillacp24', 'clarksville', 'endgunviolence', 'huntsvilleon', 'knoxville', 'nashville', 'watsonville']
# ==========================
# fourwordtweets
# ['fourwordtweets', 'journorequests', 'worldwidetweets']
# ==========================
# pharmtech
# ['bharatbiotech', 'cvspharmtech', 'darttech', 'miamibeach', 'palmbeach', 'pharmtech']
# ==========================
# video
# ['biden', 'envideo', 'evidence', 'fitso', 'giffey', 'jeudemots', 'kidney', 'midmo', 'spidey', 'tiktok', 'venlo', 'video', 'vilseck', 'vimeo', 'visit', 'windsor']
# ==========================
# onehealth
# ['enmnewshealth', 'gwynethpaltrow', 'immunehealth', 'justonehealth', 'longbeach', 'masshealth', 'moneytalks', 'onehealth', 'onehearthandoff', 'onemetuchen', 'oneyearago', 'onhealth', 'pighealth', 'telehealth', 'tonightvmtv']
# ==========================
# loveoverfear
# ['livelovefight', 'loveoverfear', 'proudtobeabear', 'serviceoverself']
# ==========================
# donaldtrump
# ['buildtrust', 'convicttrump', 'despicabletrump', 'donaldjtrump', 'donaldtrump']
# ==========================
# patents
# ['dataleaks', 'eatplants', 'fatloss', 'parents', 'patent', 'patents', 'patience', 'patients', 'patientsafety', 'patriots', 'students']
# ==========================
# vaccinerollout
# ['canadavaccinerollout', 'vaccineforeveryjuan', 'vaccinerollout', 'vaccinerolloutsa', 'votethemallout']
# ==========================
# essentialworkers
# ['essentialcoverage', 'essentialoils', 'essentialworkers', 'protectfarmworkers']
# ==========================
# parenting
# ['3goodthings', 'argentian', 'argentina', 'atencin', 'caregiving', 'geneediting', 'jeremyvine', 'lactating', 'marketing', 'painting', 'parenting', 'trending']
# ==========================
# meditationmiracles
# ['meditationmiracles', 'motivationalquotes']
# ==========================
# best
# ['ableist', 'bbcqt', 'beshear', 'best', 'bgsu', 'blessit', 'bonn', 'boost', 'booster', 'breast', 'breathe', 'brexit', 'bstf', 'bullshit', 'defstar5', 'dext', 'esg', 'jesus', 'kent', 'left', 'leftist', 'lgbt', 'obesity', 'plesbd', 'pmjt', 'quest', 'repost', 'resist', 'trust', 'west', 'wheat', 'yes']
# ==========================
# socialdistancing
# ['endsocialdistancing', 'physicaldistancing', 'socialdistance', 'socialdistancing']
# ==========================
# covidtesting
# ['antibodytesting', 'covidhesitancy', 'covidozgenetics', 'covidsortium', 'covidtesting', 'covidthings', 'givingandgetting', 'humantesting', 'macovidoversight', 'rapidtesting', 'sovietrussia']
# ==========================
# usl
# ['amlo', 'asx', 'cfl', 'esl', 'film', 'gosl', 'ks03', 'msl', 'nfl', 'oil', 'oslo', 'psn', 'sel', 'ucl', 'ucla', 'umn', 'usa', 'uscg', 'usd', 'usl', 'usps', 'ussllc', 'utah', 'uwsp', 'ysyp']
# ==========================
# thankstrump
# ['blackouttrump', 'chuckschumer', 'ivankatrump', 'thankstrump', 'traitortrump']
# ==========================
# immunity
# ['bigmoney', 'gimmegimme', 'hairfinity', 'herdimmunity', 'iamherdimmunity', 'immune', 'immunity', 'immunityjuice', 'immunitytips', 'immunized', 'immunofizz', 'immunologist', 'insociety', 'skimmthis', 'university']
# ==========================
# ahora
# ['abstract', 'accra', 'ahora', 'alhikmah', 'ashrae', 'az1923', 'calosha', 'ebola', 'hashgraph', 'infowar', 'kenora', 'lahore', 'ltimahora', 'mammogram', 'nadohe', 'pharma', 'quora', 'ramaphosa', 'shero', 'there', 'wahiawa', 'zakharova']
# ==========================
# health
# ['bchealth', 'bethealth', 'deaths', 'earth', 'guthealth', 'health', 'healthnews', 'healthshow', 'healthy', 'healthyu', 'heart', 'help', 'realtalk', 'teamgp', 'vthealth', 'zeulx']
# ==========================
# gp
# ['ab', 'afp', 'app', 'ccp', 'chp', 'dwp', 'egypt', 'eu', 'g1', 'g7', 'g8', 'gc', 'gi', 'gin', 'god', 'gop', 'gp', 'gpab', 'gpei', 'gps', 'gqp', 'gym', 'hgh', 'hpv', 'impf', 'kpk', 'pmp', 'rgp', 'ygk', 'yw']
# ==========================
# katebrown
# ['askthebreakdown', 'attleboroma', 'batonrouge', 'catoecon', 'ianbrown', 'katebrown']
# ==========================
# theaters
# ['alzheimers', 'asthmatics', 'athletes', 'deinters', 'hepatitisc', 'hipsters', 'mieuxvautenrire', 'opentexas', 'phthalates', 'shemadefoods', 'strategy', 'theater', 'theaters', 'theblacks', 'thejabbergames', 'theleaderpodcast', 'thelper17', 'themhrcgroup', 'themoment', 'thequeen', 'therapytools', 'thestatecraft', 'thetruck', 'time4stream', 'tomandjerry']
# ==========================
# community
# ['batterseacommunity', 'blackcommunity', 'cdnmuni', 'comirnaty', 'commercial', 'communiqu', 'communism', 'community', 'communityconnects', 'communityimmunity', 'ekcupimmunity', 'oncoimmune']
# ==========================
# vaccineapartheid
# ['medicalapartheid', 'passportapartheid', 'vaccineapartheid', 'vaccineappointment']
# ==========================
# technology
# ['itwasnotahoax', 'methodologies', 'nanotechnology', 'psychological', 'technology']
# ==========================
# data
# ['10tv', 'bigdata', 'dafuq', 'dakota', 'dallas', 'data', 'dataviz', 'dato', 'day1', 'death', 'drdeath', 'dubai', 'dutch', 'dvt', 'edchat', 'napa', 'opendata', 'qatar', 'update', 'watch']
# ==========================
# lalege
# ['college', 'daleggere', 'failedgov', 'fauxleft', 'iadhere', 'jolene', 'labouroflove', 'lakeside', 'lalege', 'lasvegas', 'latest', 'lebanese', 'paidleave', 'raleigh', 'txlege']
# ==========================
# mind
# ['bild', 'eminat', 'h5n8', 'ibd', 'id', 'kind', 'kingdom', 'maine', 'mediamonday', 'mgfd', 'mi03', 'mills', 'mind', 'misc', 'mntwins', 'mrna', 'ninja', 'opioid', 'pm760', 'sindh', 'swine', 'zinc']
# ==========================
# leadership
# ['censorship', 'gendergrift', 'gloucestershire', 'leadership', 'mothership', 'womeninleadership']
# ==========================
# chemotherapy
# ['chemotherapy', 'chemotherapysupport', 'cryotherapy', 'genetherapy', 'photography', 'theformerguy']
# ==========================
# emergencymanagement
# ['emergencymanagement', 'riskmanagement']
# ==========================
# whistleblowers
# ['boristhebutcher', 'cdcwhistleblower', 'disabledbloggers', 'whistleblowers']
# ==========================
# longhauler
# ['floraandulysses', 'longhauler', 'longhaulers', 'randyhillier']
# ==========================
# la
# ['1a', '2am', '5g', 'als', 'amla', 'blm', 'ca', 'cta', 'dna', 'flu', 'fly', 'ga', 'il1', 'j', 'jab', 'kfla', 'la', 'la36', 'lang', 'lapd', 'law', 'libya', 'lnk', 'lula', 'ma', 'mha', 'mlb', 'nola', 'pak', 'psa', 'rna', 'vt', 'wa', 'yll']
# ==========================
# bame
# ['badge', 'bali', 'bame', 'barrie', 'bashment', 'bayer', 'beatmaker', 'bizarre', 'bmo', 'camp', 'camt', 'endgame', 'gamble', 'home', 'lyme', 'panel', 'rbandme', 'safe', 'sage', 'shame', 'tampa', 'teambeh', 'usamade', 'zimbabwe']
# ==========================
# danrathersamerica
# ['alzheimersinamerica', 'danrathersamerica', 'hawleyhatesamerica']
# ==========================
# baseball
# ['baseball', 'basketball', 'housecall', 'sandwell', 'thagavalkal', 'townhall', 'vamosjarmell']
# ==========================
# production
# ['2021predictions', 'addiction', 'airpollution', 'coproduction', 'courtcollections', 'geolocation', 'prevention', 'production', 'protective']
# ==========================
# rip
# ['acip', 'armipt', 'arpx', 'cfp', 'did', 'esri', 'hipaa', 'hipo', 'hiv', 'ijid', 'ip', 'irish', 'mip', 'pis', 'priti', 'rcep', 'rfp', 'rgv', 'ri', 'rich', 'rip', 'ripmom', 'riseup', 'rtz', 'rupaul', 'six', 'strip', 'syria', 'tips', 'unficyp', 'vbiv', 'xrp']
# ==========================
# medicare
# ['808educate', 'agedcare', 'arminarm', 'buyerbeware', 'delaware', 'domesticabuse', 'educated', 'longtermcare', 'lymedisease', 'medical', 'medicare', 'medicareforall', 'medicres', 'miamidade', 'military', 'minimumwage', 'ministre', 'osumedicine', 'primarycare', 'selfcare', 'tedcruz', 'tedcruzisajoke', 'telemedicine', 'webinar', 'wecare']
# ==========================
# vaccinepassport
# ['fascismpassport', 'novaccinepassport', 'novaccinepassports', 'vaccinatiepaspoort', 'vaccinationpassports', 'vaccinepassport', 'vaccinepassportno', 'vaccinepassports', 'vaccinepossible']
# ==========================
# crimesagainsthumanity
# ['crimeagainsthumanity', 'crimesagainstchildren', 'crimesagainsthumanity']
# ==========================
# trustthefacts
# ['trustthefacts', 'trustthemoms']
# ==========================
# stopthespread
# ['slowthespread', 'stoprxgreed', 'stopthespread', 'stopthespreadma', 'stopthespreadofcovid19', 'stopthesteai2020']
# ==========================
# politicalcartoon
# ['politicalcartoon', 'politicalparasites', 'politicsnation']
# ==========================
# stimuluspackage
# ['stimuluschecks', 'stimuluspackage']
# ==========================
# openamerica
# ['bidensamerica', 'gopbetrayedamerica', 'occamsrazor', 'olderamericansact', 'openamerica', 'opensource', 'openupamerica', 'plumxmetrics', 'rupertmurdoch']
# ==========================
# covidsex
# ['comicstrip', 'confused', 'covidalert', 'covidanswers', 'covidfree', 'covidhoax', 'covidisreal', 'covidkim', 'covidpau', 'covidscam', 'covidsecure', 'covidsex', 'covidsweden', 'covidvax', 'covidzero', 'covishield', 'overdose', 'sweepcovidsleg']
# ==========================
# getthevax
# ['1800getvaxx', 'getoutthevax', 'gettested', 'getthejab', 'getthevax', 'maxthevax', 'nextrevfnc', 'preteenvaxca']
# ==========================
# iappreciateyou
# ['appreciationpost', 'iappreciateyou']
# ==========================
# vaccinated
# ['accinated', 'brainwashed', 'imvaccinated', 'lookingahead', 'vaccinate', 'vaccinated', 'vaccinatenhv', 'vaccinateny', 'vaccinenews', 'vaccineready', 'vaccinestrategy', 'vacinasim', 'vacinated', 'vaksingratis', 'vaxupdate']
# ==========================
# disability
# ['accessibility', 'accountability', 'adaptability', 'disabilities', 'disability', 'disabled', 'disappointed', 'dontkillit', 'drsaumyatg', 'learningdisability', 'metabolism', 'responsibility', 'rxaffordability']
# ==========================
# transplant
# ['googletranslate', 'grantalert', 'kidneytransplant', 'pennsylvania', 'stayvigilant', 'transhumanism', 'transmart', 'transnasal', 'transplant', 'transplantid', 'transport', 'travelagent']
# ==========================
# sideffect
# ['disinfect', 'impfpflicht', 'sideeffect', 'sideffect', 'spacequest', 'yessuperfeet']
# ==========================
# biotech
# ['abilenetx', 'bigtech', 'bigtobacco', 'biometric', 'biontech', 'biospace', 'biotech', 'fintech', 'insurtech', 'medtech', 'pfizerbiontech', 'pistoche', 'sunoltech', 'trimthebush', 'violence']
# ==========================
# elearning
# ['blessings', 'bluewaterbridge', 'cleaning', 'developing', 'distancelearning', 'elearning', 'geneticcleansing', 'goodmorning', 'keepleadinggcs', 'learningloss', 'learningpods', 'machinelearning', 'safeguarding', 'stillwaiting']
# ==========================
# johnsonandjohnson
# ['johnsonandjohnson', 'johnsonandjohnsonvaccine', 'johnsonandjonhson', 'johnsonjohnson']
# ==========================
# billgates
# ['arrestbillgates', 'bangladesh', 'billgates', 'billionaires', 'billynambaruk', 'georgeskatzes', 'jobguarantee', 'killgates', 'nikolatesla']
# ==========================
# biophysics
# ['anaphylaxis', 'bidplymouth', 'biophysics', 'chemicalphysics', 'econophysics', 'geophysics', 'gophypocrisy', 'sociophysics']
# ==========================
# food
# ['bigfood', 'blood', 'dunwoody', 'enfotos', 'firm', 'flow', 'food', 'foods', 'fox', 'fvd', 'gold', 'hgohd', 'hocomd', 'mood', 'oxford', 'seafood', 'superfood', 'zdoggmd', 'zoom']
# ==========================
# endlockdown
# ['antilockdown', 'endlockdown', 'endlockdownnow', 'endthelockdown', 'eternallockdown', 'nationallockdown', 'planetlockdown']
# ==========================
# vonderleyen
# ['1votecloser', 'genderreveal', 'ursulavonderleyen', 'vonderleyen']
# ==========================
# chile
# ['adele', 'agile', 'apple', 'article', 'castlej', 'child', 'children', 'chile', 'china', 'chinajoe', 'chinese', 'choice', 'climate', 'complex', 'cruise', 'cycle', 'failed', 'iciipe', 'jowhiley', 'philly', 'recycle', 'rochdale', 'sheeple', 'shingles', 'smile', 'swale', 'thisworld', 'whistler']
# ==========================
# nbc
# ['abc', 'abc15', 'bbcaq', 'bbcpm', 'bnc', 'cbd', 'innbc', 'jbs', 'kabul', 'kn95', 'l1c4', 'lbc', 'ltc', 'mbc', 'msnbc', 'nba', 'nbc', 'nbc7', 'nbcct', 'nih', 'nimc', 'nmtc', 'okc', 'quebec', 'rdcl', 'snac']
# ==========================
# vaccine
# ['hacking', 'hpvvaccine', 'nacin', 'vaccin', 'vaccinat', 'vaccine', 'vaccine4all', 'vaccines', 'vaccinesnow', 'vaccini', 'vacine', 'vacunas', 'vacvine']
# ==========================
# onlineexamsfor9thand11th
# ['onlineexamsfor9thand11th', 'onlineexamsforclass9thand11th']
# ==========================
# newyork
# ['andrewcuomo', 'beadwork', 'hcqworks', 'needyou', 'networks', 'newjersey', 'newnormal', 'newstouse', 'newyear', 'newyork', 'newyorkcity', 'nuevayork', 'pelosipork', 'seniors']
# ==========================
# bidenadmin
# ['abandonedmzansi', 'bidenadmin', 'bidenbombs', 'bidenharris', 'bidenremorse']
# ==========================
# vaccinessavelives
# ['paidsickdayssavelives', 'stayhomesavelives', 'thickthighssavelives', 'uaccessmagazine', 'vaccinessavelives']
# ==========================
# fauci
# ['anthonyfauci', 'davinci', 'drfauci', 'drfraudci', 'fact', 'fascism', 'fascist', 'fauchi', 'fauci', 'faucihero', 'fauciouchie', 'fraudci', 'naqvi', 'ocfpsummit', 'yakult']
# ==========================
# road2recovery
# ['drugdiscovery', 'economicrecovery', 'road2recovery', 'roadtorecovery', 'worldrecoveryplan']
# ==========================
# vaccinecovid19
# ['shecarescovid19', 'vaccinecovid19', 'vacunacovid19']
# ==========================
# novaccine
# ['antivaccine', 'covacin', 'fakevaccine', 'jandjvaccine', 'jjvaccine', 'jnjvaccine', 'jomvaksin', 'knowyourvaccine', 'nobavaglio', 'novaccine', 'novaccine4me', 'novaccineforme', 'oxfordvaccine', 'pavaccine', 'planyourvaccine', 'pmtookvaccine', 'postvaccine']
# ==========================
# bigtechcensorship
# ['bigtechcensorship', 'entrepreneurship']
# ==========================
# allergies
# ['alberteinstein', 'aldersley', 'allergies', 'allergy', 'allergy2021', 'foodallergies', 'hungergames', 'nhlbruins', 'rmsforgirls', 'truetrophies', 'ucalgarymed', 'ulteriormotives']
# ==========================
# vitamin
# ['bitcoin', 'britain', 'elijahmcclain', 'fctfamily', 'ginsomin', 'thinkagain', 'vaxrampup', 'victoria', 'vietnam', 'vitamin', 'vitaminc', 'vitamind', 'vitamins', 'winmetawin']
# ==========================
# missouri
# ['gainsbourg', 'godissovereign', 'melbourne', 'missionpossible', 'missionzero', 'mississauga', 'mississippi', 'missouri', 'missourimess', 'mistersoftee', 'mitochondria', 'pittsburgh', 'whoissecular']
# ==========================
# nutrition
# ['distribution', 'neutralization', 'notoracism', 'nstnation', 'nutriliva', 'nutrition', 'nutritioncoach', 'petition']
# ==========================
# sd2021
# ['8m2021', 'ags2021', 'bep001', 'bioasia2021', 'census2021', 'cpac2021', 'cuaresma2021', 'dbd2019', 'flu2021', 'gduhem2021', 'gforg2022', 'id2020', 'iwd2021', 'lapc2021', 'leph2021', 'niaw2021', 'ntts2021', 'psl62021', 'qss2021', 'sd2021', 'sicb2021', 'wbgep2021', 'wj2025']
# ==========================
# keepsafe
# ['deepfake', 'greenspace', 'jerusalem', 'kedmeoff', 'keepsafe', 'keepsuttonsafe', 'keepwell', 'keirstarmer', 'makeschoolssafe']
# ==========================
# heroes
# ['aerosol', 'blacheroesofbhm', 'cherokee', 'cherribi', 'devops', 'eroots', 'ferrets', 'hero', 'heroes', 'heynext', 'hoaxes', 'infosec', 'jeffbezos', 'merkel', 'nervous', 'percepta', 'redcross', 'refugees', 'seriodesignfx', 'shethbrothers', 'stereotypes', 'superpowers', 'thegreens', 'themodel', 'viruses', 'zerocases']
# ==========================
# savioursday2021
# ['acpeuyouth2021', 'savioursday', 'savioursday2021', 'springbreak2021']
# ==========================
# zerodiscrimination
# ['discrimination', 'zerodiscrimination', 'zerodiscriminationday']
# ==========================
# chinavirus
# ['adenovirus', 'ccpvirus', 'chinavirus', 'chinesevirus', 'chyawanprash', 'fightthevirus', 'joinallofus', 'magavirus', 'myghanalinks', 'nipahvirus', 'wuhanvirus']
# ==========================
# employers
# ['employees', 'employer', 'employers', 'employmentlaw', 'flowers', 'jewelrynews', 'orderfollowers', 'templemed']
# ==========================
# pastors
# ['beatstars', 'bfmstory', 'doctors', 'investors', 'parties', 'passport', 'pasteur', 'pastors', 'pestdoctor', 'phytopthora', 'ripianstjohn', 'truestory', 'vasanrt', 'vectors']
# ==========================
# lockdownscostlives
# ['lockdownhouseparty', 'lockdownscostlives', 'toryliescostlives']
# ==========================
# sleeveup
# ['chpwsleevesup', 'sleevesupla', 'sleeveup']
# ==========================
# wearamask
# ['bearsmaskup', 'wearadamnmask', 'wearamask', 'wearamasksavealife', 'wearemuhsd', 'wearewcsd', 'wearfacemasks', 'wearmask']
# ==========================
# podcast
# ['abadcars', 'apocalypse', 'forecast', 'gulfcoast', 'holocaust', 'honduras', 'ivorycoast', 'jobhunt', 'mcpodcast', 'opioidcrisis', 'piawest', 'podcast', 'podcasts', 'themmmpodcast']
# ==========================
# modernavaccines
# ['experimentalvaccine', 'maternaljustice', 'modernavaccine', 'modernavaccines', 'mrnavaccines', 'mypersonalvaccine', 'poisonousvaccines', 'valuingvaccines']
# ==========================
# shipping
# ['chongqing', 'ethiopia', 'freeshipping', 'gfvipparty', 'happeningnow', 'philippine', 'philippines', 'phishing', 'sheikhhasina', 'shielding', 'shipment', 'shipping', 'tipping', 'vishing', 'winning']
# ==========================
# bts
# ['abuse', 'ahs', 'atsi', 'bbn', 'bds', 'bntx', 'bots', 'bts', 'btsarmy', 'cghs', 'dfs', 'etf', 'etsy', 'gbhs', 'hhs', 'lgbtq', 'mets', 'ptsd', 'stl']
# ==========================
# scum
# ['asthma', 'cuomo', 'icu', 'icymi', 'rescue', 'scam', 'scicomm', 'scuba', 'scum', 'scummo', 'serum', 'stem', 'stfu', 'study', 'vc19', 'wcm']
# ==========================
# covid
# ['500000covid', 'cbridge', 'cloud', 'co03', 'colma', 'comic', 'covaids', 'covax', 'covaxin', 'covd', 'covi', 'covid', 'covidbc', 'coward', 'cowin', 'ctcovid', 'devil', 'dodgecovid', 'hivaids', 'joebiden', 'lipids', 'lucid', 'nocovid', 'rapidcovid', 'world']
# ==========================
# epidemiology
# ['boletnepidemiolgico', 'epidemiologist', 'epidemiology', 'puredermatology']
# ==========================
# energytransition
# ['energytransition', 'tchicktransition']
# ==========================
# coveringcovid
# ['combattingcovid', 'coveringcovid', 'coveringcovid19']
# ==========================
# nonprofits
# ['iotproducts', 'kidsoverprofits', 'nonprofit', 'nonprofits', 'unionproud', 'wrongpriorities']
# ==========================
# covid19variants
# ['brazilianvariant', 'covid19awareness', 'covid19variants', 'covidvariants', 'sarscov2b117variant', 'virusvariants']
# ==========================
# corona
# ['bolsonaro', 'colorado', 'control', 'corbyn', 'corona', 'coronapod', 'coronil', 'corpivensa', 'cowinapp', 'economy', 'forakobra', 'fucorona', 'georgia', 'icerinks', 'korona', 'koronafi', 'leronlimab', 'longcorona', 'noiinteam', 'ourotago', 'oxymoron', 'parody', 'pneumonia', 'setahuncoronari', 'throwback', 'toronto', 'viruscorona', 'workout', 'zyropathy']
# ==========================
# hospitalheroes
# ['hometownheroes', 'hospitalheroes', 'hospitalization', 'hospitalsinfocus']
# ==========================
# threatening
# ['fridayfeeling', 'reopening', 'syriabombing', 'thegreatreopening', 'threatening', 'threelingobingo']
# ==========================
# italia
# ['aaaai21', 'airasia', 'attualit', 'australia', 'evali', 'insulin', 'israeli', 'israelis', 'italia', 'italian', 'italy', 'itatiaia', 'lapalma', 'petaluma', 'phytaphix', 'slovakia', 'starlink', 'tektelic', 'utopia']
# ==========================
# police
# ['comics', 'doilies', 'jakpostlife', 'office', 'physical', 'poland', 'police', 'polio', 'poliofree', 'polish', 'polqc', 'portstlucie', 'prince', 'public', 'publicceo', 'wilmde', 'zglife']
# ==========================
# backthevac
# ['backthevac', 'backtonormal', 'blocktexas', 'factcheck', 'saskatchewan', 'trackthevax']
# ==========================
# facemasks
# ['facebook', 'facemask', 'facemasks', 'facemasksforsale', 'facemasktuesday', 'kaczyski', 'simcoemuskoka', 'ufcvegas20']
# ==========================
# research
# ['doyourresearch', 'jeopardy', 'newresearch', 'research', 'researcharticle', 'researchers', 'resources', 'taoiseach']
# ==========================
# grocery
# ['discovery', 'dogearmy', 'grocery', 'gtxcorp', 'gunreform', 'mallgrocery', 'onlinegrocery', 'robbery', 'tragedy']
# ==========================
# lagov
# ['116gov', 'akgov', 'begov', 'biggov', 'fdagov', 'glasgow', 'labour', 'lagov', 'langkawi', 'laugh', 'lavrov', 'lebanon', 'localgov', 'yougov']
# ==========================
# blackhistorymonth
# ['blackhistorymonth', 'blackhistorymonth2021', 'womenshistorymonth']
# ==========================
# heston
# ['asbestos', 'boston', 'cartoon', 'chemistry', 'eton', 'evanston', 'gemsoc', 'hbstrong', 'heartmonth', 'hesitancy', 'heston', 'heydan', 'hongkong', 'houston', 'htown', 'metoo', 'moscow', 'pentagon', 'peston', 'thevision', 'valleystrong', 'vision']
# ==========================
# riverforest
# ['davenportto', 'digitizerforever', 'domesticterrorist', 'governornewsom', 'lakeforest', 'neverforget', 'riverforest', 'wilberforcerys21']
# ==========================
# deplatformhate
# ['deplatform', 'deplatformhate']
# ==========================
# harvard
# ['amazoncard', 'awkward', 'charlieward', 'everupward', 'hardpass', 'harrisonford', 'harshvardhan', 'harvard', 'jamboard', 'january6th', 'laguaira', 'thailand', 'whartongrad']
# ==========================
# gottheshot
# ['gcsgottheshot', 'gotmyshot', 'gotothesource', 'gottheshot', 'igotmyshottn', 'igottheshot', 'igottheshotnyc', 'lovethisjob', 'tommytiernanshow', 'wegotthiswa']
# ==========================
# california
# ['california', 'californians', 'carcinogenic', 'catalonia', 'catocalifornia', 'cholinergic', 'eosinopenia']
# ==========================
# abbottfailedtexas
# ['abbottfailedtexas', 'abbottfailedtexasagain']
# ==========================
# volunteering
# ['moneylaundering', 'volunteer', 'volunteering']
# ==========================
# johnson
# ['borisjohnson', 'johnshopkins', 'johnson', 'johnsonmustgo', 'johnsson', 'johnyoung', 'joysms', 'liarjohnson', 'london', 'soundhound', 'stjohnpeople', 'tucson']
# ==========================
# nationalnews
# ['actionalert', 'independantnews', 'inspirationaltweet', 'metromanilanews', 'nationalguard', 'nationalnews', 'nationalpieweek', 'nationalscienceday', 'nationalsecurity', 'salmondspeaks', 'whitenationalists']
# ==========================
# raisethewage
# ['drinkthewater', 'flattenthecurve', 'mapoftheweek', 'raisethewage', 'rarediseaseday', 'releasethelease']
# ==========================
# covid19
# ['covid19', 'covid19ab', 'covid19az', 'covid19lbs', 'covid19ma', 'covid19ph', 'covid19sa', 'covid19sl', 'covid19tx', 'covid19uk', 'covid21', 'covidni', 'coviduk', 'cv19', 'encovid19', 'endcovid19', 'idahocovid19', 'occovid19', 'pgccovid19', 'vtcovd19']
# ==========================
# today
# ['ahatoday', 'amway', 'autophagy', 'birthday', 'corby', 'friday', 'holiday', 'honey', 'jordan', 'monday', 'mtpdaily', 'norway', 'onthisday', 'r4today', 'saturday', 'sohappy', 'thursday', 'today', 'tory', 'trudeau']
# ==========================
# congress
# ['attacksonpress', 'cellpress', 'cingress', 'congress', 'conspiracy', 'couriernews', 'montreal', 'mrnaccess', 'seconddose', 'twinglish']
# ==========================
# momlife
# ['actorslife', 'compliance', 'goodlife', 'gymlife', 'midwife', 'mobileye', 'momlife', 'mozambique', 'msmlies', 'mybodymychoice', 'outlawlife', 'zombie']
# ==========================
# politics
# ['analytics', 'apocalptica', 'apologizetobts', 'calcities', 'followtrick', 'hypocritemitch', 'mdpolitics', 'mepolitics', 'notimippci', 'olympics', 'politicians', 'politico', 'politics', 'politicslive', 'politique', 'robotics', 'solvesstrips', 'tokyoolympics', 'ukpolitics']
# ==========================
# marico
# ['1yearago', 'baric', 'fox47madison', 'henrico', 'leadcpco', 'manxradio', 'march', 'marico', 'market', 'marzo', 'mauricie', 'maziko', 'mexico', 'monaco', 'morocco', 'mswarriors', 'mxico', 'mybrcc', 'ontario', 'saltillo', 'sandiego', 'sarscov2', 'servicenow', 'vaxicov']
# ==========================
# findforfu
# ['askingforafriend', 'fieldwork', 'fightfor15', 'findforfu', 'findforfun', 'fridaysforfuture', 'fundourfutures']
# ==========================
# supplements
# ['apexlegends', 'dietarysupplement', 'noappointments', 'peoplesmint', 'simplereminders', 'supplement', 'supplements', 'supplementwarehouse', 'trueachievements']
# ==========================
# patientexperience
# ['patientexperience', 'patientrecruitment']
# ==========================
# astrazeneca
# ['advancehechat', 'ashwagandha', 'astrazeneca', 'astrazenecavaccine', 'astrazeneka', 'astrazenica', 'oxfordastrazeneca']
# ==========================
# murders
# ['ayurveda', 'bundesrat', 'burgdorf', 'ecuador', 'elders', 'mardigras', 'mudrunfinder', 'murder', 'murderer', 'murders', 'nerdalert', 'nurses', 'openborders', 'outdoors', 'shoulders', 'soldiers', 'sunrisers', 'turmeric']
# ==========================
# humanrights
# ['humanexperiments', 'humanist', 'humanrights', 'knowyourrights', 'nohumanrights', 'suboversight', 'thugarmypatriots', 'youhaverights']
# ==========================
# iran
# ['airbnb', 'brant', 'fraud', 'ghana', 'human', 'iran', 'irantruth', 'iraq', 'israel', 'isrgrajan', 'kras', 'migrant', 'oman', 'siren', 'thank', 'trakt', 'viral', 'vrbpac']
# ==========================
# alcoholawareness
# ['alcoholawareness', 'braintumorawareness', 'ultralowfreezers']
# ==========================
# ny
# ['15now', '8nn', 'cnn', 'dnd', 'eye', 'funny', 'genz', 'hungry', 'jnj', 'joy', 'ky', 'lnp', 'n501y', 'nc', 'nj', 'no', 'nwt', 'ny', 'ny19', 'ny27', 'nyc', 'nymc', 'nyp', 'nys', 'nyt', 'nz', 'only55', 'rn', 'sky', 'tb', 'wny', 'yyj']
# ==========================
# ada
# ['5fu', '80aday', 'abdx', 'abq', 'ada', 'ade', 'ads', 'age', 'ajax', 'amay', 'amg', 'ana', 'anti', 'art', 'asap', 'avn', 'azn', 'cafa', 'cdu', 'cfa', 'fda', 'fdac', 'gadaffi', 'goa', 'gta', 'iava', 'japan', 'kadha', 'ladakh', 'lds', 'maga', 'magat', 'odx', 'tea', 'zd6']
# ==========================
# pope
# ['dchope', 'dole', 'export', 'fptp', 'gopspeak', 'hope', 'house', 'joke', 'opera', 'people', 'poll', 'pope', 'pork', 'poser', 'posh', 'power', 'ppe', 'prop19', 'prophet1', 'proxy', 'pune', 'type1', 'vote']
# ==========================
# b1
# ['1b', 'b1', 'b117', 'b1351', 'b1427', 'b1526', 'bbq', 'bc', 'bjp', 'bkc', 'bnt162b2', 'bro', 'f1', 'ff', 'hq1', 'kbf', 'p1', 't1d', 'tbt', 'wb6']
# ==========================
# dr
# ['15hr', 'dc', 'ddj', 'deer', 'df', 'dr', 'drb', 'drj', 'drug', 'drugs', 'dyk', 'ehr', 'er', 'hr', 'jj', 'pr', 'prv', 'ttrpg', 'vr', 'yqr']
# ==========================
# topnews
# ['appnews', 'bignews', 'dognews', 'doktornews', 'fmtnews', 'fox11news', 'foxnews', 'gippsnews', 'goodnews', 'hounews', 'knownews', 'ktvonews', 'kutv2news', 'loonies', 'nrtnews', 'todaysnews', 'topnews', 'topnieuws', 'tppinsiders', 'worldnews', 'ziznews']
# ==========================
# egyptianstudentslivesmatter
# ['egyptianstudentslivesmatter', 'egyptianstudentslivesmatterr']
# ==========================
# elections2021
# ['election2020', 'elections2021', 'electionsmatter', 'farmbills2020']
# ==========================
# desnatis
# ['deathsantis', 'defeatdd', 'deltapilots', 'desantis', 'desnatis', 'digestthis', 'disneyplus', 'edtechethics', 'itstartswithus', 'meningitis', 'mewsuppasit', 'newsanatomy13', 'rondesnatis', 'seahawks', 'thesecats', 'wednesdaywisdom', 'yesneera']
# ==========================
# azchallenge
# ['azchallenge', 'moneyupchallenge', 'rachellevine', 'richieallenshow', 'smilechallenge']
# ==========================
# presidentbiden
# ['beijingbiden', 'ilovdmypresidentbiden', 'presidentbiden', 'presidentbidenimpetus', 'presidentjoebiden', 'presidentsiveralert', 'presidenttrump', 'presionmedicine']
# ==========================
# academictwitter
# ['academicchatter', 'academictwitter', 'cardiotwitter']
# ==========================
# carenotcovid
# ['account4covid', 'carenotcovid', 'chemvscovid', 'coronophobic', 'cuidatedelcovid19', 'gardenofflavor', 'lesaviezvouscovid', 'markedbycovid', 'takeontyphoid']
# ==========================
# bigpharma
# ['ajmpharma', 'bigfarma', 'bigpharm', 'bigpharma', 'bigpharmas', 'bigtexasfreeze', 'brigham', 'hindustanpharma', 'meijerpharmacy', 'sinopharm']
# ==========================
# celebrity
# ['celebrateblack', 'celebrity', 'cybersecurity', 'littlebritain', 'weflibrary']
# ==========================
# trudeaufailed
# ['strandedaussies', 'trudeaufailed', 'trudeaufailedcanada', 'trudeaulied', 'trudeaumustgo', 'trudeauvaccinefail']
# ==========================
# canadian
# ['canadapensionplan', 'canadawewant', 'canadian', 'canadianpm', 'canadians', 'canadiantire', 'cannabinoid', 'cannabis', 'cardinals', 'centenarian', 'janadian', 'kansascity', 'macedonian', 'senateapp', 'tanzanian']
# ==========================
# retirementlife
# ['reggaeforlife', 'retirementlife', 'theincrementalist']
# ==========================
# stayhome
# ['kwawesome', 'shotofhope', 'snackmode', 'spreadhope', 'staploe', 'stayasleep', 'stayathome', 'stayhome', 'staysafe', 'staysafemn', 'staystrong', 'staywellsomerset']
# ==========================
# vaccinecertificateno
# ['vaccinecertificateno', 'vaccinecertificateyes']
# ==========================
# lockdown
# ['biglockdown', 'blockchain', 'jockdown', 'lockdown', 'lockdown2021', 'lockdown4', 'lockdown4ever', 'lockdownbeenden', 'lockdownfatigue', 'lockdownroadmap', 'lockdowns', 'lockdownskill', 'rocknroll', 'smackdown']
# ==========================
# thescience
# ['believeinscience', 'computerscience', 'datascience', 'experiences', 'fakescience', 'followthescience', 'knowthescience', 'neuroscience', 'science', 'sipofscience', 'thedefender', 'theinfiniteage', 'thejuice', 'thereidout', 'thescience', 'trustscience', 'trustthescience']
# ==========================
# alternativemedicine
# ['alternatereality', 'alternativemedicine', 'laboratorymedicine', 'naturopathicmedicine']
# ==========================
# autism
# ['ageism', 'audits', 'autism', 'autismmlb', 'capitalism', 'nutrav', 'purim', 'putkids1st', 'racism', 'tourism', 'tunisia', 'turkish']
# ==========================
# bayern3racism
# ['bayern3racism', 'bayern3racist', 'endracism']
# ==========================
# austin
# ['21stjune', 'aussie', 'austin', 'austintx', 'austria', 'baluchistan', 'boostit', 'bulletin', 'cluster', 'dublin', 'imtiazhussain', 'justice', 'justin', 'justsaying', 'klausschwab', 'mullins', 'plastic', 'putin', 'quetta', 'russia', 'sustainable', 'utaustin', 'yakultindia']
# ==========================
# morale
# ['20more4all', 'bobmarley', 'donald', 'google', 'hottake', 'importante', 'innate', 'kirklees', 'kobjlder', 'mehole', 'michaelche', 'monsanto', 'morale', 'mosque', 'onsale', 'oracle', 'unforgivable', 'yohanblake']
# ==========================
# gothamhealthbelvis
# ['gatewayhealthfamily', 'gothamhealthbelvis']
# ==========================
# veran
# ['adverse', 'berlin', 'german', 'germany', 'herbal', 'kerns', 'mccann', 'merck', 'revera', 'saveranboo', 'tcrn', 'terbaru', 'vechain', 'vegas', 'veran', 'vermont', 'wepray']
# ==========================
# american
# ['africa', 'african', 'africanamerican', 'africans', 'america', 'americafirst', 'american', 'americanracism', 'americans', 'americaortrump', 'americastrong', 'amsterdam', 'amwriting', 'firstamerican', 'jamaica', 'mexican', 'nativeamerican']
# ==========================
# covidvaccination
# ['clientacquisition', 'coronavaccination', 'covid19vaccination', 'covidvaccinated', 'covidvaccination', 'covidvaccinationdrive', 'covidvaccinations', 'datavisualization', 'vvipvaccineracism']
# ==========================
# hotelindustry
# ['ceindustry', 'hospitalityindustry', 'hotelindustry', 'repeatinghistory', 'softdrinkfactory']
# ==========================
# stopthehate
# ['savethedate', 'skininthegame', 'stockexchange', 'stopasianhate', 'stopthecdc', 'stopthecrime', 'stopthegreatreset', 'stopthehate', 'stopthepandemic']
# ==========================
# wearescotland
# ['medgareverscollege', 'shelterscotland', 'wearescotland']
# ==========================
# europe
# ['ausopen', 'euro21', 'europe', 'european', 'europeanunion', 'eurozone', 'exercise', 'teameurope']
# ==========================
# internationalstudents
# ['internationalhpvday', 'internationalstudents']
# ==========================
# statenews
# ['awaninews', 'ctvtweets', 'diabetes', 'fakenews', 'inthenews', 'islandernews', 'ontarionews', 'smartnews', 'standwithhcws', 'statenews', 'stateofca', 'stayhighonnews', 'whatsnews']
# ==========================
# newsnight
# ['dailynewsdigest', 'isleofwight', 'jcnewmancigars', 'netanyahu', 'newsnight', 'newspicks', 'theendisinsight', 'wedoitright']
# ==========================
# veterans
# ['30seconds', 'betterbuses', 'celegans', 'eventprofs', 'kenburns', 'nevadans', 'neworleans', 'peteevans', 'restaurants', 'vaxtransit', 'venezuela', 'venezuelans', 'veteran', 'veterans', 'voteyesonc213']
# ==========================
# pregnant
# ['greghunt', 'oregonart', 'ppescandal', 'pregnancy', 'pregnant', 'prepact', 'preprint', 'programmed']
# ==========================
# thankyou
# ['euthanasia', 'thankful', 'thankyou', 'thankyoumodiji', 'thankyounhs', 'transkids', 'whatdontyouget']
# ==========================
# cure
# ['budget', 'bury', 'care', 'code', 'coke', 'cre', 'csr', 'cuba', 'cult45', 'curbal', 'curd', 'cure', 'curehiv', 'curevac', 'cyprus', 'forex', 'kurz', 'nculg', 'nurse', 'pure', 'unfurl']
# ==========================
# sciencenews
# ['access2meds', 'insurancenews', 'laifesciencenews', 'mcwsciencesays', 'prisonsocietynews', 'scienceliquid', 'sciencenews', 'sciencepolicy', 'sciencewillwin', 'scienceworks']
# ==========================
# vaccination
# ['blazernation', 'covaccination', 'happyvaccinationday', 'organisation', 'vaccinating', 'vaccination', 'vaccinationcovid', 'vaccinationdrive', 'vaccinations', 'vaccineswork', 'vaccinetime', 'vaksinasinasional', 'vaxthenation', 'ventilation']
# ==========================
# sackhancock
# ['masksdontwork', 'matthancock', 'sackhancock', 'sanfrancisco']
# ==========================
# impfungen
# ...
# ==========================
# manchin
# ['bmunc211', 'joemanchin', 'lancashire', 'macron', 'madeinchina', 'manchin', 'mancity', 'marchbreak', 'mcfranchise', 'meghanmccain', 'memphis', 'michigan', 'minbhos', 'montcopa', 'radiopunchline', 'ranchlife', 'vaxchamp', 'wecandoit']
# ==========================
# dailyfail
# ['dailyfail', 'dairyfree', 'darrashall', 'epicfail', 'familyaffair', 'paidleaveforall']
# ==========================
# government
# ['8thamendment', 'biggovernment', 'denvernuggets', 'environment', 'fosterparents', 'goverment', 'government', 'governmentgod', 'governmentofindia', 'localgovernment', 'loverfest', 'movetheneedle', 'procurement', 'ukgovernment', 'usgovernment']
# ==========================
# turkishstudentslivesmatter
# ['turkishstudentslivesmatter', 'turkishstudentslivesmatters']
# ==========================
# holdtheline
# ['abovethenoise', 'arnoldthehero', 'completemelife', 'followthemoney', 'glaxosmithkline', 'hivethinking', 'holdtheline', 'isolationlife', 'righttolive']
# ==========================
# crushcovid
# ['crushcovid', 'crushcovidri', 'crushingcovid']
# ==========================
# organic
# ['anandaorganic', 'bareorganics', 'drugprices', 'eugenics', 'hispanic', 'ohtani', 'organic', 'organicveda', 'orlando', 'virginia']
# ==========================
# askanurse
# ['arkansas', 'askabouthpv', 'askanexpert', 'askanurse', 'askunmcim', 'janatacurfew', 'maskmandate', 'massachusetts', 'thankanurse']
# ==========================
# vaccinecenter
# ['fromthecenter', 'mosconecenter', 'vaccinateteachers', 'vaccinecenter', 'vaccinevolunteers']
# ==========================
# malaria
# ['alberta', 'algeria', 'andalucia', 'bamlanivimab', 'batavia', 'bavaria', 'bayarea', 'bulgaria', 'drharris', 'florida', 'gematria', 'hifasdaterra', 'kamalaharris', 'kamalhaasan', 'maharashtra', 'majoroops', 'malaikaarora', 'malaria', 'malaysia', 'malaysians', 'mlpfim', 'moldova', 'ralphbaric', 'royalcaribbean', 'smallbiz', 'tanzania', 'valdiviacl']
# ==========================
# tracesafe
# ['handsfacespace', 'ridesafer', 'tracesafe', 'tracingapps', 'traderjoes', 'travelsafety', 'travelstyle', 'treecetalk', 'tripswaiver', 'unacceptable']
# ==========================
# happyday
# ['appstate', 'globalplayday', 'happyanniversary', 'happybirthday', 'happydance', 'happyday', 'happyface', 'opalopenday', 'pmtampabay']
# ==========================
# tcrprofiling
# ['bioprocessing', 'immuneprofiling', 'tcrprofiling', 'toryprofiteering', 'toweroflondon']
# ==========================
# israelvaccinationapartheid
# ['israelivaccinationapartheid', 'israelvaccinationapartheid']
# ==========================
# colombia
# ['britishcolumbia', 'btszombieau', 'clumsybitch', 'colombia', 'columbusga', 'despiertacolombia']
# ==========================
# logo
# ['alcohol', 'blog', 'blogpost', 'bojo', 'congo', 'dog', 'dogs', 'dougford', 'enough', 'gojoe', 'jobs', 'letsgo', 'lgm', 'logo', 'slomo', 'tokyo', 'tv3gh', 'vlog', 'yoga']
# ==========================
# breakingnews
# ['beijing2022', 'breakingnews', 'emigsbreakingnews', 'gettinganswers', 'regulatorynews', 'tprbreakingnews', 'trendingnow']
# ==========================
# ruralhealth
# ['globalhealth', 'notabouthealth', 'nutrameltz', 'oralhealth', 'ruralhealth', 'ruralhealthjustice', 'rushlimbaugh', 'syrahealth', 'vibranthealth']
# ==========================
# gatesforprison
# ['clothesforphil', 'gatesforprison', 'gatesfoundation']
# ==========================
# dranissadavis
# ['dennisschrader', 'dranissadavis', 'drdadiliagarces', 'trinitasadvisors', 'urbainiaspaces']
# ==========================
# thankfultuesday
# ['charitytuesday', 'thankfultuesday', 'thumbsuptuesday']
# ==========================
# sanitiser
# ['safetytip', 'sanitiser', 'sanitizer', 'sheismyhero', 'statistical', 'unionminister']
# ==========================
# christian
# ['afghanistan', 'caribbean', 'christian', 'christianity', 'christmas', 'christophernolan', 'chriswhitty', 'crisprcas9', 'croatia', 'kurdistan', 'kyrgyzstan']
# ==========================
# covidiot
# ['covidcuomo', 'covidday', 'covidgrift', 'covididiot', 'covidiot', 'covidioten', 'covidiots', 'covidshot', 'covidstocks', 'covidstory', 'covidunit', 'fox43findsout']
# ==========================
# brasil
# ['bahrain', 'bcfamily', 'bigoil', 'bracelet', 'brasil', 'brazil', 'bristol', 'bullsih', 'profit', 'transit', 'travel']
# ==========================
# iot
# ['bailout', 'biostat', 'bot', 'ccot', 'cios', 'cityofto', 'ckont', 'diet', 'flight', 'govt', 'idiot', 'ikea', 'inphoto', 'iom', 'iot', 'iota', 'iowa', 'job', 'jvt', 'kids', 'mom', 'north', 'oott', 'pio', 'quote', 'roc', 'shot', 'tcot', 'tipsta', 'uoft', 'uot', 'wow', 'zionist']
# ==========================
# afterschool
# ['afternoon', 'afterschool', 'antipsychotics', 'backtoschool', 'elementaryschool', 'homeschooled', 'openschoolsnow']
# ==========================
# goldenrule
# ['deadendpledge', 'glendale', 'goldendoodle', 'goldenglobes', 'goldenrule', 'goldentrump', 'goldmansachs', 'rossendale']
# ==========================
# sars
# ['70years', 'aaas', 'arr', 'carr', 'mars', 'mazars', 'ournhs', 'paris', 'sant', 'sarcasm', 'sars', 'sars2', 'scary', 'sdgs', 'sdri', 'share', 'snkrs', 'spars', 'sss', 'usarmy', 'vaers']
# ==========================
# gratitude
# ['attitude', 'graftonstreet', 'grandrounds', 'grateful', 'gratitude', 'gravitas', 'griffithuni', 'justintrudeau', 'reactstudy']
# ==========================
# ema
# ['2mar', 'amazon', 'bermuda', 'cdmx', 'denmark', 'ecme', 'ema', 'emis', 'emmy', 'emt', 'espaa', 'eua', 'evg', 'fema', 'fenway', 'gma3', 'hmh', 'jcmo', 'jmd', 'meme', 'metal', 'nepal', 'omg', 'pedia', 'peru', 'resume', 'smh', 'ymm']
# ==========================
# hair
# ['5thcir', 'chaos', 'daily', 'dairy', 'fail', 'fair', 'gvirf', 'haiku', 'hair', 'haiti', 'happy', 'hawaii', 'heor', 'horror', 'jaipur', 'latur', 'marr', 'ohwait', 'shagger', 'wbir', 'wvgirl']
# ==========================
# hereforyou
# ['hereforyou', 'therewithyou', 'votefordout2022', 'yhereforyou']
# ==========================
# blacklivesmatteruk
# ['blacklivesmatter', 'blacklivesmatteruk']
# ==========================
# register
# ['armyhistory', 'drugcartel', 'legalhistory', 'primeminister', 'rapidtest', 'receptor', 'register', 'rejecthr1', 'remdesivir', 'reminder', 'remittances', 'remotework', 'repost247', 'resisters', 'retweeet', 'ringofsteel', 'rochester']
# ==========================
# danielclarke
# ['angelamerkel', 'cancelculture', 'danielclarke', 'intelycharge']
# ==========================
# newsletter
# ['factsmatter', 'inverseexposure', 'kenneykluster', 'melbweather', 'news18debrief', 'newscentermaine', 'newsletter', 'newslineph', 'newworldorder', 'omanobserver', 'onedownonetogo', 'smellsrotten']
# ==========================
# asian
# ['abidjan', 'ahin', 'aiims', 'albany', 'amimanera', 'asia', 'asian', 'asians', 'askabc6', 'askaman', 'assay', 'fashion', 'lassa', 'sign', 'wuhan']
# ==========================
# covidpassport
# ['coronapassport', 'covidpassport', 'covidpassports', 'cowinonlineportal', 'golddomereport']
# ==========================
# nstleader
# ['ajalexander', 'dearleader', 'eatalarajender', 'elsalvador', 'nhsnewdeal', 'nitiaayog', 'nstleader', 'nucleartech', 'wastewater']
# ==========================
# carers
# ['ahrecs', 'caregivers', 'carehome', 'carer', 'carers', 'chareidi', 'cheers', 'compares', 'darwin', 'daterush', 'farmers', 'flyers', 'hackers', 'pancreas', 'starwars', 'unpaidcarers', 'womencareers', 'wowzers', 'zuckerberg']
# ==========================
# covidvaccine
# ['coloradovaccine', 'covidisairborne', 'covidlawpolicy', 'covidvacccine', 'covidvaccine', 'covidvaccineab', 'covidvaccinede', 'covidvaccineforum', 'covidvaccines', 'globalvaccine', 'olindavacina', 'peoplesvaccine', 'pfizervaccine', 'poliovaccine']
# ==========================
# cacounties
# ['accountinggo', 'cacounties', 'cancelstudentdebt', 'cancersurvivors', 'chicagosuntimes', 'commodities', 'foodpantries', 'nanobodies', 'opportunities', 'rrcouncil', 'ruralcommunities']
# ==========================
# mrpresident
# ['dollyforpresident', 'expresodelamaana', 'mrpresident', 'notmypresident', 'president', 'trumpismypresident']
# ==========================
# rollupyoursleeve
# ['rollsuphersleeve', 'rollupyoursleeve', 'rollupyoursleevesmn']
# ==========================
# oneshot
# ['boostershots', 'cnnsotu', 'flushot', 'minnesota', 'oannewsroom', 'oneshot', 'oxyshooter', 'secondshot', 'theoneshow']
# ==========================
# lastminute
# ['blossomingtrees', 'gleanerminute', 'lastminute', 'plasticusage', 'ultimominuto']
# ==========================
# canada
# ['banana', 'caedu', 'cambma', 'canada', 'canart', 'canwnt', 'cdnmedia', 'covidcanada', 'geneva', 'karnataka', 'manaus', 'newcanaan', 'ohcanada', 'panama', 'salads', 'tornado', 'vacunaya']
# ==========================
# local
# ['becalm', 'buffalo', 'dksocial', 'ethical', 'global', 'globalbuzz', 'glycans', 'joinctap', 'loan', 'local', 'nocap', 'slowakei', 'trulylocal']
# ==========================
# collegeradio
# ['collateprojectau', 'collegeadmissions', 'collegeradio', 'internetradio']
# ==========================
# onlineexamsonly
# ['emergenicesonly', 'onlineexamsforclass9', 'onlineexamsonly']
# ==========================
# qanda
# ['and', 'anmat', 'band7', 'bangla', 'gardai', 'jandj', 'manga', 'punjab', 'qanda', 'qanon', 'qanons', 'qantas', 'qumaana', 'randpaul', 'rwanda', 'rwandair', 'sunday', 'uganda', 'usfda', 'vanuatu']
# ==========================
# covid19nc
# ['covid1984', 'covid19aus', 'covid19bc', 'covid19fund', 'covid19hv', 'covid19impact', 'covid19ireland', 'covid19longbeach', 'covid19mb', 'covid19nc', 'covid19news', 'covid19nfld', 'covid19nl', 'covid19nsw', 'covid19nz', 'covid19ontario', 'covid19qc', 'covid19sc', 'covid19sk', 'covid19tz', 'covid19vic', 'covid19wi', 'covid19wy', 'covidroundsca']
# ==========================
# mentalhealthmatters
# ['mentalhealthawareness', 'mentalhealthishealth', 'mentalhealthmatters', 'publichealthmatters']
# ==========================
# southafrica
# ['intoafrica', 'investinafrica', 'northamerica', 'plustvafrica', 'southafrica', 'southafrican', 'southamerica', 'southpark', 'totoafrica']
# ==========================
# worldhealthorganization
# ['mckinseyorganization', 'worldhealthorganization']
# ==========================
# cancer
# ['breastcancer', 'cancer', 'cancun', 'cancuncruz', 'canmore', 'cannonfodder', 'career', 'confirmbecerra', 'cubacoopera', 'cyber', 'endhpvcancers', 'gopisacancer', 'hannahbecker', 'janssen', 'lancet', 'lawyer', 'myanmar', 'spaffer', 'talcumpowder', 'tanden', 'unc0ver', 'vancouver']
# ==========================
# phe
# ['nphet', 'pbl', 'pfe', 'phac', 'phage', 'phase2', 'phe', 'phled', 'phri', 'phuket', 'prek', 'ptf', 'the']
# ==========================
# realestatemarket
# ['peakstatecoffee', 'realestatemarket']
# ==========================
# liberal
# ['digital', 'epidural', 'iberoroc', 'iherbhaul', 'liberal', 'liberallogic', 'liberals', 'liberty', 'lifestyle', 'livefree', 'senegal']
# ==========================
# municipalmatters
# ['municipalities', 'municipalmatters']
# ==========================
# northkorea
# ['bobbyshmurda', 'northernireland', 'northkorea', 'northshoresd', 'southkorea']
# ==========================
# killermurphy
# ['brendanmurphy', 'killermurphy', 'villuppuram', 'vivekmurthy']
# ==========================
# ghanapolice
# ['ghanapolice', 'ghanasaysno', 'ghanaweb22', 'ghmusiclive', 'handsanilife', 'thalidomide', 'thoughtpolice']
# ==========================
# antivaxx
# ['antimask', 'antivaccin', 'antivax', 'antivaxx', 'antivaxxer', 'antivaxxers', 'antivaxxsquad', 'antiviral', 'intunivxr', 'vaxx4vaxx']
# ==========================
# idonotconsent
# ['idonotconsent', 'informedconsent', 'issotlconnect21']
# ==========================
# vaccinequity
# ['vaccinatesouthphilly', 'vaccinedaddy', 'vaccineequity', 'vaccinefacts', 'vaccinefriday', 'vaccinemaitri', 'vaccinequity', 'vaccineskit']
# ==========================
# trumps
# ['mutetrump', 'stoptrumpism', 'thefrumpfs', 'thugs', 'tiruppur', 'trips', 'trump', 'trump2024', 'trumpcpac', 'trumpcult', 'trumpisguilty', 'trumpregime', 'trumps', 'trumpusa', 'trumpvirus', 'truth']
# ==========================
# indians
# ['india', 'indian', 'indiana', 'indians', 'indias', 'indiegogo', 'indonesia', 'indveng', 'indyref2', 'inpics', 'insights', 'iranians', 'onlyfans']
# ==========================
# careworkers
# ['babyboomers', 'careworkers', 'facebookfriends', 'farmworkers', 'garbagesurveys', 'healthcareworkers', 'keyworker', 'laurenboebert', 'pipeworks', 'preorder', 'teleworkweekdc', 'warroomtraders']
# ==========================
# eating
# ['beautiful', 'beijing', 'belonging', 'bingeeating', 'breaking', 'eatfit247', 'eating', 'endtime', 'erasing', 'exciting', 'fasting', 'healing', 'latino', 'latinos', 'leftwing', 'reading', 'realtime', 'recruiting', 'seating', 'testing', 'voting']
# ==========================
# sundaymotivation
# ['genitalmutilation', 'mondaymotivation', 'sundaymotivation', 'thursdaymotivation']
# ==========================
# covid19update
# ['andamanupdate', 'covid19colorado', 'covid19kwaraupdate', 'covid19southaus', 'covid19update', 'covidupdate', 'monitorupdates', 'virusupdate']
# ==========================
# socialists
# ['seditionists', 'socialcare', 'socialists', 'socialjustice', 'socialmedia', 'solidarity']
# ==========================
# racismlsnotanopinion
# ['racismisnotanopinion', 'racismlsnotanopinion']
# ==========================
# sugar
# ['buhari', 'calgary', 'gujarat', 'hungary', 'kuwait', 'kyga21', 'sciart', 'shrmhr', 'sjugrad21', 'solgar', 'sugar', 'sugarlite', 'sunak', 'suvichar']
# ==========================
# personalfinance
# ['pearsonairport', 'personalfinance', 'personalhygiene']
# ==========================
# tcells
# ['bcells', 'calls', 'seychelles', 'stimulus', 'tcell', 'tcells', 'theelms', 'tuckercarlson', 'twill']
# ==========================
# contracting
# ['constructionworker', 'contacttracing', 'contracting', 'counterfeiting', 'criticalthinking', 'frontierairlines', 'fundraising', 'humantrafficking', 'jobtraining', 'manufacturing']
# ==========================
# live
# ['11alive', '501yv3', 'biglie', 'cblive', 'elite', 'level1', 'lies', 'life', 'live', 'liver', 'love', 'wisvets']
# ==========================
# clinicians
# ['climatechange', 'clinicaltrials', 'clinicalwaste', 'clinicians', 'gavinwilliamson', 'paidsickdays']
# ==========================
# moderna
# ['borderwall', 'elderly', 'moderna', 'modernapuff', 'modirogardo', 'modirojgar', 'monterey', 'nigeria', 'soberana02', 'thanksmoderna']
# ==========================
# highrisk
# ['bizbridge', 'highcourt', 'highfiver', 'highpeak', 'highrisk', 'highriskca', 'highriskcovid19', 'highriskct', 'rishisunak', 'thebigthrill']
# ==========================
# notjoking
# ['notcomplying', 'notjoking', 'notosinovac', 'notthrowingaway', 'nowplaying', 'remoteworking', 'seniorliving', 'unitedkingdom']
# ==========================
# libertarians
# ['authoritarianism', 'cyberattacks', 'libertapablohasel', 'libertarians', 'libertyquestions', 'listenlearnactsd', 'nayabharatabiyan']
# ==========================
# tigerwoods
# ['comfortfoods', 'lindareynolds', 'sorryfortigerwoods', 'tigerwoods', 'trishayearwood', 'yogaforwomens']
# ==========================
# stores
# ['desires', 'expreso', 'kidneystones', 'schools', 'sdpreps', 'secrets', 'smoothies', 'snowbirds', 'spoonies', 'sports', 'sportsbiz', 'stocks', 'stores', 'stress', 'tories', 'usautosales']
# ==========================
# genocide
# ['cuomocide', 'genocide', 'genome', 'greencoffee', 'pesticide', 'senicide', 'tigraygenocide']
# ==========================
# pharmaceutical
# ['pharmaceutical', 'pharmaceuticalsindustry', 'takedapharmaceutical']
# ==========================
# contactlesspayments
# ['contactlesspayments', 'contactlesssecurity']
# ==========================
# teamvaccines
# ['100mvaccines', 'safevaccines', 'teamvaccibe', 'teamvaccine', 'teamvaccines', 'trumpvaccines']
# ==========================
# washington
# ['vaxshitshow', 'washington', 'washingtondc', 'washingtonpost', 'washingtonstate', 'writingtips']
# ==========================
# mirrornow
# ['didyouknow', 'mauroena24', 'microgreens', 'micropenis', 'mirrornow', 'mirrorsandsmoke', 'virusoorlog']
# ==========================
# nursetwitter
# ['blacktwitter', 'dogsoftwitter', 'gaymedtwitter', 'nativetwitter', 'nursepractitioners', 'nursetwitter', 'podcasttwitter', 'pulseoximeters']
# ==========================
# 423

# %%
affprop_dict_scrub = {}

# %%
t = np.array(list(map(lambda v: ((v - v.min()) / (v.max() - v.min())).mean(), lev_similarity)))
t > t.mean()

# %% [markdown]
# ## Apply to main data

# %%
hashtag_eng['hashtag_group'] = list(map(lambda x: hashtag_group(grouping=affprop_dict, hashtag=x), hashtag_eng['hashtags']))

# %%
hashtag_eng
# Out:
#              hashtags             tweet_id   hashtag_group
# 0               Covid  1364726798412443649           covid
# 1             COVID19  1364726771606691845         covid19
# 2             COVID19  1364726746797367297         covid19
# 3            eviction  1364726728183144449       infection
# 4        ChuckSchumer  1364726702027530241     thankstrump
# ...               ...                  ...             ...
# 24046  COVID19Vaccine  1366568301367730176  covid19vaccine
# 24047     coronavirus  1366557132997365761     coronavirus
# 24048           Delhi  1366549371559440386           delhi
# 24049           trump  1366546719597559813          trumps
# 24050          corona  1366542785868873730          corona
#
# [23990 rows x 3 columns]

# %% [markdown]
# ### Check that Tweets are in english

# %%
raw_text_en  = raw_text[list(map(lambda x: detect(x),raw_text['full_text']))]

#? add hashtag group
raw_text_en = raw_text_eng.merge(hashtag_eng, on = "tweet_id", how = "inner")

# %%
raw_text_en

# %% [markdown]
# ### Save to local fs

# %% [markdown]
# # Data Cleaning 1

# %% [markdown]
# This is some basic inspection and cleaning for the twitter data. In this notebook we:
# 1. Find and mend two broken rows.
# 2. Find and drop duplicates.
# 3. Recast datatypes.
# 4. Add a datetime column for tweet creation timestamp.

# %% [markdown]
# ### Import Dependencies

# %%
import pandas as pd

import pickle # just in case

# %% [markdown]
# ### Set file locations

# %%
# Raw data file for tweet text (input file)
tweet_text_file = '../00_data/twitter_data/twitter_text.csv'

# File for cleaned tweet text (output file)
clean_csv = '../00_data/twitter_data/twitter_data_cleaned.csv'

# %% [markdown]
# ### Read in raw data

# %%
df = pd.read_csv(tweet_text_file)

# %%
df.head()
# Out:
#               tweet_id                      created_at  \
# 0  1364223054851813377  Tue Feb 23 14:38:16 +0000 2021
# 1  1364381497302671362  Wed Feb 24 01:07:52 +0000 2021
# 2  1364609594056704002  Wed Feb 24 16:14:15 +0000 2021
# 3  1364726798412443649  Wed Feb 24 23:59:58 +0000 2021
# 4  1364726797947052038  Wed Feb 24 23:59:58 +0000 2021
#
#                                            full_text  geo coordinates place  \
# 0  Here’s what's in the COVID relief package:\n \...  NaN         NaN   NaN
# 1  Will the National Endowment for the Arts be he...  NaN         NaN   NaN
# 2  This is both anecdotal and early, but many lon...  NaN         NaN   NaN
# 3  A Link to Professor Chossudovsky’s Analysis of...  NaN         NaN   NaN
# 4  Children warned over hugging grandparents even...  NaN         NaN   NaN
#
#   retweet_count favorite_count possibly_sensitive lang       user_id
# 0          9160          38093          NOT FOUND   en  2.950125e+07
# 1          6131          18560          NOT FOUND   en  1.201671e+18
# 2          5941          63174          NOT FOUND   en  3.842872e+07
# 3             1              0              False   en  2.192010e+09
# 4             0              2              False   en  2.868190e+09

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51172 entries, 0 to 51171
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            51172 non-null  object
#  1   created_at          51170 non-null  object
#  2   full_text           51170 non-null  object
#  3   geo                 77 non-null     object
#  4   coordinates         79 non-null     object
#  5   place               1008 non-null   object
#  6   retweet_count       51170 non-null  object
#  7   favorite_count      51170 non-null  object
#  8   possibly_sensitive  51170 non-null  object
#  9   lang                51168 non-null  object
#  10  user_id             51168 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 4.3+ MB

# %%
df.possibly_sensitive.value_counts()
# Out:
# False         30276
# NOT FOUND     20438
# True            454
# 46902592.0        1
# 46902592          1
# Name: possibly_sensitive, dtype: int64

# %% [markdown]
# Observations:
# 1. 'geo', 'coordinates', and 'place' are very lightly populated. Exclude?
# 2. I would expect 'tweet_id', 'full_text', and 'user_id' to all have identical counts, but they do not. Need to look at that.
# 3. I would expect 'tweet_id' to be of the same Dtype as 'user_id', but it does not.
# 4. I would expect 'retweet_count' and 'favorite_count' to be integers, but they are not.
# 5. I would expect 'possibly_sensitive' to be free of numerical data.

# %% [markdown]
# ### Check the obvious anomalies

# %% [markdown]
# We're looking to account for the holes in the counts above, i.e.:
# 2 instances each of null values for 'created_at', 'full_text', 'retweet_count', 'favorite_count', and 'possibly_sensitive'
# 4 instances each of null values for 'lang' and 'user_id'.
# 2 instances of numerical data in 'possibly_sensitive'.

# %%
df[df['user_id'].isnull()]
# Out:
#                       tweet_id                      created_at  \
# 3600       1364723003620270083  Wed Feb 24 23:44:54 +0000 2021
# 3601   https://t.co/dMoo7szXE0                             NaN
# 16061      1366124610568216582  Sun Feb 28 20:34:23 +0000 2021
# 16062  https://t.co/AVf4W5aP3L                             NaN
#
#                                                full_text  geo coordinates  \
# 3600   Good News for Europeans... even if your leftis...  NaN         NaN
# 3601                                                 NaN  NaN           1
# 16061  Important Open Letter and Analysis of the Covi...  NaN         NaN
# 16062                                                NaN  NaN           0
#
#       place retweet_count favorite_count possibly_sensitive lang  user_id
# 3600    NaN           NaN            NaN                NaN  NaN      NaN
# 3601      1         False             en           46902592  NaN      NaN
# 16061   NaN           NaN            NaN                NaN  NaN      NaN
# 16062     1         False             en         46902592.0  NaN      NaN

# %% [markdown]
# It looks like two broken lines in the csv. The 'full_text' entries somehow got split right before the included urls. This also explains why 'tweet_id', 'retweet_count', 'favorite_count', and 'user_id' had been automatically cast as strings, as well as why there is numerical data in 'possibly_sensitive'. That's everything we're looking for.
#
# Looked these tweets up manually to see if there is anything unusual:
# twitter.com/anyuser/status/1364723003620270083
# twitter.com/anyuser/status/1366124610568216582
#
# Turns out it's the same user and sequence of hashtags for both tweets, but not the only time that user included that sequence of hashtags in our dataset. So, inconclusive (but repairable for now).

# %% [markdown]
# ### Mend the broken rows

# %%
# We could also just drop them.
# df = df[df['user_id'].notna()]

# %%
# To mend this, we need to add the url back into the 'full_text' column and also sort of slide 
# the rest of the mislocated columns back into place.  
# This mends the rows, but we could alternatively just take care of this manually in the csv using a text editor.

# Shift the cells that were mislocated in their entirety.
df.iloc[3600, 3:11] = df.iloc[3601, 1:9]
# Join the cell that was broken in the middle.
df.iloc[3600, 2] = df.iloc[3600, 2] + '\n' + df.iloc[3601, 0]

df.iloc[16061, 3:11] = df.iloc[16062, 1:9]
df.iloc[16061, 2] = df.iloc[16061, 2] + '\n' + df.iloc[16062, 0]

df.drop(df.index[[3601,16062]], inplace = True)

# %%
# Check the mended rows.
df.iloc[[3600, 16060], :]
# Out:
#                   tweet_id                      created_at  \
# 3600   1364723003620270083  Wed Feb 24 23:44:54 +0000 2021
# 16061  1366124610568216582  Sun Feb 28 20:34:23 +0000 2021
#
#                                                full_text  geo coordinates  \
# 3600   Good News for Europeans... even if your leftis...  NaN         NaN
# 16061  Important Open Letter and Analysis of the Covi...  NaN         NaN
#
#       place retweet_count favorite_count possibly_sensitive lang     user_id
# 3600    NaN             1              1              False   en    46902592
# 16061   NaN             0              1              False   en  46902592.0

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51170 entries, 0 to 51171
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            51170 non-null  object
#  1   created_at          51170 non-null  object
#  2   full_text           51170 non-null  object
#  3   geo                 77 non-null     object
#  4   coordinates         77 non-null     object
#  5   place               1006 non-null   object
#  6   retweet_count       51170 non-null  object
#  7   favorite_count      51170 non-null  object
#  8   possibly_sensitive  51170 non-null  object
#  9   lang                51170 non-null  object
#  10  user_id             51170 non-null  object
# dtypes: object(11)
# memory usage: 4.7+ MB

# %% [markdown]
# ### Check for duplicates

# %%
df.duplicated().value_counts()
# Out:
# False    51157
# True        13
# dtype: int64

# %%
suspected_duplicates_df = df[df.duplicated(keep = False)]
len(suspected_duplicates_df)
# Out:
# 26

# %%
suspected_duplicates_df.sort_values('tweet_id')
# Out:
#                   tweet_id                      created_at  \
# 51171  1364320252461535235  Tue Feb 23 21:04:30 +0000 2021
# 9061   1364320252461535235  Tue Feb 23 21:04:30 +0000 2021
# 9060   1364519307103916039  Wed Feb 24 10:15:29 +0000 2021
# 51170  1364519307103916039  Wed Feb 24 10:15:29 +0000 2021
# 9059   1364573246885163013  Wed Feb 24 13:49:49 +0000 2021
# 51169  1364573246885163013  Wed Feb 24 13:49:49 +0000 2021
# 51168  1364594670030962691  Wed Feb 24 15:14:56 +0000 2021
# 9058   1364594670030962691  Wed Feb 24 15:14:56 +0000 2021
# 9057   1364598020558491655  Wed Feb 24 15:28:15 +0000 2021
# 51167  1364598020558491655  Wed Feb 24 15:28:15 +0000 2021
# 9056   1364692013690535938  Wed Feb 24 21:41:45 +0000 2021
# 51166  1364692013690535938  Wed Feb 24 21:41:45 +0000 2021
# 10504  1364742955840335874  Thu Feb 25 01:04:11 +0000 2021
# 51165  1364742955840335874  Thu Feb 25 01:04:11 +0000 2021
# 51164  1364842762831425539  Thu Feb 25 07:40:46 +0000 2021
# 10553  1364842762831425539  Thu Feb 25 07:40:46 +0000 2021
# 10527  1364960645960056833  Thu Feb 25 15:29:12 +0000 2021
# 51163  1364960645960056833  Thu Feb 25 15:29:12 +0000 2021
# 897    1365051451802873857  Thu Feb 25 21:30:02 +0000 2021
# 51162  1365051451802873857  Thu Feb 25 21:30:02 +0000 2021
# 51161  1365179171194822657  Fri Feb 26 05:57:32 +0000 2021
# 4149   1365179171194822657  Fri Feb 26 05:57:32 +0000 2021
# 51160  1365251083036098562  Fri Feb 26 10:43:17 +0000 2021
# 7747   1365251083036098562  Fri Feb 26 10:43:17 +0000 2021
# 51159  1365297742659129346  Fri Feb 26 13:48:42 +0000 2021
# 21965  1365297742659129346  Fri Feb 26 13:48:42 +0000 2021
#
#                                                full_text  geo coordinates  \
# 51171  @CGreenUK No, but maybe employers shouldn't be...  NaN         NaN
# 9061   @CGreenUK No, but maybe employers shouldn't be...  NaN         NaN
# 9060   @NickBoles Treating the Covid19 vaccines diffe...  NaN         NaN
# 51170  @NickBoles Treating the Covid19 vaccines diffe...  NaN         NaN
# 9059   @BarryCPearson @HilaryWallace1 @stiffenking @l...  NaN         NaN
# 51169  @BarryCPearson @HilaryWallace1 @stiffenking @l...  NaN         NaN
# 51168  @TamronHallShow please don't put Anti-Vaxxers ...  NaN         NaN
# 9058   @TamronHallShow please don't put Anti-Vaxxers ...  NaN         NaN
# 9057   Remember when you saw Toby Young and Julia Har...  NaN         NaN
# 51167  Remember when you saw Toby Young and Julia Har...  NaN         NaN
# 9056   @thatgirl409 I guess I’d be okay with that if ...  NaN         NaN
# 51166  @thatgirl409 I guess I’d be okay with that if ...  NaN         NaN
# 10504  Instead of focusing on equitable and efficient...  NaN         NaN
# 51165  Instead of focusing on equitable and efficient...  NaN         NaN
# 51164  @senatormelendez @GavinNewsom No- the idiots n...  NaN         NaN
# 10553  @senatormelendez @GavinNewsom No- the idiots n...  NaN         NaN
# 10527  Please spread this #Ivermectin information. A ...  NaN         NaN
# 51163  Please spread this #Ivermectin information. A ...  NaN         NaN
# 897    Johnson and Johnson @JNJCares  #COVID19 #vacci...  NaN         NaN
# 51162  Johnson and Johnson @JNJCares  #COVID19 #vacci...  NaN         NaN
# 51161  SA doctors say lies about vaccines containing ...  NaN         NaN
# 4149   SA doctors say lies about vaccines containing ...  NaN         NaN
# 51160  Wow - anti-vax people are coming out of the wo...  NaN         NaN
# 7747   Wow - anti-vax people are coming out of the wo...  NaN         NaN
# 51159  @kodaplanetearth @Sebz_1000 @MandyLorijn1 @dav...  NaN         NaN
# 21965  @kodaplanetearth @Sebz_1000 @MandyLorijn1 @dav...  NaN         NaN
#
#            place retweet_count favorite_count possibly_sensitive lang  \
# 51171        NaN             0              0          NOT FOUND   en
# 9061         NaN             0              0          NOT FOUND   en
# 9060         NaN             0              2          NOT FOUND   en
# 51170        NaN             0              2          NOT FOUND   en
# 9059         NaN             0              3              False   en
# 51169        NaN             0              3              False   en
# 51168        NaN             0              0          NOT FOUND   en
# 9058         NaN             0              0          NOT FOUND   en
# 9057         NaN             0              0              False   en
# 51167        NaN             0              0              False   en
# 9056   NOT FOUND             0             14          NOT FOUND   en
# 51166  NOT FOUND             0             14          NOT FOUND   en
# 10504        NaN            25             55              False   en
# 51165        NaN            25             55              False   en
# 51164        NaN             0              0          NOT FOUND   en
# 10553        NaN             0              0          NOT FOUND   en
# 10527        NaN             2              1              False   en
# 51163        NaN             2              1              False   en
# 897          NaN            10              8              False   en
# 51162        NaN            10              8              False   en
# 51161        NaN             1              4              False   en
# 4149         NaN             1              4              False   en
# 51160        NaN             3             10              False   en
# 7747         NaN             3             10              False   en
# 51159        NaN             0              0          NOT FOUND   en
# 21965        NaN             0              0          NOT FOUND   en
#
#                      user_id
# 51171   747351737443328000.0
# 9061    747351737443328000.0
# 9060            3049083785.0
# 51170           3049083785.0
# 9059              19769417.0
# 51169             19769417.0
# 51168            120200107.0
# 9058             120200107.0
# 9057            2548402543.0
# 51167           2548402543.0
# 9056             110871084.0
# 51166            110871084.0
# 10504           3279277182.0
# 51165           3279277182.0
# 51164   808644757316665344.0
# 10553   808644757316665344.0
# 10527  1238836818478587904.0
# 51163  1238836818478587904.0
# 897              421275603.0
# 51162            421275603.0
# 51161              9609582.0
# 4149               9609582.0
# 51160            437351737.0
# 7747             437351737.0
# 51159  1307460325789270016.0
# 21965  1307460325789270016.0

# %%
# Those all look like legitimate duplicates. Let's drop them.
df.drop_duplicates(inplace=True)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51157 entries, 0 to 51158
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            51157 non-null  object
#  1   created_at          51157 non-null  object
#  2   full_text           51157 non-null  object
#  3   geo                 77 non-null     object
#  4   coordinates         77 non-null     object
#  5   place               1005 non-null   object
#  6   retweet_count       51157 non-null  object
#  7   favorite_count      51157 non-null  object
#  8   possibly_sensitive  51157 non-null  object
#  9   lang                51157 non-null  object
#  10  user_id             51157 non-null  object
# dtypes: object(11)
# memory usage: 4.7+ MB

# %% [markdown]
# ### Recast column datatypes

# %%
# Tidy up the column Dtypes
# 'tweet_id' is too big for int or long.

df['tweet_id']=df.tweet_id.astype('float64')
df['retweet_count']=df.retweet_count.astype('int64')
df['favorite_count']=df.favorite_count.astype('int64')
df['user_id']=df.user_id.astype('float64')

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51157 entries, 0 to 51158
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            51157 non-null  float64
#  1   created_at          51157 non-null  object
#  2   full_text           51157 non-null  object
#  3   geo                 77 non-null     object
#  4   coordinates         77 non-null     object
#  5   place               1005 non-null   object
#  6   retweet_count       51157 non-null  int64
#  7   favorite_count      51157 non-null  int64
#  8   possibly_sensitive  51157 non-null  object
#  9   lang                51157 non-null  object
#  10  user_id             51157 non-null  float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 4.7+ MB

# %% [markdown]
# ### Adding datetime for 'created_at'

# %%
# Add a column for 'created_at' recast as datetime.
# I kept the original 'created_at' column out of a super-abundance of caution.

df['created_at'] = pd.to_datetime(df['created_at'])

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51157 entries, 0 to 51158
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            51157 non-null  float64
#  1   created_at          51157 non-null  datetime64[ns, UTC]
#  2   full_text           51157 non-null  object
#  3   geo                 77 non-null     object
#  4   coordinates         77 non-null     object
#  5   place               1005 non-null   object
#  6   retweet_count       51157 non-null  int64
#  7   favorite_count      51157 non-null  int64
#  8   possibly_sensitive  51157 non-null  object
#  9   lang                51157 non-null  object
#  10  user_id             51157 non-null  float64
# dtypes: datetime64[ns, UTC](1), float64(2), int64(2), object(6)
# memory usage: 4.7+ MB

# %%
df.head()
# Out:
#        tweet_id                created_at  \
# 0  1.364223e+18 2021-02-23 14:38:16+00:00
# 1  1.364381e+18 2021-02-24 01:07:52+00:00
# 2  1.364610e+18 2021-02-24 16:14:15+00:00
# 3  1.364727e+18 2021-02-24 23:59:58+00:00
# 4  1.364727e+18 2021-02-24 23:59:58+00:00
#
#                                            full_text  geo coordinates place  \
# 0  Here’s what's in the COVID relief package:\n \...  NaN         NaN   NaN
# 1  Will the National Endowment for the Arts be he...  NaN         NaN   NaN
# 2  This is both anecdotal and early, but many lon...  NaN         NaN   NaN
# 3  A Link to Professor Chossudovsky’s Analysis of...  NaN         NaN   NaN
# 4  Children warned over hugging grandparents even...  NaN         NaN   NaN
#
#    retweet_count  favorite_count possibly_sensitive lang       user_id
# 0           9160           38093          NOT FOUND   en  2.950125e+07
# 1           6131           18560          NOT FOUND   en  1.201671e+18
# 2           5941           63174          NOT FOUND   en  3.842872e+07
# 3              1               0              False   en  2.192010e+09
# 4              0               2              False   en  2.868190e+09

# %% [markdown]
# ### Export the cleaned data

# %%
# Write it to csv.

df.to_csv(clean_csv, index = False)
